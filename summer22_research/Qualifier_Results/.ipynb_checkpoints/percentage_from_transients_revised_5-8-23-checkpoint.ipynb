# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
#from intake import open_catalog
import cartopy.io.shapereader as shpreader
import mygrads as mg
#import Ngl
#import Nio
#import fiona
import matplotlib as mpl
import cartopy.mpl.ticker as cticker
from cartopy.util import add_cyclic_point
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from cartopy.feature import NaturalEarthFeature
from cartopy.feature import COASTLINE
#from clim680_function import xyticks
import pymannkendall as mk
import pandas as pd
import time
import matplotlib.image as mpimg
stime=time.time()

# %%
#load in climatologies for dse and latent heat for 850

# %% [markdown]
# ## 850mb

# %% [markdown]
# ### Total fields

# %%
#DSE
f='/project/xprecip/merra2_ncfiles/energy_calcs/corrections/dse_total850.nc'
DS_dse=xr.open_dataset(f)
dse_total850=DS_dse['__xarray_dataarray_variable__']
dse_total850
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
# array([[-646930.8   , -674930.7   , -700850.4   , ...,  145245.97  ,
#          133545.89  ,  123843.79  ],
#        [-672896.1   , -703205.06  , -731233.6   , ...,  169830.    ,
#          156688.38  ,  146379.75  ],
#        [-697414.1   , -729819.5   , -760233.5   , ...,  194996.56  ,
#          181908.25  ,  170869.81  ],
#        ...,
#        [1377677.9   , 1255415.8   , 1275369.4   , ...,  149353.27  ,
#          -26720.654 ,  -60508.22  ],
#        [1348851.6   , 1025719.5   ,  400837.7   , ...,   98984.82  ,
#           17115.037 , -109653.35  ],
#        [ 387193.    ,    5645.9624,  309201.84  , ..., -116744.516 ,
#         -107000.29  , -116385.914 ]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 ...

# %%
#LE
f='/project/xprecip/merra2_ncfiles/energy_calcs/corrections/lh_climo_total850.nc'
DS_lh=xr.open_dataset(f)
lh_total850=DS_lh['__xarray_dataarray_variable__']
lh_total850
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
# array([[-18380.394243, -18669.270221, -18870.620653, ...,   8273.986145,
#           7581.779971,   7008.470697],
#        [-18737.995792, -19092.063401, -19365.107156, ...,   9578.794846,
#           8811.505586,   8208.257267],
#        [-19110.511877, -19478.761554, -19801.044744, ...,  10888.225138,
#          10134.348646,   9493.38356 ],
#        ...,
#        [ 33020.555247,  29819.985703,  29803.896695, ...,   1878.4283  ,
#           -337.431291,   -774.508489],
#        [ 31501.899455,  22813.932355,   8382.894769, ...,   1198.736149,
#            210.746194,  -1359.961277],
#        [  7961.632297,    101.011456,   4296.017776, ...,  -1341.000285,
#          -1254.606195,  -1395.221098]])
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 ...

# %% [markdown]
# ### Transients

# %%
#DSE
f='/project/xprecip/merra2_ncfiles/energy_calcs/corrections/dse_trans850.nc'
DS_dse_trans850=xr.open_dataset(f)
dse_trans850=DS_dse_trans850['__xarray_dataarray_variable__']
dse_trans850
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 19, lon: 19)>
# array([[  217.506848,   229.58062 ,   243.252529, ...,   455.942041,
#           364.954935,   274.142219],
#        [  348.894211,   363.059363,   354.595136, ...,   839.861279,
#           647.484534,   527.157733],
#        [  543.303949,   559.079736,   470.291175, ...,  1407.965957,
#          1180.783213,   930.417394],
#        ...,
#        [ 3470.776509,  1133.071388,  1139.433968, ...,  9923.531419,
#         11630.581047, 14934.827323],
#        [ 2288.220529,  1682.569008,   548.312099, ...,  7095.463979,
#          8229.378379, 11265.00381 ],
#        [         nan,  2141.213487,          nan, ..., 13007.691833,
#         10389.930513,  6410.072926]])
# Coordinates:
#   * lat           (lat) float64 24.5 26.0 27.5 29.0 30.5 ... 47.0 48.5 50.0 51.5
#   * lon           (lon) float64 -125.0 -121.2 -117.5 ... -65.0 -61.25 -57.5
#     cutoffs       int64 ...
#     coefficients  float64 ...
# ...

# %%
#LE
f='/project/xprecip/merra2_ncfiles/energy_calcs/lhtransients_climo850.nc'
DS_lh_trans850=xr.open_dataset(f)
lh_trans850=DS_lh_trans850['__xarray_dataarray_variable__']
lh_trans850
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
# array([[ 3.418889e+02,  0.000000e+00,  0.000000e+00, ...,  0.000000e+00,
#          0.000000e+00,  0.000000e+00],
#        [ 3.920953e+02,  3.215794e+02,  2.970231e+02, ...,  4.360611e+02,
#          4.109211e+02,  3.505553e+02],
#        [ 3.471532e+02,  2.951376e+02,  2.625973e+02, ...,  4.398623e+02,
#          4.222973e+02,  3.796048e+02],
#        ...,
#        [-3.480678e+02,  3.761622e+00,  4.868593e+02, ...,  3.747272e+03,
#          3.857452e+03,  3.936323e+03],
#        [ 7.998782e+02,  8.023687e+02,  1.027949e+03, ...,  3.005098e+03,
#          3.106265e+03,  3.214582e+03],
#        [ 1.129775e+03,  1.214797e+03,  1.286837e+03, ...,  2.309172e+03,
#          2.455445e+03,  2.634120e+03]])
# Coordinates:
#     cutoffs       int64 ...
#     coefficients  float64 ...
#     lev           float64 ...
#   * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
# ...

# %% [markdown]
# ### Ratio plot

# %%
#zonal means
dse850_transzonal=dse_trans850.mean(dim='lon')
dse850_totalzonal=dse_total850.mean(dim='lon')
lh850_transzonal=lh_trans850.mean(dim='lon')
lh850_totalzonal=lh_total850.mean(dim='lon')
dse_zonal_new=(dse850_transzonal/dse850_totalzonal)*100
lh_zonal_new=(lh850_transzonal/lh850_totalzonal)*100

# %%
ratio_dse_850=(dse_trans850/dse_total850)*100
ratio_lh_850=(lh_trans850/lh_total850)*100

# %%
masked_lh=xr.where((lh_total850<=0.1*lh_total850) & (lh_total850>=-0.1*lh_total850),np.nan,lh_total850) #if CI includes 0, then not significant. If CI doesn't then significant.
masked_lh
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
# array([[-18380.3942427 , -18669.27022114, -18870.62065303, ...,
#           8273.98614492,   7581.77997079,   7008.47069733],
#        [-18737.99579218, -19092.06340089, -19365.10715634, ...,
#           9578.79484631,   8811.50558591,   8208.25726725],
#        [-19110.51187664, -19478.76155376, -19801.04474351, ...,
#          10888.22513819,  10134.34864581,   9493.38356033],
#        ...,
#        [ 33020.55524662,  29819.98570263,  29803.89669538, ...,
#           1878.42829968,   -337.43129054,   -774.50848941],
#        [ 31501.89945474,  22813.93235549,   8382.89476931, ...,
#           1198.73614865,    210.74619362,  -1359.96127734],
#        [  7961.63229737,    101.01145599,   4296.01777578, ...,
#          -1341.00028547,  -1254.60619456,  -1395.22109763]])
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
# ...

# %%
ratio_lh_rev=(lh_trans850/masked_lh)*100
ratio_lh_rev
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 19, lon: 19)>
# array([[ 9.70949104e-02, -4.01047815e-01, -1.80979527e+00,
#         -4.70342513e+00, -9.72677615e+00,  1.89340804e+00,
#                     nan,  9.82185588e+00,  7.92505875e+00,
#          1.14085386e+01,  9.25348970e+00,  9.95974615e+00,
#          1.66522165e+01,  1.11059443e+01,  5.62392856e+00,
#          4.20144485e+00,  4.33645744e+00,  4.28401467e+00,
#          6.64011518e+00],
#        [ 2.82102978e-01, -5.99596910e-01, -1.73052174e+00,
#         -3.67585572e+00, -3.12854174e+02,             nan,
#          2.89560825e+01,  1.27559582e+01,  1.30716173e+01,
#          1.88358731e+01,  1.84307050e+01,  1.88425612e+01,
#          2.03822913e+01,  1.37703279e+01,  8.19970225e+00,
#          5.59605652e+00,  5.60345513e+00,  6.01466632e+00,
#          5.76600582e+00],
#        [-4.15580053e-01, -8.53976702e-01, -1.93519020e+00,
#         -2.82719926e+00,  8.42546867e+00,             nan,
# ...

# %%
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' ()>
# array(-1700.89630819)
# Coordinates:
#     cutoffs       int64 10
#     coefficients  float64 -15.0
#     lev           float64 850.0

# %%
fraction850=[ratio_dse_850,ratio_lh_rev]

# %%
from matplotlib.pylab import *

# Define the figure and each axis for the 2 rows and 2 columns
fig, axs = plt.subplots(nrows=2,ncols=1,
                        subplot_kw={'projection': ccrs.PlateCarree()},
                        figsize=(20,10))
titles=['Dry Static Energy flux', 'Latent Heat flux']
# axs is a 2 dimensional array of `GeoAxes`.  
# We will flatten it into a 1-D array
axs=axs.flatten()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())

#Loop over all of the seasons and plot
#for i in enumerate(climo_all):
for i in range(len(fraction850)):
        # Select the season
        data=fraction850[i]
        # Add the cyclic point
        data,lons=add_cyclic_point(data,coord=dse_trans850['lon'])
        max_val=100
        increment=5
        clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
        cs=axs[i].contourf(lons,dse_trans850['lat'],data,clevs,
                          transform = ccrs.PlateCarree(),
                          cmap='coolwarm',extend='both')
       # Longitude labels
        axs[i].set_xticks(np.arange(-180,181,60), crs=ccrs.PlateCarree())
        lon_formatter = cticker.LongitudeFormatter()
        axs[i].xaxis.set_major_formatter(lon_formatter)

        # Latitude labels
        axs[i].set_yticks(np.arange(-90,91,30), crs=ccrs.PlateCarree())
        lat_formatter = cticker.LatitudeFormatter()
        axs[i].yaxis.set_major_formatter(lat_formatter)

        # Title each subplot with the name of the season
        axs[i].set_title(titles[i])

        # Draw the coastines for each subplot
        axs[i].coastlines()
        axs[i].set_extent([-124.5,-66.8,23.486,49])
        axs[i].add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')
# Adjust the location of the subplots 
# on the page to make room for the colorbar
fig.subplots_adjust(bottom=0.25, top=0.9, left=0.05, right=0.95,
                    wspace=0.2, hspace=0.2)

# Add a colorbar axis at the bottom of the graph
#cbar_ax = fig.add_axes([0.2, 0.175, 0.6, 0.02])
cbar_ax = fig.add_axes([0.69, 0.2, 0.025, 0.7]) #left, bottom width, height
cbar = fig.colorbar(cs, cax = cbar_ax, orientation = 'vertical', label='Percentage (%)',pad = 0.05)
# Draw the colorbar
text = cbar_ax.yaxis.label
font = matplotlib.font_manager.FontProperties(family='times new roman', style='normal', size=16)
text.set_font_properties(font)
# Draw the colorbar
#cbar=fig.colorbar(cs, cax=cbar_ax,orientation='horizontal',label='percentage')
fig.tight_layout()
# Add a big title at the top
plt.suptitle('Fraction of Energy Transport Climatology by transients (850mb)',fontsize=15)
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/revisions/850mbratio_map.png')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:59: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:59: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.

# %% [markdown]
# ## 300 mb

# %% [markdown]
# ### Total fields

# %%
#DSE
f='/project/xprecip/merra2_ncfiles/energy_calcs/corrections/dse_total300.nc'
DS_dse=xr.open_dataset(f)
dse_total300=DS_dse['__xarray_dataarray_variable__']
dse_total300
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
# array([[ -107809.63 ,   -80000.055,   -49205.42 , ..., -1388229.1  ,
#         -1412623.   , -1437728.4  ],
#        [ -167298.84 ,  -140047.5  ,  -111321.19 , ..., -1343531.9  ,
#         -1369664.1  , -1396745.6  ],
#        [ -231696.05 ,  -203950.78 ,  -175132.92 , ..., -1294732.8  ,
#         -1322159.6  , -1350550.8  ],
#        ...,
#        [  -28294.803,  -112692.   ,  -204382.4  , ...,  1800554.4  ,
#          1870441.9  ,  1912126.8  ],
#        [    6276.649,   -93310.69 ,  -240497.89 , ...,  1774332.8  ,
#          1851343.2  ,  1911492.9  ],
#        [  -25828.768,  -160409.8  ,  -314217.25 , ...,  1761267.   ,
#          1834018.6  ,  1900840.9  ]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 ...

# %%
#LE
f='/project/xprecip/merra2_ncfiles/energy_calcs/corrections/lhtotal_climo300.nc'
DS_lh=xr.open_dataset(f)
lh_total300=DS_lh['__xarray_dataarray_variable__']
lh_total300
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
# array([[ -186.135488,  -138.428011,   -85.523218, ..., -2174.349796,
#         -2201.185067, -2225.057452],
#        [ -281.463668,  -236.154516,  -188.204281, ..., -2140.989548,
#         -2168.94825 , -2197.463274],
#        [ -380.304494,  -335.197386,  -288.137658, ..., -2097.201649,
#         -2123.731725, -2155.560345],
#        ...,
#        [  -20.025259,   -78.899159,  -139.751117, ...,   832.254165,
#           864.9837  ,   908.108394],
#        [    4.223408,   -60.319344,  -150.217427, ...,   798.598194,
#           841.165053,   880.425025],
#        [  -15.912411,   -97.16798 ,  -189.17722 , ...,   763.382904,
#           805.096533,   847.771525]])
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 ...

# %% [markdown]
# ### Transients

# %%
#DSE
f='/project/xprecip/merra2_ncfiles/energy_calcs/corrections/geo_trans300.nc'
geo=xr.open_dataset(f)
geo=geo['__xarray_dataarray_variable__']
geo
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 19, lon: 19)>
# array([[ 0.000000e+00,  0.000000e+00,  0.000000e+00, ...,  0.000000e+00,
#          0.000000e+00,  0.000000e+00],
#        [ 0.000000e+00,  0.000000e+00,  0.000000e+00, ...,  0.000000e+00,
#          0.000000e+00,  0.000000e+00],
#        [ 0.000000e+00,  0.000000e+00,  0.000000e+00, ...,  0.000000e+00,
#          0.000000e+00,  0.000000e+00],
#        ...,
#        [ 1.619309e-09,  5.656522e-07, -1.376200e-06, ..., -2.662950e-07,
#          0.000000e+00, -2.823948e-06],
#        [ 6.047501e-08,  2.768454e-06,  5.103165e-07, ..., -3.068171e-08,
#         -3.683556e-08, -1.484474e-06],
#        [ 5.080525e-07,  2.624406e-06,  2.037108e-06, ..., -2.051153e-06,
#         -2.042633e-06, -7.979138e-07]])
# Coordinates:
#   * lat           (lat) float64 24.5 26.0 27.5 29.0 30.5 ... 47.0 48.5 50.0 51.5
#   * lon           (lon) float64 -125.0 -121.2 -117.5 ... -65.0 -61.25 -57.5
#     cutoffs       int64 ...
# ...

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/shtransients_climo300.nc'
sh=xr.open_dataset(f)
sh=sh['__xarray_dataarray_variable__']
sh
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
# array([[-753.460963,    0.      ,    0.      , ...,    0.      ,    0.      ,
#            0.      ],
#        [-720.466756, -704.709946, -680.922979, ..., -207.605835, -204.919311,
#         -228.347983],
#        [-665.741292, -654.711276, -619.21347 , ..., -192.925888, -199.900721,
#         -222.143152],
#        ...,
#        [-367.590429, -471.258788, -626.500325, ..., 6377.653839, 6514.960169,
#         6660.901813],
#        [-435.933696, -539.103022, -691.305799, ..., 5659.190365, 5797.534057,
#         5930.48845 ],
#        [-350.876499, -465.650697, -665.267765, ..., 4932.260946, 5059.092722,
#         5161.564318]])
# Coordinates:
#     cutoffs       int64 ...
#     coefficients  float64 ...
#     lev           float64 ...
#   * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
#   * lat           (lat) float64 20.0 20.75 21.5 22.25 ... 52.25 53.0 53.75 54.5

# %%
dse_trans300=geo+sh
dse_trans300
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 19, lon: 19)>
# array([[-3.23417242e+02, -8.20606409e+01, -2.04855349e+01,
#          1.78981973e+02,  2.59374501e+02,  1.37111912e+02,
#          1.31911807e+02,  6.53012830e+01,  1.19596064e+02,
#          1.71866500e+02,  3.03605917e+01,  4.26533183e+01,
#          7.98334989e+01,  1.32796226e+02,  5.49940821e+01,
#          7.88926838e+00, -3.74399205e+01, -6.66194077e+01,
#         -2.08836841e+00],
#        [-3.45143139e+01,  1.54405392e+02,  1.51300622e+02,
#          3.35812749e+02,  4.93467265e+02,  5.80423276e+02,
#          4.69027685e+02,  4.13718746e+02,  4.70670759e+02,
#          5.45342559e+02,  4.21592889e+02,  3.51433759e+02,
#          3.26823293e+02,  3.58212609e+02,  2.12208653e+02,
#          6.92807534e+01,  9.83156704e+01,  8.73336625e+01,
#          1.85701319e+02],
#        [ 2.58872587e+02,  3.16386827e+02,  3.15206469e+02,
#          4.54555481e+02,  5.71202950e+02,  8.52156756e+02,
# ...

# %%
#LE
f='/project/xprecip/merra2_ncfiles/energy_calcs/lhtransients_climo300.nc'
lh300_trans=xr.open_dataset(f)
lh300_trans=lh300_trans['__xarray_dataarray_variable__']
lh300_trans
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
# array([[341.481134,   0.      ,   0.      , ...,   0.      ,   0.      ,
#           0.      ],
#        [330.21634 , 334.035943, 333.315469, ..., 121.262576, 125.63106 ,
#         130.877538],
#        [335.61175 , 335.64692 , 334.323839, ..., 134.118318, 139.390225,
#         147.766035],
#        ...,
#        [ 40.429323,  41.196277,  41.216372, ..., 184.060625, 184.311322,
#         185.335902],
#        [ 45.239068,  45.882565,  44.251637, ..., 174.002576, 176.377786,
#         178.365741],
#        [ 48.185284,  45.160989,  40.660561, ..., 168.171345, 170.401101,
#         175.392922]])
# Coordinates:
#     cutoffs       int64 ...
#     coefficients  float64 ...
#     lev           float64 ...
#   * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
#   * lat           (lat) float64 20.0 20.75 21.5 22.25 ... 52.25 53.0 53.75 54.5

# %%
lh_total300
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
# array([[ -186.135488,  -138.428011,   -85.523218, ..., -2174.349796,
#         -2201.185067, -2225.057452],
#        [ -281.463668,  -236.154516,  -188.204281, ..., -2140.989548,
#         -2168.94825 , -2197.463274],
#        [ -380.304494,  -335.197386,  -288.137658, ..., -2097.201649,
#         -2123.731725, -2155.560345],
#        ...,
#        [  -20.025259,   -78.899159,  -139.751117, ...,   832.254165,
#           864.9837  ,   908.108394],
#        [    4.223408,   -60.319344,  -150.217427, ...,   798.598194,
#           841.165053,   880.425025],
#        [  -15.912411,   -97.16798 ,  -189.17722 , ...,   763.382904,
#           805.096533,   847.771525]])
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 300.0

# %%
masked_lh=xr.where((lh_total300<=0.5*lh_total300) & (lh_total300>=-0.5*lh_total300),np.nan,lh_total300) #if CI includes 0, then not significant. If CI doesn't then significant.
masked_lh
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
# array([[ -186.1354876 ,  -138.42801083,   -85.523218  , ...,
#         -2174.34979626, -2201.18506695, -2225.05745245],
#        [ -281.46366792,  -236.15451602,  -188.20428144, ...,
#         -2140.98954806, -2168.94824989, -2197.46327377],
#        [ -380.30449447,  -335.19738587,  -288.13765792, ...,
#         -2097.20164887, -2123.73172515, -2155.56034469],
#        ...,
#        [  -20.02525871,   -78.8991592 ,  -139.75111739, ...,
#           832.25416543,   864.98370045,   908.10839378],
#        [    4.22340793,   -60.31934379,  -150.21742744, ...,
#           798.59819438,   841.16505284,   880.42502466],
#        [  -15.91241053,   -97.16797969,  -189.17722016, ...,
#           763.38290353,   805.09653315,   847.77152515]])
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
# ...

# %%
ratio_dse_300=(dse_trans300/dse_total300)*100
ratio_lh_300=(lh300_trans/masked_lh)*100

# %%
fraction300=[ratio_dse_300,ratio_lh_300]
fraction300
# Out:
# [<xarray.DataArray '__xarray_dataarray_variable__' (lat: 19, lon: 19)>
#  array([[ 6.57279686e-01, -4.44817837e-02, -4.34117920e-03,
#           2.32409881e-02,  2.35296813e-02,  9.21190698e-03,
#           8.50609418e-03,  4.26830042e-03,  8.32069070e-03,
#           1.35746938e-02,  3.07946539e-03,  5.64532523e-03,
#           1.88264436e-02,  1.45726068e-01, -2.19049107e-02,
#          -1.23759939e-03,  4.05295186e-03,  5.47060394e-03,
#           1.50433986e-04],
#         [ 1.42494968e-02, -3.81629107e-01,  6.03316259e-02,
#           5.64364794e-02,  5.10512842e-02,  4.30500626e-02,
#           3.11446604e-02,  2.72576649e-02,  3.27216592e-02,
#           4.15492722e-02,  4.05256469e-02,  4.15720090e-02,
#           6.14878497e-02,  1.71477640e-01, -2.32911441e-01,
#          -1.56534594e-02, -1.31183084e-02, -8.32172089e-03,
#          -1.49503134e-02],
#         [-5.73658880e-02, -1.11612029e-01,  4.86983833e+01,
#           1.16542144e-01,  6.92463423e-02,  7.18222756e-02,
# ...

# %%
# Define the figure and each axis for the 2 rows and 2 columns
fig, axs = plt.subplots(nrows=2,ncols=1,
                        subplot_kw={'projection': ccrs.PlateCarree()},
                        figsize=(20,10))
titles=['Dry Static Energy flux', 'Latent Heat flux']
# axs is a 2 dimensional array of `GeoAxes`.  
# We will flatten it into a 1-D array
axs=axs.flatten()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())

#Loop over all of the seasons and plot
#for i in enumerate(climo_all):
for i in range(len(fraction300)):
        # Select the season
        data=fraction300[i]
        # Add the cyclic point
        data,lons=add_cyclic_point(data,coord=dse_trans300['lon'])
        max_val=100
        increment=5
        clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
        cs=axs[i].contourf(lons,dse_trans300['lat'],data,clevs,
                          transform = ccrs.PlateCarree(),
                          cmap='coolwarm',extend='both')
       # Longitude labels
        axs[i].set_xticks(np.arange(-180,181,60), crs=ccrs.PlateCarree())
        lon_formatter = cticker.LongitudeFormatter()
        axs[i].xaxis.set_major_formatter(lon_formatter)

        # Latitude labels
        axs[i].set_yticks(np.arange(-90,91,30), crs=ccrs.PlateCarree())
        lat_formatter = cticker.LatitudeFormatter()
        axs[i].yaxis.set_major_formatter(lat_formatter)

        # Title each subplot with the name of the season
        axs[i].set_title(titles[i])

        # Draw the coastines for each subplot
        axs[i].coastlines()
        axs[i].set_extent([-124.5,-66.8,23.486,49])
        axs[i].add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')
# Adjust the location of the subplots 
# on the page to make room for the colorbar
fig.subplots_adjust(bottom=0.25, top=0.9, left=0.05, right=0.95,
                    wspace=0.2, hspace=0.2)

# Add a colorbar axis at the bottom of the graph
#cbar_ax = fig.add_axes([0.2, 0.175, 0.6, 0.02])
cbar_ax = fig.add_axes([0.69, 0.2, 0.025, 0.7]) #left, bottom width, height
cbar = fig.colorbar(cs, cax = cbar_ax, orientation = 'vertical', label='Percentage (%)',pad = 0.05)
# Draw the colorbar
text = cbar_ax.yaxis.label
font = matplotlib.font_manager.FontProperties(family='times new roman', style='normal', size=16)
text.set_font_properties(font)
# Draw the colorbar
#cbar=fig.colorbar(cs, cax=cbar_ax,orientation='horizontal',label='percentage')
fig.tight_layout()
# Add a big title at the top
plt.suptitle('Fraction of Energy Transport Climatology by transients (300mb)',fontsize=15)
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/revisions/300mbratio_map.png')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:782: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   return super(GeoAxes, self).set_xticks(xticks, minor)
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:829: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   return super(GeoAxes, self).set_yticks(yticks, minor)
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:57: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
# ...

# %%
dse_zonal850=ratio_dse_850.mean(dim='lon')
lh_zonal850=ratio_lh_850.mean(dim='lon')

# %%
dse_zonal300=ratio_dse_300.mean(dim='lon')
lh_zonal300=ratio_lh_300.mean(dim='lon')

# %%
plt.figure(figsize=(10,10))
plt.title("Zonal mean CONUS Percentage of Transient Energy Flux climatology (850mb)",fontsize=15)
plt.plot(dse_zonal850,dse_zonal850['lat'],label='Dry Static Energy flux percentage',linewidth=4,color='red')
plt.xlabel('Percentage of northward transport',fontsize=15)
#plt.ylabel('Z (meters)',fontsize=15,rotation='90')
plt.gcf().text(-0.02,0.45, "Latitude (degrees North)", ha="center", va="center", rotation=90, fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.plot(lh_zonal850,lh_zonal850['lat'],label='Latent Heat flux percentage',linewidth=4,color='forestgreen')
plt.legend()
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/revisions/850mbtransportpercentage.png')

# %%
plt.figure(figsize=(10,10))
plt.title("Zonal mean CONUS Percentage of Transient Energy Flux climatology (850mb)",fontsize=15)
plt.plot(dse_zonal_new,dse_zonal_new['lat'],label='Dry static energy flux percentage',linewidth=4,color='red')
plt.xlabel('Percentage of northward transport',fontsize=15)
#plt.ylabel('Z (meters)',fontsize=15,rotation='90')
plt.gcf().text(-0.02,0.45, "Latitude (degrees North)", ha="center", va="center", rotation=90, fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.plot(lh_zonal_new,lh_zonal_new['lat'],label='Latent Heat flux percentage',linewidth=4,color='forestgreen')
plt.legend()
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/revisions/850mbtransportpercentage_newmethod.png')

# %%
plt.figure(figsize=(10,10))
plt.title("Zonal mean CONUS Percentage of Transient Energy Flux climatology (300mb)",fontsize=15)
plt.plot(dse_zonal300,dse_zonal300['lat'],label='Dry static energy flux percentage',linewidth=4,color='red')
plt.xlabel('Percentage of northward transport',fontsize=15)
#plt.ylabel('Z (meters)',fontsize=15,rotation='90')
plt.gcf().text(-0.02,0.45, "Latitude (degrees North)", ha="center", va="center", rotation=90, fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.plot(lh_zonal300,lh_zonal300['lat'],label='Latent Heat flux percentage',linewidth=4,color='forestgreen')
plt.legend()
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/300mbtransportpercentage.png')

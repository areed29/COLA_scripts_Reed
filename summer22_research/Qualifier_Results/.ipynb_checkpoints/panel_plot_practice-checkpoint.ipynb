# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
#from intake import open_catalog
import cartopy.io.shapereader as shpreader
import mygrads as mg
#import Ngl
#import Nio
#import fiona
import matplotlib as mpl
import cartopy.mpl.ticker as cticker
from cartopy.util import add_cyclic_point
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from cartopy.feature import NaturalEarthFeature
from cartopy.feature import COASTLINE
#from clim680_function import xyticks
import pymannkendall as mk
import pandas as pd
import time
import matplotlib.image as mpimg
stime=time.time()

# %%
#load in wind climatology for contours

# %%
f='/project/xprecip/merra2_ncfiles/winds/vwind_850_computed_4-14-23.nc'
DS_winds_850=xr.open_dataset(f)
#DS_winds_850
winter_selected_meridwind_850=DS_winds_850['V']
winter_selected_meridwind_850
# Out:
# <xarray.DataArray 'V' (time: 15400, lat: 55, lon: 113)>
# [95711000 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2022-02-28T18:00:00
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 ...
# Attributes:
#     standard_name:   northward_wind
#     long_name:       Northward wind component
#     units:           m/s
#     fmissing_value:  1000000000000000.0
#     vmax:            1000000000000000.0
#     vmin:            -1000000000000000.0

# %%
vclimo850=winter_selected_meridwind_850.mean(dim='time')
vclimo850
# Out:
# <xarray.DataArray 'V' (lat: 55, lon: 113)>
# array([[-2.2709541 , -2.36838   , -2.4584134 , ...,  0.50762856,
#          0.46681783,  0.43298322],
#        [-2.3635316 , -2.4691207 , -2.566633  , ...,  0.5938745 ,
#          0.5480109 ,  0.5120406 ],
#        [-2.451161  , -2.5641503 , -2.6700354 , ...,  0.68229043,
#          0.6365874 ,  0.5980475 ],
#        ...,
#        [ 4.990153  ,  4.5417686 ,  4.5846643 , ...,  0.5667625 ,
#         -0.10074187, -0.2288651 ],
#        [ 4.843831  ,  3.6429648 ,  1.4123408 , ...,  0.37715444,
#          0.06506082, -0.41620177],
#        [ 1.3643906 ,  0.01985777,  1.0794904 , ..., -0.44385362,
#         -0.40662727, -0.44259277]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 850.0

# %%
f='/project/xprecip/merra2_ncfiles/winds/vwinds_preslevs_4-23/850/high_pass/850winds_highpass_0.75deg.nc'
DS=xr.open_dataset(f)
hp_850winds=DS['__xarray_dataarray_variable__']
hp_850winds
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (time: 12917, lat: 47, lon: 100)>
# [60709900 values with dtype=float64]
# Coordinates:
#     cutoffs       int64 ...
#     coefficients  float64 ...
#     lev           float64 ...
#   * lat           (lat) float64 20.0 20.75 21.5 22.25 ... 52.25 53.0 53.75 54.5
#   * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
#   * time          (time) datetime64[ns] 1980-12-01 ... 2022-02-20T12:00:00

# %%
vclimo_transients850=hp_850winds.mean(dim='time')
vclimo_transients850
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
# array([[-0.00178716,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.00173086, -0.00124219, -0.00099764, ..., -0.00157464,
#         -0.0013698 , -0.00087926],
#        [-0.00184101, -0.00132082, -0.0012241 , ..., -0.00218668,
#         -0.00168021, -0.00079336],
#        ...,
#        [-0.01013383, -0.04674732, -0.00140468, ..., -0.02010305,
#         -0.01942506, -0.018044  ],
#        [-0.00088488, -0.00196855, -0.0024768 , ..., -0.01956684,
#         -0.01848001, -0.01685298],
#        [-0.00166095, -0.00313089, -0.00385002, ..., -0.01912815,
#         -0.01784136, -0.01607739]])
# Coordinates:
#     cutoffs       int64 10
#     coefficients  float64 -15.0
#     lev           float64 850.0
#   * lat           (lat) float64 20.0 20.75 21.5 22.25 ... 52.25 53.0 53.75 54.5
#   * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75

# %%
f='/project/xprecip/merra2_ncfiles/winds/vwinds_preslevs_4-23/300/vwinds_300_winter.nc'
DS=xr.open_dataset(f)
vwinds300=DS['V']
vwinds300
# Out:
# <xarray.DataArray 'V' (time: 14936, lat: 361, lon: 576)>
# [3105732096 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2023-02-28T18:00:00
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 -88.0 ... 88.5 89.0 89.5 90.0
#     lev      float64 ...
# Attributes:
#     standard_name:   northward_wind
#     long_name:       Northward wind component
#     units:           m/s
#     fmissing_value:  1000000000000000.0
#     vmax:            1000000000000000.0
#     vmin:            -1000000000000000.0

# %%
vclimo300=vwinds300.mean(dim='time')
vclimo300
# Out:
# <xarray.DataArray 'V' (lat: 361, lon: 576)>
# array([[-0.48178005, -0.48270354, -0.4835694 , ..., -0.4786679 ,
#         -0.47976536, -0.48080215],
#        [-0.5804326 , -0.58601826, -0.5915887 , ..., -0.56360936,
#         -0.5692284 , -0.57483494],
#        [-0.91950035, -0.9317404 , -0.943984  , ..., -0.8827772 ,
#         -0.895012  , -0.90725565],
#        ...,
#        [-0.7984807 , -0.82313913, -0.8478492 , ..., -0.7248069 ,
#         -0.7493142 , -0.7738717 ],
#        [-0.7688032 , -0.7866811 , -0.80457306, ..., -0.7152543 ,
#         -0.7330874 , -0.75093716],
#        [-0.80356956, -0.8140344 , -0.82440126, ..., -0.77160287,
#         -0.7823509 , -0.7930076 ]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 -88.0 ... 88.5 89.0 89.5 90.0
#     lev      float64 300.0

# %%
f='/project/xprecip/merra2_ncfiles/winds/vwinds_preslevs_4-23/300/high_pass/hpfilter_vwind_0.75.nc'
DS=xr.open_dataset(f)
hp_300winds=DS['__xarray_dataarray_variable__']
hp_300winds
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (time: 12917, lat: 47, lon: 100)>
# [60709900 values with dtype=float64]
# Coordinates:
#     cutoffs       int64 ...
#     lev           float64 ...
#     coefficients  float64 ...
#   * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
#   * lat           (lat) float64 20.0 20.75 21.5 22.25 ... 52.25 53.0 53.75 54.5
#   * time          (time) datetime64[ns] 1980-12-01 ... 2022-02-20T12:00:00

# %%
vclimo300_transients=hp_300winds.mean(dim='time')
vclimo300_transients
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
# array([[-0.0057248 ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.00638233, -0.00735323, -0.00688807, ...,  0.00795863,
#          0.00594473,  0.00368436],
#        [-0.00718644, -0.00692469, -0.00561473, ...,  0.00790732,
#          0.00635887,  0.00440469],
#        ...,
#        [-0.00962439, -0.00428256,  0.0002626 , ..., -0.02418732,
#         -0.02217451, -0.01835755],
#        [-0.00664636, -0.00231346,  0.00126911, ..., -0.02121801,
#         -0.01906579, -0.01563339],
#        [-0.00288979,  0.00044918,  0.00304772, ..., -0.01845274,
#         -0.01606257, -0.01289857]])
# Coordinates:
#     cutoffs       int64 10
#     lev           float64 300.0
#     coefficients  float64 -15.0
#   * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
#   * lat           (lat) float64 20.0 20.75 21.5 22.25 ... 52.25 53.0 53.75 54.5

# %%
### Loading several files
f='/project/xprecip/merra2_ncfiles/energy_calcs/shtotal_climo.nc'
DS_sh_climo=xr.open_dataset(f)
sh_climo=DS_sh_climo['__xarray_dataarray_variable__']
sh_climo
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
# array([[-644161.2   , -672322.75  , -698401.    , ...,  148575.08  ,
#          136801.78  ,  127034.61  ],
#        [-670036.5   , -700519.    , -728724.06  , ...,  173541.4   ,
#          160320.    ,  149927.83  ],
#        [-694442.3   , -727038.    , -757629.2   , ...,  199117.86  ,
#          185936.61  ,  174819.81  ],
#        ...,
#        [1367595.    , 1242338.8   , 1252119.2   , ...,  171388.84  ,
#           -3572.7405,  -37316.438 ],
#        [1322879.4   ,  995666.44  ,  388150.22  , ...,  117491.75  ,
#           37713.77  ,  -87573.31  ],
#        [ 375433.9   ,    8213.18  ,  295107.06  , ..., -101956.52  ,
#          -92001.67  ,  -99265.04  ]], dtype=float32)
# Coordinates:
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#     lev      float64 ...

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/sh_diff_total.nc'
DS_sh_diff=xr.open_dataset(f)
sh_diff=DS_sh_diff['__xarray_dataarray_variable__']
sh_diff
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
# array([[ -91628.69   ,  -82945.56   ,  -72631.06   , ...,  -96627.73   ,
#          -99647.81   , -103117.91   ],
#        [ -97488.875  ,  -86557.     ,  -75181.75   , ...,  -98108.086  ,
#          -99689.055  ,  -99644.58   ],
#        [-102873.06   ,  -92614.375  ,  -81494.75   , ...,  -97833.625  ,
#          -99603.03   ,  -96863.54   ],
#        ...,
#        [-110800.375  , -106893.75   ,  -94928.75   , ...,  -80927.03   ,
#          -78493.05   ,  -74267.91   ],
#        [ -94316.375  ,  -69614.31   ,  -23619.812  , ...,  -95025.69   ,
#          -83241.33   ,  -72827.87   ],
#        [   -703.40625,  118979.17   , -139166.81   , ..., -127106.59   ,
#         -108031.77   ,  -86729.59   ]], dtype=float32)
# Coordinates:
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
# ...

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/lh_climo_total.nc'
DS_lh_climo=xr.open_dataset(f)
lh_climo=DS_lh_climo['__xarray_dataarray_variable__']
lh_climo
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
# array([[-11906.346289, -12113.189823, -12232.613373, ...,  12077.542887,
#          11357.01015 ,  10812.417731],
#        [-12332.717125, -12561.283953, -12750.711013, ...,  13606.588722,
#          12830.023479,  12258.331168],
#        [-12772.74081 , -13021.603233, -13246.492146, ...,  15246.172108,
#          14435.421616,  13808.696287],
#        ...,
#        [ 45957.097314,  41527.949358,  41268.475203, ...,  13041.693585,
#          10385.093785,  10106.027244],
#        [ 43584.492942,  31844.890311,  12607.058482, ...,  10740.604399,
#           9999.420985,   8506.994754],
#        [ 12397.198808,   1372.50106 ,   4329.878151, ...,   6727.120578,
#           6835.327947,   6942.293048]])
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 ...

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/lh_diff_total.nc'
DS_lh_diff=xr.open_dataset(f)
lh_diff=DS_lh_diff['__xarray_dataarray_variable__']
lh_diff
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
# array([[-2258.087174, -1710.885545, -1030.870525, ..., -6272.088508,
#         -6213.651275, -6251.216096],
#        [-2600.849821, -1927.386888, -1208.953378, ..., -6409.350079,
#         -6242.8227  , -6080.294359],
#        [-3015.798112, -2270.020782, -1457.113257, ..., -6283.702761,
#         -6214.672942, -5834.291123],
#        ...,
#        [-2867.827859, -2971.050988, -2887.806043, ..., -1396.226984,
#         -1518.191346, -1463.213731],
#        [-2259.132536, -1928.037158, -1171.456587, ..., -1590.268646,
#         -1467.295015, -1467.774976],
#        [ -309.700472,  2558.921889, -1254.02235 , ..., -2211.888069,
#         -2019.050884, -1716.8169  ]])
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 ...

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/geofluxtotal_mean_850.nc'
DS_geoflux_climo=xr.open_dataset(f)
geo_climo=DS_geoflux_climo['__xarray_dataarray_variable__']
geo_climo
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
# array([[-3512.0146  , -3659.078   , -3794.3726  , ...,   791.53644 ,
#           728.00165 ,   675.17285 ],
#        [-3657.9453  , -3817.2576  , -3963.7397  , ...,   926.10205 ,
#           854.7733  ,   798.7281  ],
#        [-3796.323   , -3966.8574  , -4125.9097  , ...,  1064.1295  ,
#           993.1187  ,   933.0575  ],
#        ...,
#        [ 6873.7773  ,  6288.4414  ,  6403.5195  , ...,   738.33624 ,
#          -101.75662 ,  -245.45753 ],
#        [ 6763.352   ,  5106.892   ,  2048.6226  , ...,   514.48157 ,
#           114.425064,  -500.405   ],
#        [ 1969.2836  ,    32.71514 ,  1757.6769  , ...,  -494.65378 ,
#          -448.41766 ,  -505.2712  ]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 ...

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/geo_diff_total.nc'
DS_geoflux_diff=xr.open_dataset(f)
geoflux_diff=DS_geoflux_diff['__xarray_dataarray_variable__']
geoflux_diff
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
# array([[-484.87524 , -438.23584 , -382.8015  , ..., -532.99255 , -549.19867 ,
#         -567.4573  ],
#        [-516.2605  , -457.96265 , -396.70972 , ..., -541.98444 , -550.78076 ,
#         -550.304   ],
#        [-544.81177 , -490.31128 , -430.44678 , ..., -541.45294 , -551.63293 ,
#         -536.9053  ],
#        ...,
#        [-528.49316 , -509.79883 , -447.78467 , ..., -384.60815 , -379.14453 ,
#         -361.63367 ],
#        [-447.87842 , -316.38135 ,  -99.75549 , ..., -448.99704 , -395.74493 ,
#         -347.76117 ],
#        [  16.006836,  692.5259  , -842.1719  , ..., -600.02216 , -511.05655 ,
#         -412.6239  ]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 ...

# %%
climo_all=[sh_climo,lh_climo,geo_climo]
climo_all
# Out:
# [<xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
#  array([[-644161.2   , -672322.75  , -698401.    , ...,  148575.08  ,
#           136801.78  ,  127034.61  ],
#         [-670036.5   , -700519.    , -728724.06  , ...,  173541.4   ,
#           160320.    ,  149927.83  ],
#         [-694442.3   , -727038.    , -757629.2   , ...,  199117.86  ,
#           185936.61  ,  174819.81  ],
#         ...,
#         [1367595.    , 1242338.8   , 1252119.2   , ...,  171388.84  ,
#            -3572.7405,  -37316.438 ],
#         [1322879.4   ,  995666.44  ,  388150.22  , ...,  117491.75  ,
#            37713.77  ,  -87573.31  ],
#         [ 375433.9   ,    8213.18  ,  295107.06  , ..., -101956.52  ,
#           -92001.67  ,  -99265.04  ]], dtype=float32)
#  Coordinates:
#    * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#    * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#      lev      float64 850.0,
# ...

# %%
diff_all=[sh_diff,lh_diff,geoflux_diff]
diff_all
# Out:
# [<xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
#  array([[ -91628.69   ,  -82945.56   ,  -72631.06   , ...,  -96627.73   ,
#           -99647.81   , -103117.91   ],
#         [ -97488.875  ,  -86557.     ,  -75181.75   , ...,  -98108.086  ,
#           -99689.055  ,  -99644.58   ],
#         [-102873.06   ,  -92614.375  ,  -81494.75   , ...,  -97833.625  ,
#           -99603.03   ,  -96863.54   ],
#         ...,
#         [-110800.375  , -106893.75   ,  -94928.75   , ...,  -80927.03   ,
#           -78493.05   ,  -74267.91   ],
#         [ -94316.375  ,  -69614.31   ,  -23619.812  , ...,  -95025.69   ,
#           -83241.33   ,  -72827.87   ],
#         [   -703.40625,  118979.17   , -139166.81   , ..., -127106.59   ,
#          -108031.77   ,  -86729.59   ]], dtype=float32)
#  Coordinates:
#    * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#    * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
# ...

# %%
import matplotlib.colors as colors
from matplotlib import ticker, cm

# %%
# Define the figure and each axis for the 2 rows and 2 columns
fig, axs = plt.subplots(nrows=3,ncols=1,
                        subplot_kw={'projection': ccrs.PlateCarree()},
                        figsize=(20,10))
titles=['Sensible Heat Transport', 'Latent Heat transport', 'Geopotential flux transport']
# axs is a 2 dimensional array of `GeoAxes`.  
# We will flatten it into a 1-D array
axs=axs.flatten()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())

#Loop over all of the seasons and plot
#for i in enumerate(climo_all):
for i in range(len(climo_all)):
        # Select the season
        data=climo_all[i]
        # Add the cyclic point
        data,lons=add_cyclic_point(data,coord=sh_climo['lon'])
        max_val=100000
        increment=25000
        clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
        # Contour plot
        #norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03,
        #                                      vmin=-1600000, vmax=1600000, base=10)
        clevs2=np.arange(-6,7,1)
        cs=axs[i].contourf(lons,sh_climo['lat'],data,clevs,
                          transform = ccrs.PlateCarree(),
                          cmap='coolwarm',extend='both')
        axs[i].contour(vclimo850['lon'],vclimo850['lat'],vclimo850,clevs2,transform=ccrs.PlateCarree(),linewidths=1,colors='k')
       # Longitude labels
        axs[i].set_xticks(np.arange(-180,181,60), crs=ccrs.PlateCarree())
        lon_formatter = cticker.LongitudeFormatter()
        axs[i].xaxis.set_major_formatter(lon_formatter)

        # Latitude labels
        axs[i].set_yticks(np.arange(-90,91,30), crs=ccrs.PlateCarree())
        lat_formatter = cticker.LatitudeFormatter()
        axs[i].yaxis.set_major_formatter(lat_formatter)

        # Title each subplot with the name of the season
        axs[i].set_title(titles[i])

        # Draw the coastines for each subplot
        axs[i].coastlines()
        axs[i].set_extent([-124.5,-66.8,23.486,49])
        axs[i].add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')
# Adjust the location of the subplots 
# on the page to make room for the colorbar
fig.subplots_adjust(bottom=0.25, top=0.9, left=0.05, right=0.95,
                    wspace=0.2, hspace=0.2)

# Add a colorbar axis at the bottom of the graph
cbar_ax = fig.add_axes([0.2, 0.175, 0.6, 0.02])

# Draw the colorbar
cbar=fig.colorbar(cs, cax=cbar_ax,orientation='horizontal',label='m^3/s^3')
fig.tight_layout()
# Add a big title at the top
plt.suptitle('Total Energy Transport Climatology (850mb)',fontsize=15)
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/850mbtotalall.png')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:782: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   return super(GeoAxes, self).set_xticks(xticks, minor)
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:829: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   return super(GeoAxes, self).set_yticks(yticks, minor)
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:57: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
# ...

# %%
#Difference plots

# %%
# Define the figure and each axis for the 2 rows and 2 columns
fig, axs = plt.subplots(nrows=3,ncols=1,
                        subplot_kw={'projection': ccrs.PlateCarree()},
                        figsize=(20,10))
titles=['Sensible Heat Transport', 'Latent Heat transport', 'Geopotential flux transport']
# axs is a 2 dimensional array of `GeoAxes`.  
# We will flatten it into a 1-D array
axs=axs.flatten()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())

#Loop over all of the seasons and plot
#for i in enumerate(climo_all):
for i in range(len(diff_all)):
        # Select the season
        data=diff_all[i]
        # Add the cyclic point
        data,lons=add_cyclic_point(data,coord=sh_climo['lon'])
        #max_val=100000
        #increment=25000
        #clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
        # Contour plot
        #norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03,
        #                                      vmin=-1600000, vmax=1600000, base=10)
        cs=axs[i].contourf(lons,sh_climo['lat'],data,clevs,
                          transform = ccrs.PlateCarree(),
                          cmap='BrBG',extend='both')
       # Longitude labels
        axs[i].set_xticks(np.arange(-180,181,60), crs=ccrs.PlateCarree())
        lon_formatter = cticker.LongitudeFormatter()
        axs[i].xaxis.set_major_formatter(lon_formatter)

        # Latitude labels
        axs[i].set_yticks(np.arange(-90,91,30), crs=ccrs.PlateCarree())
        lat_formatter = cticker.LatitudeFormatter()
        axs[i].yaxis.set_major_formatter(lat_formatter)

        # Title each subplot with the name of the season
        axs[i].set_title(titles[i])

        # Draw the coastines for each subplot
        axs[i].coastlines()
        axs[i].set_extent([-124.5,-66.8,23.486,49])
        axs[i].add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')
# Adjust the location of the subplots 
# on the page to make room for the colorbar
fig.subplots_adjust(bottom=0.25, top=0.9, left=0.05, right=0.95,
                    wspace=0.2, hspace=0.2)

# Add a colorbar axis at the bottom of the graph
cbar_ax = fig.add_axes([0.2, 0.175, 0.6, 0.02])

# Draw the colorbar
cbar=fig.colorbar(cs, cax=cbar_ax,orientation='horizontal',label='difference (m^3/s^3)')
fig.tight_layout()
# Add a big title at the top
plt.suptitle('Total Energy Transport Late-Early Climatology Difference (850mb)',fontsize=15)
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/850mbtotalall_diff.png')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:55: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:55: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.

# %% [markdown]
# ### Panel Plots for Transients

# %%
### Loading several files
f='/project/xprecip/merra2_ncfiles/energy_calcs/shtransients_climo850.nc'
DS_sh_climo=xr.open_dataset(f)
sh_climo_transients=DS_sh_climo['__xarray_dataarray_variable__']
sh_climo_transients
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
# array([[  34.417425,    0.      ,    0.      , ...,    0.      ,    0.      ,
#            0.      ],
#        [  44.653539,   51.505404,   53.179916, ...,   84.435667,   84.563996,
#           83.084241],
#        [  72.365538,   82.722305,   84.398032, ...,   96.383231,   97.712106,
#           99.988029],
#        ...,
#        [2437.89971 , 2412.806013, 2896.935191, ..., 7655.574002, 7797.23462 ,
#         7851.544429],
#        [3303.450197, 3595.206059, 3673.223382, ..., 6503.213118, 6553.532904,
#         6575.382179],
#        [2986.604044, 3135.917177, 2999.108968, ..., 5279.066799, 5314.458544,
#         5376.87186 ]])
# Coordinates:
#   * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
#   * lat           (lat) float64 20.0 20.75 21.5 22.25 ... 52.25 53.0 53.75 54.5
#     lev           float64 ...
#     cutoffs       int64 ...
#     coefficients  float64 ...

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/sh_diff_transients850.nc'
DS_sh_diff=xr.open_dataset(f)
sh_diff_transients=DS_sh_diff['__xarray_dataarray_variable__']
sh_diff_transients
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
# array([[    9.923135,     0.      ,     0.      , ...,     0.      ,
#             0.      ,     0.      ],
#        [   36.914119,    23.575731,    33.803046, ...,   -25.481233,
#           -30.215441,   -32.970145],
#        [   80.197154,    68.586189,    75.690656, ...,   -37.659237,
#           -34.989456,   -41.525572],
#        ...,
#        [ 1318.359787,  1317.816618,   857.980327, ...,  -491.717451,
#          -570.125171,  -652.329884],
#        [  621.700793,   671.551544,   635.278038, ...,  -766.239786,
#          -789.926975,  -743.170576],
#        [  511.835792,   582.075688,   537.669408, ..., -1000.431747,
#          -943.526583,  -835.137174]])
# Coordinates:
#   * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
#   * lat           (lat) float64 20.0 20.75 21.5 22.25 ... 52.25 53.0 53.75 54.5
#     lev           float64 ...
#     cutoffs       int64 ...
# ...

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/lhtransients_climo850.nc'
DS_lh_climo=xr.open_dataset(f)
lh_climo_transients=DS_lh_climo['__xarray_dataarray_variable__']
lh_climo_transients
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
# array([[ 3.418889e+02,  0.000000e+00,  0.000000e+00, ...,  0.000000e+00,
#          0.000000e+00,  0.000000e+00],
#        [ 3.920953e+02,  3.215794e+02,  2.970231e+02, ...,  4.360611e+02,
#          4.109211e+02,  3.505553e+02],
#        [ 3.471532e+02,  2.951376e+02,  2.625973e+02, ...,  4.398623e+02,
#          4.222973e+02,  3.796048e+02],
#        ...,
#        [-3.480678e+02,  3.761622e+00,  4.868593e+02, ...,  3.747272e+03,
#          3.857452e+03,  3.936323e+03],
#        [ 7.998782e+02,  8.023687e+02,  1.027949e+03, ...,  3.005098e+03,
#          3.106265e+03,  3.214582e+03],
#        [ 1.129775e+03,  1.214797e+03,  1.286837e+03, ...,  2.309172e+03,
#          2.455445e+03,  2.634120e+03]])
# Coordinates:
#     cutoffs       int64 ...
#     coefficients  float64 ...
#     lev           float64 ...
#   * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
# ...

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/lh_diff_transients850.nc'
DS_lh_diff=xr.open_dataset(f)
lh_diff_transients=DS_lh_diff['__xarray_dataarray_variable__']
lh_diff_transients
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
# array([[ 176.629839,    0.      ,    0.      , ...,    0.      ,    0.      ,
#            0.      ],
#        [ 225.082378,  185.239481,  120.324177, ...,  217.095745,  247.381597,
#          266.322348],
#        [  13.302086,  100.047339,  111.740281, ...,  185.184   ,  199.139492,
#          272.229781],
#        ...,
#        [ 412.473881,  327.482642,  113.832161, ..., -279.148221, -265.313428,
#         -164.477688],
#        [ 188.486014,  185.100606,  191.903978, ..., -361.504603, -337.227305,
#         -233.50573 ],
#        [ 284.704004,  314.432429,  306.033321, ..., -479.576984, -474.920646,
#         -376.36815 ]])
# Coordinates:
#     cutoffs       int64 ...
#     coefficients  float64 ...
#     lev           float64 ...
#   * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
#   * lat           (lat) float64 20.0 20.75 21.5 22.25 ... 52.25 53.0 53.75 54.5

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/geofluxtransients_climo850.nc'
DS_geoflux_climo=xr.open_dataset(f)
geofluxclimo_850=DS_geoflux_climo['__xarray_dataarray_variable__']
geofluxclimo_850
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
# array([[ 0.028757,  0.      ,  0.      , ...,  0.      ,  0.      ,  0.      ],
#        [ 0.02735 ,  0.027718,  0.027155, ..., -0.010242, -0.010817, -0.011793],
#        [ 0.026675,  0.027137,  0.027209, ..., -0.009406, -0.010258, -0.011222],
#        ...,
#        [ 0.024069,  0.023218,  0.019131, ..., -0.083083, -0.087211, -0.090463],
#        [ 0.025685,  0.023508,  0.021173, ..., -0.086739, -0.089678, -0.091559],
#        [ 0.028122,  0.025295,  0.022337, ..., -0.088471, -0.09046 , -0.091083]])
# Coordinates:
#     cutoffs       int64 ...
#     coefficients  float64 ...
#   * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
#     lev           float64 ...
#   * lat           (lat) float64 20.0 20.75 21.5 22.25 ... 52.25 53.0 53.75 54.5

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/geofluxtransients_diff850.nc'
DS_geoflux_diff=xr.open_dataset(f)
geoflux_diff_transients=DS_geoflux_diff['__xarray_dataarray_variable__']
geoflux_diff_transients
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
# array([[-0.028821,  0.      ,  0.      , ...,  0.      ,  0.      ,  0.      ],
#        [-0.026756, -0.02523 , -0.023223, ...,  0.0078  ,  0.007022,  0.006725],
#        [-0.026697, -0.026115, -0.025516, ...,  0.008845,  0.007804,  0.007426],
#        ...,
#        [ 0.004456, -0.005582, -0.013344, ...,  0.125639,  0.126606,  0.126955],
#        [-0.009733, -0.013744, -0.018697, ...,  0.08293 ,  0.080065,  0.077393],
#        [-0.019265, -0.020291, -0.021967, ...,  0.045774,  0.039265,  0.033483]])
# Coordinates:
#     cutoffs       int64 ...
#     coefficients  float64 ...
#   * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
#     lev           float64 ...
#   * lat           (lat) float64 20.0 20.75 21.5 22.25 ... 52.25 53.0 53.75 54.5

# %%
climo_all_trans=[sh_climo_transients,lh_climo_transients,geofluxclimo_850]
climo_all_trans
# Out:
# [<xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
#  array([[  34.417425,    0.      ,    0.      , ...,    0.      ,    0.      ,
#             0.      ],
#         [  44.653539,   51.505404,   53.179916, ...,   84.435667,   84.563996,
#            83.084241],
#         [  72.365538,   82.722305,   84.398032, ...,   96.383231,   97.712106,
#            99.988029],
#         ...,
#         [2437.89971 , 2412.806013, 2896.935191, ..., 7655.574002, 7797.23462 ,
#          7851.544429],
#         [3303.450197, 3595.206059, 3673.223382, ..., 6503.213118, 6553.532904,
#          6575.382179],
#         [2986.604044, 3135.917177, 2999.108968, ..., 5279.066799, 5314.458544,
#          5376.87186 ]])
#  Coordinates:
#    * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
#    * lat           (lat) float64 20.0 20.75 21.5 22.25 ... 52.25 53.0 53.75 54.5
#      lev           float64 850.0
#      cutoffs       int64 10
# ...

# %%
# Define the figure and each axis for the 2 rows and 2 columns
fig, axs = plt.subplots(nrows=3,ncols=1,
                        subplot_kw={'projection': ccrs.PlateCarree()},
                        figsize=(20,10))
titles=['Sensible Heat Transport', 'Latent Heat transport','Geopotential flux transport']
# axs is a 2 dimensional array of `GeoAxes`.  
# We will flatten it into a 1-D array
axs=axs.flatten()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())

#Loop over all of the seasons and plot
#for i in enumerate(climo_all):
for i in range(len(climo_all)):
        # Select the season
        data=climo_all[i]
        # Add the cyclic point
        data,lons=add_cyclic_point(data,coord=sh_climo_transients['lon'])
        max_val=18000
        increment=3000
        clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
        clevs2=np.arange(-6,7,1)
        # Contour plot
        #norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03,
        #                                      vmin=-1600000, vmax=1600000, base=10)
        cs=axs[i].contourf(lons,sh_climo_transients['lat'],data,clevs,
                          transform = ccrs.PlateCarree(),
                          cmap='coolwarm',extend='both')
        axs[i].contour(vclimo_transients850['lon'],vclimo_transients850['lat'],vclimo_transients850,clevs2,transform=ccrs.PlateCarree(),linewidths=1,colors='k')
       # Longitude labels
        axs[i].set_xticks(np.arange(-180,181,60), crs=ccrs.PlateCarree())
        lon_formatter = cticker.LongitudeFormatter()
        axs[i].xaxis.set_major_formatter(lon_formatter)

        # Latitude labels
        axs[i].set_yticks(np.arange(-90,91,30), crs=ccrs.PlateCarree())
        lat_formatter = cticker.LatitudeFormatter()
        axs[i].yaxis.set_major_formatter(lat_formatter)

        # Title each subplot with the name of the season
        axs[i].set_title(titles[i])

        # Draw the coastines for each subplot
        axs[i].coastlines()
        axs[i].set_extent([-124.5,-66.8,23.486,49])
        axs[i].add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')
# Adjust the location of the subplots 
# on the page to make room for the colorbar
fig.subplots_adjust(bottom=0.25, top=0.9, left=0.05, right=0.95,
                    wspace=0.2, hspace=0.2)

# Add a colorbar axis at the bottom of the graph
cbar_ax = fig.add_axes([0.2, 0.175, 0.6, 0.02])

# Draw the colorbar
cbar=fig.colorbar(cs, cax=cbar_ax,orientation='horizontal',label='m^3/s^3')
fig.tight_layout()
# Add a big title at the top
plt.suptitle('Transient Energy Transport Climatology (850mb)',fontsize=15)
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/850mbtransientsall.png')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:57: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:57: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.

# %%
diff_all=[sh_diff_transients,lh_diff_transients,geoflux_diff_transients]
diff_all
# Out:
# [<xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
#  array([[    9.923135,     0.      ,     0.      , ...,     0.      ,
#              0.      ,     0.      ],
#         [   36.914119,    23.575731,    33.803046, ...,   -25.481233,
#            -30.215441,   -32.970145],
#         [   80.197154,    68.586189,    75.690656, ...,   -37.659237,
#            -34.989456,   -41.525572],
#         ...,
#         [ 1318.359787,  1317.816618,   857.980327, ...,  -491.717451,
#           -570.125171,  -652.329884],
#         [  621.700793,   671.551544,   635.278038, ...,  -766.239786,
#           -789.926975,  -743.170576],
#         [  511.835792,   582.075688,   537.669408, ..., -1000.431747,
#           -943.526583,  -835.137174]])
#  Coordinates:
#    * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
#    * lat           (lat) float64 20.0 20.75 21.5 22.25 ... 52.25 53.0 53.75 54.5
#      lev           float64 850.0
# ...

# %%
# Define the figure and each axis for the 2 rows and 2 columns
fig, axs = plt.subplots(nrows=3,ncols=1,
                        subplot_kw={'projection': ccrs.PlateCarree()},
                        figsize=(20,10))
titles=['Sensible Heat Transport', 'Latent Heat transport','Geopotential flux transport']
# axs is a 2 dimensional array of `GeoAxes`.  
# We will flatten it into a 1-D array
axs=axs.flatten()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())

#Loop over all of the seasons and plot
#for i in enumerate(climo_all):
for i in range(len(diff_all)):
        # Select the season
        data=diff_all[i]
        # Add the cyclic point
        data,lons=add_cyclic_point(data,coord=sh_climo_transients['lon'])
        max_val=4000
        increment=500
        clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
        # Contour plot
        #norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03,
        #                                      vmin=-1600000, vmax=1600000, base=10)
        cs=axs[i].contourf(lons,sh_climo_transients['lat'],data,clevs,
                          transform = ccrs.PlateCarree(),
                          cmap='BrBG',extend='both')
       # Longitude labels
        axs[i].set_xticks(np.arange(-180,181,60), crs=ccrs.PlateCarree())
        lon_formatter = cticker.LongitudeFormatter()
        axs[i].xaxis.set_major_formatter(lon_formatter)

        # Latitude labels
        axs[i].set_yticks(np.arange(-90,91,30), crs=ccrs.PlateCarree())
        lat_formatter = cticker.LatitudeFormatter()
        axs[i].yaxis.set_major_formatter(lat_formatter)

        # Title each subplot with the name of the season
        axs[i].set_title(titles[i])

        # Draw the coastines for each subplot
        axs[i].coastlines()
        axs[i].set_extent([-124.5,-66.8,23.486,49])
        axs[i].add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')
# Adjust the location of the subplots 
# on the page to make room for the colorbar
fig.subplots_adjust(bottom=0.25, top=0.9, left=0.05, right=0.95,
                    wspace=0.2, hspace=0.2)

# Add a colorbar axis at the bottom of the graph
cbar_ax = fig.add_axes([0.2, 0.175, 0.6, 0.02])

# Draw the colorbar
cbar=fig.colorbar(cs, cax=cbar_ax,orientation='horizontal',label='difference (m^3/s^3)')
fig.tight_layout()
# Add a big title at the top
plt.suptitle('Transient Energy Transport Late-Early Climatology Difference (850mb)',fontsize=15)
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/850mbtransientsall_diff.png')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:55: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:55: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.

# %% [markdown]
# ### 300mb total

# %%
### Loading several files
f='/project/xprecip/merra2_ncfiles/energy_calcs/shtotal_climo300.nc'
DS_sh_climo=xr.open_dataset(f)
sh_climo300=DS_sh_climo['__xarray_dataarray_variable__']
sh_climo300
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
# array([[-1.091989e+05, -8.104518e+04, -4.987407e+04, ..., -1.385097e+06,
#         -1.409684e+06, -1.435050e+06],
#        [-1.682123e+05, -1.406678e+05, -1.115521e+05, ..., -1.340146e+06,
#         -1.366448e+06, -1.393760e+06],
#        [-2.321249e+05, -2.041049e+05, -1.749302e+05, ..., -1.291097e+06,
#         -1.318690e+06, -1.347284e+06],
#        ...,
#        [-3.182575e+04, -1.155819e+05, -2.044600e+05, ...,  1.816562e+06,
#          1.871879e+06,  1.926275e+06],
#        [ 9.228025e+02, -9.467397e+04, -2.330118e+05, ...,  1.796396e+06,
#          1.870153e+06,  1.929655e+06],
#        [-2.877125e+04, -1.547170e+05, -2.980977e+05, ...,  1.777279e+06,
#          1.850911e+06,  1.920553e+06]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
# ...

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/lhtotal_climo300.nc'
DS_lh_climo=xr.open_dataset(f)
lh_climo300=DS_lh_climo['__xarray_dataarray_variable__']
lh_climo300
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
# array([[ 1.324263e+03,  1.364478e+03,  1.428792e+03, ..., -1.697763e+03,
#         -1.734670e+03, -1.770999e+03],
#        [ 1.168357e+03,  1.207972e+03,  1.261071e+03, ..., -1.635807e+03,
#         -1.672989e+03, -1.705508e+03],
#        [ 1.002498e+03,  1.045543e+03,  1.094368e+03, ..., -1.552294e+03,
#         -1.594745e+03, -1.629620e+03],
#        ...,
#        [ 1.428601e+02,  7.026926e+01, -1.236373e+00, ...,  1.334783e+03,
#          1.370401e+03,  1.432271e+03],
#        [ 1.760545e+02,  9.009327e+01, -3.196331e+01, ...,  1.294869e+03,
#          1.345597e+03,  1.393112e+03],
#        [ 1.277816e+02,  3.103102e+01, -9.108700e+01, ...,  1.248162e+03,
#          1.298630e+03,  1.353679e+03]])
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 ...

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/geofluxtotal_mean_300.nc'
DS_geoflux_climo=xr.open_dataset(f)
geoflux_climo300=DS_geoflux_climo['__xarray_dataarray_variable__']
geoflux_climo300
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
# array([[ 5.343520e+02,  1.677240e+03,  2.624740e+03, ..., -5.075939e+04,
#         -5.353371e+04, -5.614020e+04],
#        [-1.356382e+03,  6.325697e-01,  6.684628e+02, ..., -4.907362e+04,
#         -5.196409e+04, -5.458668e+04],
#        [-3.666529e+03, -2.151778e+03, -1.326285e+03, ..., -4.704279e+04,
#         -5.000124e+04, -5.277233e+04],
#        ...,
#        [-8.706860e+03, -1.113883e+04, -1.379460e+04, ...,  5.834097e+04,
#          5.982184e+04,  6.149465e+04],
#        [-8.023868e+03, -1.122080e+04, -1.589942e+04, ...,  5.584832e+04,
#          5.817950e+04,  6.015485e+04],
#        [-9.716381e+03, -1.396364e+04, -1.874596e+04, ...,  5.340400e+04,
#          5.599433e+04,  5.844228e+04]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
# ...

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/shtotal_diff300.nc'
DS_sh_diff=xr.open_dataset(f)
sh_diff300=DS_sh_diff['__xarray_dataarray_variable__']
sh_diff300
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
# array([[  80599.79 ,   95538.734,  110880.08 , ..., -106582.75 , -107058.75 ,
#         -111333.625],
#        [  74993.23 ,   88319.15 ,  104560.91 , ..., -108932.875, -112616.375,
#         -118904.875],
#        [  73737.75 ,   85956.266,   99649.31 , ..., -109372.875, -117037.5  ,
#         -127233.625],
#        ...,
#        [-422794.5  , -403025.22 , -388023.72 , ...,   25350.75 ,   39408.5  ,
#           55757.625],
#        [-414624.94 , -396807.06 , -379961.4  , ...,   34621.625,   46587.   ,
#           58679.625],
#        [-394618.06 , -376144.03 , -358844.62 , ...,   41408.75 ,   50672.5  ,
#           59308.75 ]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 ...

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/lh_diff_total300.nc'
DS_lh_diff=xr.open_dataset(f)
lh_diff300=DS_lh_diff['__xarray_dataarray_variable__']
lh_diff300
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
# array([[ 224.739999,  262.325895,  283.1533  , ..., -270.074954, -273.460381,
#         -272.88938 ],
#        [ 231.268018,  268.561288,  282.234881, ..., -295.678888, -302.706493,
#         -289.853101],
#        [ 230.808665,  267.437826,  283.099861, ..., -309.315275, -306.983003,
#         -299.600234],
#        ...,
#        [-283.697474, -269.461825, -248.624724, ...,  -22.485567,   -5.033557,
#           14.58573 ],
#        [-257.561315, -242.942928, -241.964175, ...,   -6.273891,   -4.580202,
#           13.935483],
#        [-234.132407, -230.652468, -235.884879, ...,   11.972167,   16.611436,
#           28.061584]])
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 ...

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/geo_diff_total300.nc'
DS_geoflux_diff300=xr.open_dataset(f)
geoflux_diff300=DS_geoflux_diff300['__xarray_dataarray_variable__']
geoflux_diff300
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
# array([[ -2385.1995 ,   -265.70032,   1931.2485 , ...,  12062.023  ,
#          13094.867  ,  12723.898  ],
#        [  -427.80676,   1719.3391 ,   3821.0515 , ...,  13719.57   ,
#          14246.375  ,  13952.043  ],
#        [  1050.3955 ,   3519.3464 ,   6076.0957 , ...,  15115.359  ,
#          15452.574  ,  15067.086  ],
#        ...,
#        [-18963.197  , -17684.33   , -16471.81   , ...,   7226.785  ,
#           7613.0664 ,   7174.4727 ],
#        [-17508.31   , -16685.229  , -15416.626  , ...,   8138.5586 ,
#           8622.234  ,   7989.41   ],
#        [-16223.424  , -15039.871  , -13574.5205 , ...,   7760.0625 ,
#           8508.637  ,   8302.309  ]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 ...

# %%
diff_all300=[sh_diff300,lh_diff300,geoflux_diff300]
diff_all300
# Out:
# [<xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
#  array([[  80599.79 ,   95538.734,  110880.08 , ..., -106582.75 , -107058.75 ,
#          -111333.625],
#         [  74993.23 ,   88319.15 ,  104560.91 , ..., -108932.875, -112616.375,
#          -118904.875],
#         [  73737.75 ,   85956.266,   99649.31 , ..., -109372.875, -117037.5  ,
#          -127233.625],
#         ...,
#         [-422794.5  , -403025.22 , -388023.72 , ...,   25350.75 ,   39408.5  ,
#            55757.625],
#         [-414624.94 , -396807.06 , -379961.4  , ...,   34621.625,   46587.   ,
#            58679.625],
#         [-394618.06 , -376144.03 , -358844.62 , ...,   41408.75 ,   50672.5  ,
#            59308.75 ]], dtype=float32)
#  Coordinates:
#    * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#    * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#      lev      float64 300.0,
# ...

# %%
climo_all300=[sh_climo300,lh_climo300,geoflux_climo300]
climo_all300
# Out:
# [<xarray.DataArray '__xarray_dataarray_variable__' (lat: 55, lon: 113)>
#  array([[-1.091989e+05, -8.104518e+04, -4.987407e+04, ..., -1.385097e+06,
#          -1.409684e+06, -1.435050e+06],
#         [-1.682123e+05, -1.406678e+05, -1.115521e+05, ..., -1.340146e+06,
#          -1.366448e+06, -1.393760e+06],
#         [-2.321249e+05, -2.041049e+05, -1.749302e+05, ..., -1.291097e+06,
#          -1.318690e+06, -1.347284e+06],
#         ...,
#         [-3.182575e+04, -1.155819e+05, -2.044600e+05, ...,  1.816562e+06,
#           1.871879e+06,  1.926275e+06],
#         [ 9.228025e+02, -9.467397e+04, -2.330118e+05, ...,  1.796396e+06,
#           1.870153e+06,  1.929655e+06],
#         [-2.877125e+04, -1.547170e+05, -2.980977e+05, ...,  1.777279e+06,
#           1.850911e+06,  1.920553e+06]], dtype=float32)
#  Coordinates:
#    * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#    * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
# ...

# %%
# Define the figure and each axis for the 2 rows and 2 columns
fig, axs = plt.subplots(nrows=3,ncols=1,
                        subplot_kw={'projection': ccrs.PlateCarree()},
                        figsize=(20,10))
titles=['Sensible Heat Transport', 'Latent Heat transport','Geopotential Flux transport']
# axs is a 2 dimensional array of `GeoAxes`.  
# We will flatten it into a 1-D array
axs=axs.flatten()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())

#Loop over all of the seasons and plot
#for i in enumerate(climo_all):
for i in range(len(climo_all)):
        # Select the season
        data=climo_all300[i]
        # Add the cyclic point
        data,lons=add_cyclic_point(data,coord=sh_climo300['lon'])
        max_val=100000
        increment=25000
        clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
        # Contour plot
        #norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03,
        #                                      vmin=-1600000, vmax=1600000, base=10)
        cs=axs[i].contourf(lons,sh_climo300['lat'],data,clevs,
                          transform = ccrs.PlateCarree(),
                          cmap='coolwarm',extend='both')
        clevs2=np.arange(-6,7,1)
        axs[i].contour(vclimo300['lon'],vclimo300['lat'],vclimo300,clevs2,transform=ccrs.PlateCarree(),linewidths=1,colors='k')

       # Longitude labels
        axs[i].set_xticks(np.arange(-180,181,60), crs=ccrs.PlateCarree())
        lon_formatter = cticker.LongitudeFormatter()
        axs[i].xaxis.set_major_formatter(lon_formatter)

        # Latitude labels
        axs[i].set_yticks(np.arange(-90,91,30), crs=ccrs.PlateCarree())
        lat_formatter = cticker.LatitudeFormatter()
        axs[i].yaxis.set_major_formatter(lat_formatter)

        # Title each subplot with the name of the season
        axs[i].set_title(titles[i])

        # Draw the coastines for each subplot
        axs[i].coastlines()
        axs[i].set_extent([-124.5,-66.8,23.486,49])
        axs[i].add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')
# Adjust the location of the subplots 
# on the page to make room for the colorbar
fig.subplots_adjust(bottom=0.25, top=0.9, left=0.05, right=0.95,
                    wspace=0.2, hspace=0.2)

# Add a colorbar axis at the bottom of the graph
cbar_ax = fig.add_axes([0.2, 0.175, 0.6, 0.02])

# Draw the colorbar
cbar=fig.colorbar(cs, cax=cbar_ax,orientation='horizontal',label='m^3/s^3')
fig.tight_layout()
# Add a big title at the top
plt.suptitle('Total Energy Transport Climatology (300mb)',fontsize=15)
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/300mbtotalall.png')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.

# %%
# Define the figure and each axis for the 2 rows and 2 columns
fig, axs = plt.subplots(nrows=3,ncols=1,
                        subplot_kw={'projection': ccrs.PlateCarree()},
                        figsize=(20,10))
titles=['Sensible Heat Transport', 'Latent Heat transport','Geopotential flux transport']
# axs is a 2 dimensional array of `GeoAxes`.  
# We will flatten it into a 1-D array
axs=axs.flatten()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())

#Loop over all of the seasons and plot
#for i in enumerate(climo_all):
for i in range(len(diff_all300)):
        # Select the season
        data=diff_all300[i]
        # Add the cyclic point
        data,lons=add_cyclic_point(data,coord=geoflux_diff300['lon'])
        max_val=10000
        increment=2500
        clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
        # Contour plot
        #norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03,
        #                                      vmin=-1600000, vmax=1600000, base=10)
        cs=axs[i].contourf(lons,geoflux_diff300['lat'],data,clevs,
                          transform = ccrs.PlateCarree(),
                          cmap='BrBG',extend='both')
       # Longitude labels
        axs[i].set_xticks(np.arange(-180,181,60), crs=ccrs.PlateCarree())
        lon_formatter = cticker.LongitudeFormatter()
        axs[i].xaxis.set_major_formatter(lon_formatter)

        # Latitude labels
        axs[i].set_yticks(np.arange(-90,91,30), crs=ccrs.PlateCarree())
        lat_formatter = cticker.LatitudeFormatter()
        axs[i].yaxis.set_major_formatter(lat_formatter)

        # Title each subplot with the name of the season
        axs[i].set_title(titles[i])

        # Draw the coastines for each subplot
        axs[i].coastlines()
        axs[i].set_extent([-124.5,-66.8,23.486,49])
        axs[i].add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')
# Adjust the location of the subplots 
# on the page to make room for the colorbar
fig.subplots_adjust(bottom=0.25, top=0.9, left=0.05, right=0.95,
                    wspace=0.2, hspace=0.2)

# Add a colorbar axis at the bottom of the graph
cbar_ax = fig.add_axes([0.2, 0.175, 0.6, 0.02])

# Draw the colorbar
cbar=fig.colorbar(cs, cax=cbar_ax,orientation='horizontal',label='difference (m^3/s^3)')
fig.tight_layout()
# Add a big title at the top
plt.suptitle('Total Energy Transport Late-Early Climatology Difference (300mb)',fontsize=15)
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/300mbtotalall_diff.png')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:55: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:55: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.

# %%
### 300mb Transients

# %%
### Loading several files
f='/project/xprecip/merra2_ncfiles/energy_calcs/shtransients_climo300.nc'
DS_sh_trans=xr.open_dataset(f)
sh_trans300=DS_sh_trans['__xarray_dataarray_variable__']
sh_trans300
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
# array([[-753.460963,    0.      ,    0.      , ...,    0.      ,    0.      ,
#            0.      ],
#        [-720.466756, -704.709946, -680.922979, ..., -207.605835, -204.919311,
#         -228.347983],
#        [-665.741292, -654.711276, -619.21347 , ..., -192.925888, -199.900721,
#         -222.143152],
#        ...,
#        [-367.590429, -471.258788, -626.500325, ..., 6377.653839, 6514.960169,
#         6660.901813],
#        [-435.933696, -539.103022, -691.305799, ..., 5659.190365, 5797.534057,
#         5930.48845 ],
#        [-350.876499, -465.650697, -665.267765, ..., 4932.260946, 5059.092722,
#         5161.564318]])
# Coordinates:
#     cutoffs       int64 ...
#     coefficients  float64 ...
#     lev           float64 ...
#   * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
#   * lat           (lat) float64 20.0 20.75 21.5 22.25 ... 52.25 53.0 53.75 54.5

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/shtransients_diff300.nc'
DS_sh_diff=xr.open_dataset(f)
sh_diff300trans=DS_sh_diff['__xarray_dataarray_variable__']
sh_diff300trans
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
# array([[ -266.771509,     0.      ,     0.      , ...,     0.      ,
#             0.      ,     0.      ],
#        [ -277.884686,  -177.100404,  -137.330284, ...,   147.235119,
#           152.794572,   136.264851],
#        [ -236.505312,  -160.187839,  -132.235291, ...,   111.867282,
#           111.467693,   109.85603 ],
#        ...,
#        [-1271.27784 , -1304.222932, -1299.069191, ...,    51.526655,
#          -220.875763,  -355.303836],
#        [-1403.649022, -1427.912529, -1404.832285, ...,   120.908331,
#          -116.849967,  -267.094706],
#        [-1377.218739, -1448.745321, -1560.909312, ...,    21.116321,
#          -172.925811,  -299.098375]])
# Coordinates:
#     cutoffs       int64 ...
#     coefficients  float64 ...
#     lev           float64 ...
#   * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
# ...

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/lhtransients_climo300.nc'
DS_lh_climo=xr.open_dataset(f)
lh_climo300trans=DS_lh_climo['__xarray_dataarray_variable__']
lh_climo300trans
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
# array([[341.481134,   0.      ,   0.      , ...,   0.      ,   0.      ,
#           0.      ],
#        [330.21634 , 334.035943, 333.315469, ..., 121.262576, 125.63106 ,
#         130.877538],
#        [335.61175 , 335.64692 , 334.323839, ..., 134.118318, 139.390225,
#         147.766035],
#        ...,
#        [ 40.429323,  41.196277,  41.216372, ..., 184.060625, 184.311322,
#         185.335902],
#        [ 45.239068,  45.882565,  44.251637, ..., 174.002576, 176.377786,
#         178.365741],
#        [ 48.185284,  45.160989,  40.660561, ..., 168.171345, 170.401101,
#         175.392922]])
# Coordinates:
#     cutoffs       int64 ...
#     coefficients  float64 ...
#     lev           float64 ...
#   * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
#   * lat           (lat) float64 20.0 20.75 21.5 22.25 ... 52.25 53.0 53.75 54.5

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/lhtransients_diff300.nc'
DS_lh_diff=xr.open_dataset(f)
lh_diff300trans=DS_lh_diff['__xarray_dataarray_variable__']
lh_diff300trans
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
# array([[ 93.109558,   0.      ,   0.      , ...,   0.      ,   0.      ,
#           0.      ],
#        [ 83.108597,  74.729327,  68.498446, ...,  -9.729106, -10.909192,
#         -14.96953 ],
#        [ 90.181066,  78.69495 ,  73.965142, ...,  -5.378157,  -2.624688,
#          -5.045503],
#        ...,
#        [-23.545445, -29.551708, -35.871259, ...,  57.886035,  52.824539,
#          43.425059],
#        [-22.425283, -26.30198 , -30.720571, ...,  48.918545,  48.750162,
#          47.144014],
#        [-24.101502, -24.841146, -26.191491, ...,  38.415948,  41.444575,
#          49.674205]])
# Coordinates:
#     cutoffs       int64 ...
#     coefficients  float64 ...
#     lev           float64 ...
#   * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
#   * lat           (lat) float64 20.0 20.75 21.5 22.25 ... 52.25 53.0 53.75 54.5

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/geofluxtransients_climo300.nc'
DS_geoflux_climo=xr.open_dataset(f)
geoflux_climo300trans=DS_geoflux_climo['__xarray_dataarray_variable__']
geoflux_climo300trans
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
# array([[ 0.05644 ,  0.      ,  0.      , ...,  0.      ,  0.      ,  0.      ],
#        [ 0.050292,  0.047653,  0.044509, ..., -0.035106, -0.032901, -0.030451],
#        [ 0.041561,  0.038387,  0.035931, ..., -0.040618, -0.0379  , -0.034712],
#        ...,
#        [-0.073041, -0.08002 , -0.087127, ..., -0.215656, -0.215088, -0.212851],
#        [-0.070368, -0.078802, -0.082829, ..., -0.21996 , -0.21733 , -0.213288],
#        [-0.066182, -0.072639, -0.076555, ..., -0.221507, -0.217837, -0.213071]])
# Coordinates:
#     cutoffs       int64 ...
#     coefficients  float64 ...
#   * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
#     lev           float64 ...
#   * lat           (lat) float64 20.0 20.75 21.5 22.25 ... 52.25 53.0 53.75 54.5

# %%
f='/project/xprecip/merra2_ncfiles/energy_calcs/geofluxtransients_diff300.nc'
DS_geoflux_diff300=xr.open_dataset(f)
geoflux_diff300trans=DS_geoflux_diff300['__xarray_dataarray_variable__']
geoflux_diff300trans
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
# array([[-9.255450e-02,  0.000000e+00,  0.000000e+00, ...,  0.000000e+00,
#          0.000000e+00,  0.000000e+00],
#        [-9.078126e-02, -1.007944e-01, -1.074097e-01, ...,  5.348262e-02,
#          6.136034e-02,  6.748709e-02],
#        [-8.359467e-02, -9.343341e-02, -1.041623e-01, ...,  5.943233e-02,
#          6.722914e-02,  7.352490e-02],
#        ...,
#        [ 2.636197e-02,  1.764962e-02,  1.253321e-02, ..., -1.412890e-01,
#         -1.667986e-01, -1.928163e-01],
#        [ 1.491616e-02,  1.027890e-02,  7.687923e-03, ..., -1.616547e-01,
#         -1.831401e-01, -2.033471e-01],
#        [ 5.050284e-03,  2.829293e-03,  1.236785e-04, ..., -1.722797e-01,
#         -1.900220e-01, -2.088827e-01]])
# Coordinates:
#     cutoffs       int64 ...
#     coefficients  float64 ...
#   * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
#     lev           float64 ...
# ...

# %%
diff_all300trans=[sh_diff300trans,lh_diff300trans,geoflux_diff300trans]
diff_all300trans
# Out:
# [<xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
#  array([[ -266.771509,     0.      ,     0.      , ...,     0.      ,
#              0.      ,     0.      ],
#         [ -277.884686,  -177.100404,  -137.330284, ...,   147.235119,
#            152.794572,   136.264851],
#         [ -236.505312,  -160.187839,  -132.235291, ...,   111.867282,
#            111.467693,   109.85603 ],
#         ...,
#         [-1271.27784 , -1304.222932, -1299.069191, ...,    51.526655,
#           -220.875763,  -355.303836],
#         [-1403.649022, -1427.912529, -1404.832285, ...,   120.908331,
#           -116.849967,  -267.094706],
#         [-1377.218739, -1448.745321, -1560.909312, ...,    21.116321,
#           -172.925811,  -299.098375]])
#  Coordinates:
#      cutoffs       int64 10
#      coefficients  float64 -15.0
#      lev           float64 300.0
#    * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
# ...

# %%
climo_all300trans=[sh_trans300,lh_climo300trans,geoflux_climo300trans]
climo_all300trans
# Out:
# [<xarray.DataArray '__xarray_dataarray_variable__' (lat: 47, lon: 100)>
#  array([[-753.460963,    0.      ,    0.      , ...,    0.      ,    0.      ,
#             0.      ],
#         [-720.466756, -704.709946, -680.922979, ..., -207.605835, -204.919311,
#          -228.347983],
#         [-665.741292, -654.711276, -619.21347 , ..., -192.925888, -199.900721,
#          -222.143152],
#         ...,
#         [-367.590429, -471.258788, -626.500325, ..., 6377.653839, 6514.960169,
#          6660.901813],
#         [-435.933696, -539.103022, -691.305799, ..., 5659.190365, 5797.534057,
#          5930.48845 ],
#         [-350.876499, -465.650697, -665.267765, ..., 4932.260946, 5059.092722,
#          5161.564318]])
#  Coordinates:
#      cutoffs       int64 10
#      coefficients  float64 -15.0
#      lev           float64 300.0
#    * lon           (lon) float64 -125.0 -124.2 -123.5 ... -52.25 -51.5 -50.75
# ...

# %%
# Define the figure and each axis for the 2 rows and 2 columns
fig, axs = plt.subplots(nrows=3,ncols=1,
                        subplot_kw={'projection': ccrs.PlateCarree()},
                        figsize=(20,10))
titles=['Sensible Heat Transport', 'Latent Heat transport','Geopotential Flux transport']
# axs is a 2 dimensional array of `GeoAxes`.  
# We will flatten it into a 1-D array
axs=axs.flatten()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())

#Loop over all of the seasons and plot
#for i in enumerate(climo_all):
for i in range(len(climo_all)):
        # Select the season
        data=climo_all300trans[i]
        # Add the cyclic point
        data,lons=add_cyclic_point(data,coord=sh_trans300['lon'])
        max_val=12500
        increment=2500
        clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
        clevs2=np.arange(-6,7,1)
        # Contour plot
        #norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03,
        #                                      vmin=-1600000, vmax=1600000, base=10)
        cs=axs[i].contourf(lons,sh_trans300['lat'],data,clevs,
                          transform = ccrs.PlateCarree(),
                          cmap='coolwarm',extend='both')
        axs[i].contour(vclimo300_transients['lon'],vclimo300_transients['lat'],vclimo300_transients,clevs2,transform=ccrs.PlateCarree(),linewidths=1,colors='k')

       # Longitude labels
        axs[i].set_xticks(np.arange(-180,181,60), crs=ccrs.PlateCarree())
        lon_formatter = cticker.LongitudeFormatter()
        axs[i].xaxis.set_major_formatter(lon_formatter)

        # Latitude labels
        axs[i].set_yticks(np.arange(-90,91,30), crs=ccrs.PlateCarree())
        lat_formatter = cticker.LatitudeFormatter()
        axs[i].yaxis.set_major_formatter(lat_formatter)

        # Title each subplot with the name of the season
        axs[i].set_title(titles[i])

        # Draw the coastines for each subplot
        axs[i].coastlines()
        axs[i].set_extent([-124.5,-66.8,23.486,49])
        axs[i].add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')
# Adjust the location of the subplots 
# on the page to make room for the colorbar
fig.subplots_adjust(bottom=0.25, top=0.9, left=0.05, right=0.95,
                    wspace=0.2, hspace=0.2)

# Add a colorbar axis at the bottom of the graph
cbar_ax = fig.add_axes([0.2, 0.175, 0.6, 0.02])

# Draw the colorbar
cbar=fig.colorbar(cs, cax=cbar_ax,orientation='horizontal',label='m^3/s^3')
fig.tight_layout()
# Add a big title at the top
plt.suptitle('Transient Energy Transport Climatology (300mb)',fontsize=15)
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/300mbtransall.png')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.

# %%
# Define the figure and each axis for the 2 rows and 2 columns
fig, axs = plt.subplots(nrows=3,ncols=1,
                        subplot_kw={'projection': ccrs.PlateCarree()},
                        figsize=(20,10))
titles=['Sensible Heat Transport', 'Latent Heat transport','Geopotential flux transport']
# axs is a 2 dimensional array of `GeoAxes`.  
# We will flatten it into a 1-D array
axs=axs.flatten()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())

#Loop over all of the seasons and plot
#for i in enumerate(climo_all):
for i in range(len(diff_all300trans)):
        # Select the season
        data=diff_all300trans[i]
        # Add the cyclic point
        data,lons=add_cyclic_point(data,coord=geoflux_diff300trans['lon'])
        max_val=4000
        increment=500
        clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
        # Contour plot
        #norm=colors.SymLogNorm(linthresh=0.03, linscale=0.03,
        #                                      vmin=-1600000, vmax=1600000, base=10)
        cs=axs[i].contourf(lons,geoflux_diff300trans['lat'],data,clevs,
                          transform = ccrs.PlateCarree(),
                          cmap='BrBG',extend='both')
       # Longitude labels
        axs[i].set_xticks(np.arange(-180,181,60), crs=ccrs.PlateCarree())
        lon_formatter = cticker.LongitudeFormatter()
        axs[i].xaxis.set_major_formatter(lon_formatter)

        # Latitude labels
        axs[i].set_yticks(np.arange(-90,91,30), crs=ccrs.PlateCarree())
        lat_formatter = cticker.LatitudeFormatter()
        axs[i].yaxis.set_major_formatter(lat_formatter)

        # Title each subplot with the name of the season
        axs[i].set_title(titles[i])

        # Draw the coastines for each subplot
        axs[i].coastlines()
        axs[i].set_extent([-124.5,-66.8,23.486,49])
        axs[i].add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')
# Adjust the location of the subplots 
# on the page to make room for the colorbar
fig.subplots_adjust(bottom=0.25, top=0.9, left=0.05, right=0.95,
                    wspace=0.2, hspace=0.2)

# Add a colorbar axis at the bottom of the graph
cbar_ax = fig.add_axes([0.2, 0.175, 0.6, 0.02])

# Draw the colorbar
cbar=fig.colorbar(cs, cax=cbar_ax,orientation='horizontal',label='difference (m^3/s^3)')
fig.tight_layout()
# Add a big title at the top
plt.suptitle('Transient Energy Transport Late-Early Climatology Difference (300mb)',fontsize=15)
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/300mbtransall_diff.png')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:55: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:55: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.

# %%
### FRACTION CALCULATIONS

# %%
sh=(sh_climo_transients/sh_climo)*100
lh=(lh_climo_transients/lh_climo)*100
geo=(geofluxclimo_850/geo_climo)*100

# %%
fraction850=[sh,lh,geo]
fraction850
# Out:
# [<xarray.DataArray '__xarray_dataarray_variable__' (lat: 19, lon: 19)>
#  array([[-3.11435476e-02, -3.00052901e-02, -3.28778142e-02,
#          -5.88230152e-02, -2.81431954e-01,  6.21023838e-01,
#                      nan,  5.78153828e-01,  3.90891430e-01,
#           4.19380639e-01,  2.77374178e-01,  1.94299314e-01,
#           2.48469682e-01,  2.52121626e-01,  1.60983852e-01,
#           1.35969007e-01,  1.34162280e-01,  1.53104962e-01,
#           1.84514269e-01],
#         [-4.45051548e-02, -4.27678450e-02, -4.32576482e-02,
#          -8.97508713e-02, -6.51584536e+00,             nan,
#          -6.89260909e-01,  4.52557329e-01,  4.19393959e-01,
#           4.68132366e-01,  3.48566288e-01,  2.77763830e-01,
#           2.90033596e-01,  3.27945216e-01,  2.57251726e-01,
#           2.31785300e-01,  2.21487662e-01,  2.20409411e-01,
#           2.33293247e-01],
#         [-6.35904897e-02, -6.07479528e-02, -5.59896024e-02,
#          -1.44610240e-01,  1.91157925e-01,             nan,
# ...

# %%
# Define the figure and each axis for the 2 rows and 2 columns
fig, axs = plt.subplots(nrows=3,ncols=1,
                        subplot_kw={'projection': ccrs.PlateCarree()},
                        figsize=(20,10))
titles=['Sensible Heat Transport', 'Latent Heat transport','Geopotential flux transport']
# axs is a 2 dimensional array of `GeoAxes`.  
# We will flatten it into a 1-D array
axs=axs.flatten()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())

#Loop over all of the seasons and plot
#for i in enumerate(climo_all):
for i in range(len(fraction850)):
        # Select the season
        data=fraction850[i]
        # Add the cyclic point
        data,lons=add_cyclic_point(data,coord=sh['lon'])
        max_val=100
        increment=5
        clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
        cs=axs[i].contourf(lons,sh['lat'],data,clevs,
                          transform = ccrs.PlateCarree(),
                          cmap='coolwarm',extend='both')
       # Longitude labels
        axs[i].set_xticks(np.arange(-180,181,60), crs=ccrs.PlateCarree())
        lon_formatter = cticker.LongitudeFormatter()
        axs[i].xaxis.set_major_formatter(lon_formatter)

        # Latitude labels
        axs[i].set_yticks(np.arange(-90,91,30), crs=ccrs.PlateCarree())
        lat_formatter = cticker.LatitudeFormatter()
        axs[i].yaxis.set_major_formatter(lat_formatter)

        # Title each subplot with the name of the season
        axs[i].set_title(titles[i])

        # Draw the coastines for each subplot
        axs[i].coastlines()
        axs[i].set_extent([-124.5,-66.8,23.486,49])
        axs[i].add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')
# Adjust the location of the subplots 
# on the page to make room for the colorbar
fig.subplots_adjust(bottom=0.25, top=0.9, left=0.05, right=0.95,
                    wspace=0.2, hspace=0.2)

# Add a colorbar axis at the bottom of the graph
cbar_ax = fig.add_axes([0.2, 0.175, 0.6, 0.02])

# Draw the colorbar
cbar=fig.colorbar(cs, cax=cbar_ax,orientation='horizontal',label='percentage')
fig.tight_layout()
# Add a big title at the top
plt.suptitle('Fraction of Energy Transport Climatology by transients (850mb)',fontsize=15)
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/850mbfraction_map.png')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:52: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:52: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.

# %%
shzonal=sh.mean(dim='lon')
lhzonal=lh.mean(dim='lon')
geozonal=geo.mean(dim='lon')

# %%
lhzonal
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 19)>
# array([ 4.44426098,  5.63915931,  6.17315796,  7.39820181,  8.60772473,
#        12.36046476, 15.9667244 ,  8.85074553, 26.3801808 , 53.42293537,
#        29.86336638, 58.35886584, 24.16054319, 34.00370354, 46.67395451,
#        -7.48952107, 32.39923098, 20.04655557, 41.20343616])
# Coordinates:
#   * lat           (lat) float64 24.5 26.0 27.5 29.0 30.5 ... 47.0 48.5 50.0 51.5
#     cutoffs       int64 10
#     coefficients  float64 -15.0
#     lev           float64 850.0

# %%
plt.figure(figsize=(10,10))
plt.title("Zonal mean CONUS Percentage of Transient Energy transport climatology (850mb)",fontsize=15)
plt.plot(shzonal,shzonal['lat'],label='Sensible Heat percentage',linewidth=4,color='blue')
plt.xlabel('Percentage of northward transport',fontsize=15)
#plt.ylabel('Z (meters)',fontsize=15,rotation='90')
plt.gcf().text(-0.02,0.45, "Latitude (degrees North)", ha="center", va="center", rotation=90, fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.plot(lhzonal,lhzonal['lat'],label='Latent Heat percentage',linewidth=4,color='forestgreen')
plt.plot(geozonal,geozonal['lat'],label='Geopotential flux percentage',linewidth=4,color='red')
plt.legend()
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/850mbtransportpercentage.png')

# %%
sh300=(sh_trans300/sh_climo300)*100
lh300=(lh_climo300trans/lh_climo300)*100
geo300=(geoflux_climo300trans/geoflux_climo300)*100

# %%
fraction300=[sh300,lh300,geo300]
fraction300
# Out:
# [<xarray.DataArray '__xarray_dataarray_variable__' (lat: 19, lon: 19)>
#  array([[ 6.48467762e-01, -4.42221435e-02, -4.31951162e-03,
#           2.31630949e-02,  2.35147596e-02,  9.75403021e-03,
#           9.09327061e-03,  4.31971398e-03,  8.30768225e-03,
#           1.35473240e-02,  3.07208280e-03,  5.62662152e-03,
#           1.87161351e-02,  1.41329773e-01, -2.21764932e-02,
#          -1.24446212e-03,  4.07072635e-03,  5.48831531e-03,
#           1.50774190e-04],
#         [ 1.42868772e-02, -4.03471504e-01,  5.94103048e-02,
#           5.60610293e-02,  5.08666408e-02,  4.73425199e-02,
#           3.25761853e-02,  2.73153846e-02,  3.26414148e-02,
#           4.14292554e-02,  4.03894244e-02,  4.14080152e-02,
#           6.11497086e-02,  1.68857834e-01, -2.42377385e-01,
#          -1.57930363e-02, -1.32006513e-02, -8.35925911e-03,
#          -1.49978078e-02],
#         [-5.75804154e-02, -1.12841272e-01,  5.63920439e+00,
#           1.15425275e-01,  6.91723280e-02,  7.64976485e-02,
# ...

# %%
# Define the figure and each axis for the 2 rows and 2 columns
fig, axs = plt.subplots(nrows=3,ncols=1,
                        subplot_kw={'projection': ccrs.PlateCarree()},
                        figsize=(20,10))
titles=['Sensible Heat Transport', 'Latent Heat transport','Geopotential flux transport']
# axs is a 2 dimensional array of `GeoAxes`.  
# We will flatten it into a 1-D array
axs=axs.flatten()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())

#Loop over all of the seasons and plot
#for i in enumerate(climo_all):
for i in range(len(fraction300)):
        # Select the season
        data=fraction300[i]
        # Add the cyclic point
        data,lons=add_cyclic_point(data,coord=sh300['lon'])
        max_val=100
        increment=5
        clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
        cs=axs[i].contourf(lons,sh300['lat'],data,clevs,
                          transform = ccrs.PlateCarree(),
                          cmap='coolwarm',extend='both')
       # Longitude labels
        axs[i].set_xticks(np.arange(-180,181,60), crs=ccrs.PlateCarree())
        lon_formatter = cticker.LongitudeFormatter()
        axs[i].xaxis.set_major_formatter(lon_formatter)

        # Latitude labels
        axs[i].set_yticks(np.arange(-90,91,30), crs=ccrs.PlateCarree())
        lat_formatter = cticker.LatitudeFormatter()
        axs[i].yaxis.set_major_formatter(lat_formatter)

        # Title each subplot with the name of the season
        axs[i].set_title(titles[i])

        # Draw the coastines for each subplot
        axs[i].coastlines()
        axs[i].set_extent([-124.5,-66.8,23.486,49])
        axs[i].add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')
# Adjust the location of the subplots 
# on the page to make room for the colorbar
fig.subplots_adjust(bottom=0.25, top=0.9, left=0.05, right=0.95,
                    wspace=0.2, hspace=0.2)

# Add a colorbar axis at the bottom of the graph
cbar_ax = fig.add_axes([0.2, 0.175, 0.6, 0.02])

# Draw the colorbar
cbar=fig.colorbar(cs, cax=cbar_ax,orientation='horizontal',label='percentage')
fig.tight_layout()
# Add a big title at the top
plt.suptitle('Fraction of Energy Transport Climatology by transients (300mb)',fontsize=15)
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/300mbfraction_map.png')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:52: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/ipykernel_launcher.py:52: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.

# %%
shzonal300=sh300.mean(dim='lon')
lhzonal300=lh300.mean(dim='lon')
geozonal300=geo300.mean(dim='lon')

# %%
plt.figure(figsize=(10,10))
plt.title("Zonal mean CONUS Percentage of Transient Energy transport climatology (300mb)",fontsize=15)
plt.plot(shzonal300,shzonal300['lat'],label='Sensible Heat percentage',linewidth=7,color='blue', alpha=0.5)
plt.xlabel('Percentage of northward transport',fontsize=15)
#plt.ylabel('Z (meters)',fontsize=15,rotation='90')
plt.gcf().text(-0.02,0.45, "Latitude (degrees North)", ha="center", va="center", rotation=90, fontsize=15)
xlabel=np.arange(-200,200,25)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.plot(lhzonal300,lhzonal300['lat'],label='Latent Heat percentage',linewidth=4,color='forestgreen')
plt.plot(geozonal300,geozonal300['lat'],label='Geopotential flux percentage',linewidth=3,color='red',alpha=0.7)
plt.legend()
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/300mbtransportpercentage.png')

# %%
shzonal300
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (lat: 19)>
# array([ 4.45610240e-02, -1.28763413e-03,  3.59806889e-01, -3.58883591e-01,
#        -4.62282488e-02,  5.92504233e-02,  3.45936667e+00,  3.00272917e-01,
#         3.16923928e-01,  3.68821636e-01,  4.13155556e-01,  3.91798047e-01,
#         2.58232673e-01,  3.46086216e-02,  7.92355384e-01,  1.09120288e-01,
#         3.67675386e-01,  2.21076995e+00, -5.04574596e-01])
# Coordinates:
#   * lat           (lat) float64 24.5 26.0 27.5 29.0 30.5 ... 47.0 48.5 50.0 51.5
#     cutoffs       int64 10
#     coefficients  float64 -15.0
#     lev           float64 300.0

# %% [markdown]
# ## Splitting data into 2 periods to determine reasons for trends

# %% [markdown]
# ### Try on snowfall data

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
#from intake import open_catalog
import cartopy.io.shapereader as shpreader
import mygrads as mg
#import Ngl
#import Nio
#import fiona
import matplotlib as mpl
import cartopy.mpl.ticker as cticker
from cartopy.util import add_cyclic_point
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from cartopy.feature import NaturalEarthFeature
from cartopy.feature import COASTLINE
#from clim680_function import xyticks
import pymannkendall as mk

# %%
f='/project/xprecip/merra2_ncfiles/snow/sixhour_resampled/totalsnow_6hrs.nc'
DS_snow6hr=xr.open_dataset(f)
DS_snow6hr
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 66, lon: 120, time: 61600)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2022-02-28T18:00:00
#   * lon      (lon) float64 -128.1 -127.5 -126.9 -126.2 ... -55.0 -54.38 -53.75
#   * lat      (lat) float64 20.5 21.0 21.5 22.0 22.5 ... 51.0 51.5 52.0 52.5 53.0
# Data variables:
#     PRECSNO  (time, lat, lon) float32 ...

# %%
snow6hr=DS_snow6hr['PRECSNO']
snow6hr
# Out:
# <xarray.DataArray 'PRECSNO' (time: 61600, lat: 66, lon: 120)>
# [487872000 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2022-02-28T18:00:00
#   * lon      (lon) float64 -128.1 -127.5 -126.9 -126.2 ... -55.0 -54.38 -53.75
#   * lat      (lat) float64 20.5 21.0 21.5 22.0 22.5 ... 51.0 51.5 52.0 52.5 53.0

# %%
winter_selected_snow=snow6hr.isel(time=snow6hr.time.dt.season.isin(['DJF']))
winter_selected_snow
# Out:
# <xarray.DataArray 'PRECSNO' (time: 15400, lat: 66, lon: 120)>
# [121968000 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2022-02-28T18:00:00
#   * lon      (lon) float64 -128.1 -127.5 -126.9 -126.2 ... -55.0 -54.38 -53.75
#   * lat      (lat) float64 20.5 21.0 21.5 22.0 22.5 ... 51.0 51.5 52.0 52.5 53.0

# %%
first_data=winter_selected_snow.sel(time=slice('1980-12-31','2001-02-28'))
first_data
# Out:
# <xarray.DataArray 'PRECSNO' (time: 7460, lat: 66, lon: 120)>
# [59083200 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 1980-12-31 ... 2001-02-28T18:00:00
#   * lon      (lon) float64 -128.1 -127.5 -126.9 -126.2 ... -55.0 -54.38 -53.75
#   * lat      (lat) float64 20.5 21.0 21.5 22.0 22.5 ... 51.0 51.5 52.0 52.5 53.0

# %%
last_data=winter_selected_snow.sel(time=slice('2001-12-31','2022-02-28'))
last_data
# Out:
# <xarray.DataArray 'PRECSNO' (time: 7460, lat: 66, lon: 120)>
# [59083200 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2001-12-31 ... 2022-02-28T18:00:00
#   * lon      (lon) float64 -128.1 -127.5 -126.9 -126.2 ... -55.0 -54.38 -53.75
#   * lat      (lat) float64 20.5 21.0 21.5 22.0 22.5 ... 51.0 51.5 52.0 52.5 53.0

# %% [markdown]
# ### First part of data (1980-2001)

# %%
monthly_timeseries=[]
for i in range(1980,2002,1):
    #print(i)
    year_of_data = winter_selected_snow.sel(time = slice(str(i)+"-01-01",str(i)+"-12-31")).groupby('time.month')
    timeseries_50th=year_of_data.quantile(0.50,dim='time')
    print(timeseries_50th)
    #print(year_of_data)
    monthly_timeseries.append(timeseries_50th)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-e0787b9baa58> in <module>
#       3     #print(i)
#       4     year_of_data = winter_selected_snow.sel(time = slice(str(i)+"-01-01",str(i)+"-12-31")).groupby('time.month').sum()
# ----> 5     timeseries_50th=year_of_data.quantile(0.50,dim='time')
#       6     print(timeseries_50th)
#       7     #print(year_of_data)
#
# ~/.conda/envs/clim680/lib/python3.6/site-packages/xarray/core/dataarray.py in quantile(self, q, dim, interpolation, keep_attrs, skipna)
#    3431             keep_attrs=keep_attrs,
#    3432             interpolation=interpolation,
# -> 3433             skipna=skipna,
#    3434         )
#    3435         return self._from_temp_dataset(ds)
#
# ~/.conda/envs/clim680/lib/python3.6/site-packages/xarray/core/dataset.py in quantile(self, q, dim, interpolation, numeric_only, keep_attrs, skipna)
# ...

# %%
monthly_ts=xr.concat(monthly_timeseries,dim='month')
monthly_ts
# Out:
# <xarray.DataArray 'PRECSNO' (month: 66, lat: 66, lon: 120)>
# array([[[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [2.98889972e-07, 4.17439151e-06, 3.60570266e-05, ...,
#          1.70124695e-05, 3.08782328e-05, 3.59864353e-05],
#         [3.57670160e-07, 1.06205116e-05, 2.88530719e-05, ...,
#          2.10458875e-05, 3.17897648e-05, 3.20019317e-05],
#         [1.27884905e-05, 1.58436596e-05, 3.01812252e-05, ...,
#          2.69575976e-05, 3.73383518e-05, 4.92325053e-05]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
# ...

# %%
jan_ts=monthly_ts.sel(month=1)
jan_ts
# Out:
# <xarray.DataArray 'PRECSNO' (month: 22, lat: 66, lon: 120)>
# array([[[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [2.98889972e-07, 4.17439151e-06, 3.60570266e-05, ...,
#          1.70124695e-05, 3.08782328e-05, 3.59864353e-05],
#         [3.57670160e-07, 1.06205116e-05, 2.88530719e-05, ...,
#          2.10458875e-05, 3.17897648e-05, 3.20019317e-05],
#         [1.27884905e-05, 1.58436596e-05, 3.01812252e-05, ...,
#          2.69575976e-05, 3.73383518e-05, 4.92325053e-05]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
# ...

# %%
from scipy.stats import mstats
months=np.arange(0,22,1)
nlons=len(jan_ts['lon'])
nlats=len(jan_ts['lat'])
#p_array=np.zeros((nlats,nlons))
#r_array=np.zeros((nlats,nlons))
m_array_jan=np.zeros((nlats,nlons))
low_ci=np.zeros((nlats,nlons))
high_ci=np.zeros((nlats,nlons))
for i in range(nlons):
    for j in range(nlats): 
        y=jan_ts[:,j,i]
        slope_thiel, intercept_thiel, low_slope,high_slope=mstats.theilslopes(y, x=months, alpha=0.95)
        #m,b,r,p,e = linregress(months,y)
        m_array_jan[j,i]=slope_thiel
        low_ci[j,i]=low_slope
        high_ci[j,i]=high_slope
        #r_array[j,i]=r
        #p_array[j,i]=p

# %%
values_med=first_data.groupby('time.month').quantile(0.50,dim='time')
values_med
# Out:
# <xarray.DataArray 'PRECSNO' (month: 3, lat: 66, lon: 120)>
# array([[[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [1.29395938e-11, 3.69809641e-07, 5.81764616e-05, ...,
#          1.15087769e-05, 1.90484570e-05, 2.15973705e-05],
#         [1.57212021e-10, 8.19706329e-05, 1.18249678e-04, ...,
#          1.21993944e-05, 2.02105293e-05, 2.48381402e-05],
#         [1.31897628e-04, 2.04584561e-04, 1.05984509e-04, ...,
#          1.78765040e-05, 2.41079397e-05, 2.87909061e-05]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
# ...

# %%
jan_ts_values_med=values_med.sel(month=1)
jan_ts_values_med=jan_ts_values_med*21600

# %%
fig = plt.figure(figsize=(11,8.5))
max_val=2
increment=0.025
clevs=np.arange(0,max_val+increment,increment)
#clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree(central_longitude=180))

# Add cyclic point
data=jan_ts_values_med[:,:]
#data,lon=add_cyclic_point(data,coord=data['lon'])
#mask_data,lons=add_cyclic_point(mask_sig,coord=jan_ts['lon'])

# Make a filled contour plot
cs=ax.contourf(jan_ts_values_med['lon'],jan_ts_values_med['lat'],
            data,clevs,
            transform=ccrs.PlateCarree(),
            cmap='YlGnBu',extend='both')

#ax.contourf(lon,jan_ts['lat'],mask_data,[0,1],
 #           transform = ccrs.PlateCarree(),colors='None',
  #          hatches=['.','.'],extend='both',alpha=0)
# Define the xticks for longtitude 
ax.set_xticks(np.arange(-180,181,60),crs=ccrs.PlateCarree())
lon_formatter=cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)

# Define ytick for latitude
ax.set_yticks(np.arange(-90,91,30),crs=ccrs.PlateCarree())
lat_formatter=cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)

ax.set_extent([-124.5,-66.8,23.486,49])
ax.coastlines()
ax.gridlines()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')

# Call colorbar
cbar=plt.colorbar(cs,orientation='horizontal',shrink=0.7,
                 label='Percentage')

# Add title
plt.title('Median snowfall (early period)')
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/janmedian_totalsnow_firstperiod.png')

# %%
ratio_median_jan=(m_array_jan/jan_ts_values_med)*100*21
ratio_median_jan
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/xarray/core/computation.py:739: RuntimeWarning: divide by zero encountered in true_divide
#   result_data = func(*input_data)
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/xarray/core/computation.py:739: RuntimeWarning: invalid value encountered in true_divide
#   result_data = func(*input_data)
# <xarray.DataArray 'PRECSNO' (lat: 66, lon: 120)>
# array([[         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        ...,
#        [  0.        ,   0.        ,   2.86885145, ..., -22.13441184,
#          12.61860963,  42.32916852],
#        [  0.        ,   0.40883713,  -4.29289026, ..., -30.80313351,
#          11.9520238 ,  23.61734737],
# ...

# %%
fig = plt.figure(figsize=(11,8.5))
max_val=100.0
increment=20

clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree(central_longitude=180))

# Add cyclic point
data=ratio_median_jan[:,:]
data,lon=add_cyclic_point(data,coord=jan_ts['lon'])
#mask_data,lons=add_cyclic_point(mask_sig,coord=jan_ts['lon'])

# Make a filled contour plot
cs=ax.contourf(lon,jan_ts['lat'],
            data,clevs,
            transform=ccrs.PlateCarree(),
            cmap='bwr',extend='both')

#ax.contourf(lon,jan_ts['lat'],mask_data,[0,1],
 #           transform = ccrs.PlateCarree(),colors='None',
  #          hatches=['.','.'],extend='both',alpha=0)
# Define the xticks for longtitude 
ax.set_xticks(np.arange(-180,181,60),crs=ccrs.PlateCarree())
lon_formatter=cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)

# Define ytick for latitude
ax.set_yticks(np.arange(-90,91,30),crs=ccrs.PlateCarree())
lat_formatter=cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)

ax.set_extent([-124.5,-66.8,23.486,49])
ax.coastlines()
ax.gridlines()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')

# Call colorbar
cbar=plt.colorbar(cs,orientation='horizontal',shrink=0.7,
                 label='Percentage')

# Add title
plt.title('Percentage of trend of Median to mean Median values of Janurary Snowfall over CONUS over 1980-2001 period')
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/janmedian_snowtrend_firstperiod.png')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:782: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   return super(GeoAxes, self).set_xticks(xticks, minor)
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:829: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   return super(GeoAxes, self).set_yticks(yticks, minor)
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:388: MatplotlibDeprecationWarning:
# ...

# %% [markdown]
# ### Second part of data (2002-2022)

# %%
monthly_timeseries=[]
for i in range(2002,2023,1):
    print(i)
    year_of_data = winter_selected_snow.sel(time = slice(str(i)+"-01-01",str(i)+"-12-31")).groupby('time.month')
    timeseries_50th=year_of_data.quantile(0.50,dim='time')
    #print(year_of_data)
    monthly_timeseries.append(timeseries_50th)
# Out:
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022

# %%
monthly_ts_late=xr.concat(monthly_timeseries,dim='month')
monthly_ts_late
# Out:
# <xarray.DataArray 'PRECSNO' (month: 62, lat: 66, lon: 120)>
# array([[[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [2.03652107e-07, 5.05783828e-06, 7.89223559e-05, ...,
#          1.12303860e-05, 1.65209640e-05, 2.25145650e-05],
#         [1.13637100e-09, 1.66201964e-04, 1.92739069e-04, ...,
#          9.51287802e-06, 2.01106886e-05, 2.62468820e-05],
#         [1.81731360e-04, 2.62293761e-04, 1.61638483e-04, ...,
#          1.48298786e-05, 2.63463589e-05, 3.89856286e-05]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
# ...

# %%
jan_ts_late=monthly_ts_late.sel(month=1)
jan_ts_late
# Out:
# <xarray.DataArray 'PRECSNO' (month: 21, lat: 66, lon: 120)>
# array([[[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [2.03652107e-07, 5.05783828e-06, 7.89223559e-05, ...,
#          1.12303860e-05, 1.65209640e-05, 2.25145650e-05],
#         [1.13637100e-09, 1.66201964e-04, 1.92739069e-04, ...,
#          9.51287802e-06, 2.01106886e-05, 2.62468820e-05],
#         [1.81731360e-04, 2.62293761e-04, 1.61638483e-04, ...,
#          1.48298786e-05, 2.63463589e-05, 3.89856286e-05]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
# ...

# %%
from scipy.stats import mstats
months=np.arange(0,21,1)
nlons=len(jan_ts['lon'])
nlats=len(jan_ts['lat'])
#p_array=np.zeros((nlats,nlons))
#r_array=np.zeros((nlats,nlons))
m_array_jan=np.zeros((nlats,nlons))
low_ci=np.zeros((nlats,nlons))
high_ci=np.zeros((nlats,nlons))
for i in range(nlons):
    for j in range(nlats): 
        y=jan_ts_late[:,j,i]
        slope_thiel, intercept_thiel, low_slope,high_slope=mstats.theilslopes(y, x=months, alpha=0.95)
        #m,b,r,p,e = linregress(months,y)
        m_array_jan[j,i]=slope_thiel
        low_ci[j,i]=low_slope
        high_ci[j,i]=high_slope
        #r_array[j,i]=r
        #p_array[j,i]=p

# %%
values_med_last=last_data.groupby('time.month').quantile(0.50,dim='time')
values_med_last
# Out:
# <xarray.DataArray 'PRECSNO' (month: 3, lat: 66, lon: 120)>
# array([[[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [4.41198293e-25, 1.94454628e-07, 7.29072744e-05, ...,
#          1.22547644e-05, 1.85806603e-05, 2.18462665e-05],
#         [1.20653117e-21, 1.26306084e-04, 1.66068785e-04, ...,
#          1.33842696e-05, 2.28194613e-05, 2.79410888e-05],
#         [1.72620341e-04, 2.91142613e-04, 1.53223053e-04, ...,
#          1.92383304e-05, 2.80851382e-05, 3.32179770e-05]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
# ...

# %%
jan_ts_values_med_last=values_med_last.sel(month=1)
jan_ts_values_med_last=jan_ts_values_med_last*21600

# %%
fig = plt.figure(figsize=(11,8.5))
max_val=2
increment=0.025
clevs=np.arange(0,max_val+increment,increment)

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree(central_longitude=180))

# Add cyclic point
data=jan_ts_values_med_last[:,:]
#data,lon=add_cyclic_point(data,coord=data['lon'])
#mask_data,lons=add_cyclic_point(mask_sig,coord=jan_ts['lon'])

# Make a filled contour plot
cs=ax.contourf(jan_ts_values_med_last['lon'],jan_ts_values_med_last['lat'],
            data,clevs,
            transform=ccrs.PlateCarree(),
            cmap='YlGnBu',extend='both')

#ax.contourf(lon,jan_ts['lat'],mask_data,[0,1],
 #           transform = ccrs.PlateCarree(),colors='None',
  #          hatches=['.','.'],extend='both',alpha=0)
# Define the xticks for longtitude 
ax.set_xticks(np.arange(-180,181,60),crs=ccrs.PlateCarree())
lon_formatter=cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)

# Define ytick for latitude
ax.set_yticks(np.arange(-90,91,30),crs=ccrs.PlateCarree())
lat_formatter=cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)

ax.set_extent([-124.5,-66.8,23.486,49])
ax.coastlines()
ax.gridlines()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')

# Call colorbar
cbar=plt.colorbar(cs,orientation='horizontal',shrink=0.7,
                 label='Percentage')

# Add title
plt.title('Median snowfall (late period)')
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/janmedian_totalsnow_lateperiod.png')

# %%
diff_jan=jan_ts_values_med_last-jan_ts_values_med
diff_jan
# Out:
# <xarray.DataArray 'PRECSNO' (lat: 66, lon: 120)>
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        ...,
#        [-2.79495227e-07, -3.78766827e-03,  3.18185557e-01, ...,
#          1.61133314e-02, -1.01044105e-02,  5.37615269e-03],
#        [-3.39577966e-06,  9.57645744e-01,  1.03289271e+00, ...,
#          2.55933031e-02,  5.63529298e-02,  6.70236885e-02],
#        [ 8.79610592e-01,  1.86965391e+00,  1.02035254e+00, ...,
#          2.94154510e-02,  8.59074877e-02,  9.56247328e-02]])
# Coordinates:
#   * lon       (lon) float64 -128.1 -127.5 -126.9 -126.2 ... -55.0 -54.38 -53.75
# ...

# %%
fig = plt.figure(figsize=(11,8.5))
max_val=1
increment=0.2

clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree(central_longitude=180))

# Add cyclic point
data=diff_jan[:,:]
#data,lon=add_cyclic_point(data,coord=data['lon'])
#mask_data,lons=add_cyclic_point(mask_sig,coord=jan_ts['lon'])

# Make a filled contour plot
cs=ax.contourf(jan_ts_values_med_last['lon'],jan_ts_values_med_last['lat'],
            data,clevs,
            transform=ccrs.PlateCarree(),
            cmap='bwr',extend='both')

#ax.contourf(lon,jan_ts['lat'],mask_data,[0,1],
 #           transform = ccrs.PlateCarree(),colors='None',
  #          hatches=['.','.'],extend='both',alpha=0)
# Define the xticks for longtitude 
ax.set_xticks(np.arange(-180,181,60),crs=ccrs.PlateCarree())
lon_formatter=cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)

# Define ytick for latitude
ax.set_yticks(np.arange(-90,91,30),crs=ccrs.PlateCarree())
lat_formatter=cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)

ax.set_extent([-124.5,-66.8,23.486,49])
ax.coastlines()
ax.gridlines()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')

# Call colorbar
cbar=plt.colorbar(cs,orientation='horizontal',shrink=0.7,
                 label='Percentage')

# Add title
plt.title('Median snowfall difference (late-early period)')
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/janmedian_totalsnow_diff.png')

# %%
ratio_median_jan_last=(m_array_jan/jan_ts_values_med_last)*100*21
ratio_median_jan_last
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/xarray/core/computation.py:739: RuntimeWarning: divide by zero encountered in true_divide
#   result_data = func(*input_data)
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/xarray/core/computation.py:739: RuntimeWarning: invalid value encountered in true_divide
#   result_data = func(*input_data)
# <xarray.DataArray 'PRECSNO' (lat: 66, lon: 120)>
# array([[            nan,             nan,             nan, ...,
#                     nan,             nan,             nan],
#        [            nan,             nan,             nan, ...,
#                     nan,             nan,             nan],
#        [            nan,             nan,             nan, ...,
#                     nan,             nan,             nan],
#        ...,
#        [ 0.00000000e+00, -1.63829127e-11,  1.03251695e+01, ...,
#         -3.75292176e+01, -4.95284477e+01, -7.99735878e+01],
# ...

# %%
fig = plt.figure(figsize=(11,8.5))
max_val=100.0
increment=20

clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree(central_longitude=180))

# Add cyclic point
data=ratio_median_jan_last[:,:]
data,lon=add_cyclic_point(data,coord=jan_ts_values_med_last['lon'])
#mask_data,lons=add_cyclic_point(mask_sig,coord=jan_ts['lon'])

# Make a filled contour plot
cs=ax.contourf(lon,jan_ts_values_med_last['lat'],
            data,clevs,
            transform=ccrs.PlateCarree(),
            cmap='bwr',extend='both')

#ax.contourf(lon,jan_ts['lat'],mask_data,[0,1],
 #           transform = ccrs.PlateCarree(),colors='None',
  #          hatches=['.','.'],extend='both',alpha=0)
# Define the xticks for longtitude 
ax.set_xticks(np.arange(-180,181,60),crs=ccrs.PlateCarree())
lon_formatter=cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)

# Define ytick for latitude
ax.set_yticks(np.arange(-90,91,30),crs=ccrs.PlateCarree())
lat_formatter=cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)

ax.set_extent([-124.5,-66.8,23.486,49])
ax.coastlines()
ax.gridlines()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')

# Call colorbar
cbar=plt.colorbar(cs,orientation='horizontal',shrink=0.7,
                 label='Percentage')

# Add title
plt.title('Percentage of trend of Median to mean Median values of Janurary Snowfall over CONUS over 2001-2022 period')
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/janmedian_snowtrend_lateperiod.png')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:782: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   return super(GeoAxes, self).set_xticks(xticks, minor)
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:829: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   return super(GeoAxes, self).set_yticks(yticks, minor)
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:388: MatplotlibDeprecationWarning:
# ...

# %% [markdown]
# ### Adding significance hatch marks

# %%
mask_sig=np.where(((low_ci<=0) & (high_ci<=0))|((low_ci>=0) & (high_ci>=0)),ratio_median_jan_last,np.nan) #if CI includes 0, then not significant. If CI doesn't then significant.
mask_sig
# Out:
# array([[         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        ...,
#        [  0.        ,          nan,          nan, ...,          nan,
#                  nan, -79.97358781],
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ...,          nan,
#         -56.55236113, -95.07592451]])

# %%
fig = plt.figure(figsize=(11,8.5))
max_val=100.0
increment=20

clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree(central_longitude=180))

# Add cyclic point
data=ratio_median_jan_last[:,:]
data,lon=add_cyclic_point(data,coord=jan_ts_values_med_last['lon'])
mask_data,lons=add_cyclic_point(mask_sig,coord=jan_ts_values_med_last['lon'])

# Make a filled contour plot
cs=ax.contourf(lon,jan_ts_values_med_last['lat'],
            data,clevs,
            transform=ccrs.PlateCarree(),
            cmap='bwr',extend='both')

ax.contourf(lon,jan_ts_values_med_last['lat'],mask_data,[0,1],
            transform = ccrs.PlateCarree(),colors='None',
            hatches=['.','.'],extend='both',alpha=0)
# Define the xticks for longtitude 
ax.set_xticks(np.arange(-180,181,60),crs=ccrs.PlateCarree())
lon_formatter=cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)

# Define ytick for latitude
ax.set_yticks(np.arange(-90,91,30),crs=ccrs.PlateCarree())
lat_formatter=cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)

ax.set_extent([-124.5,-66.8,23.486,49])
ax.coastlines()
ax.gridlines()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')

# Call colorbar
cbar=plt.colorbar(cs,orientation='horizontal',shrink=0.7,
                 label='Percentage')

# Add title
plt.title('Percentage of trend of Median to mean Median values of Janurary Snowfall over CONUS over 2001-2022 period')
#plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/janmedian_snowtrend_lateperiod.png')
# Out:
# Text(0.5, 1.0, 'Percentage of trend of Median to mean Median values of Janurary Snowfall over CONUS over 2001-2022 period')

# %% [markdown]
# ## Calculations of Total Energy Transport (No filter)

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
#from intake import open_catalog
import cartopy.io.shapereader as shpreader
import mygrads as mg
#import Ngl
#import Nio
#import fiona
import matplotlib as mpl
import cartopy.mpl.ticker as cticker
from cartopy.util import add_cyclic_point
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from cartopy.feature import NaturalEarthFeature
from cartopy.feature import COASTLINE
#from clim680_function import xyticks
import pymannkendall as mk

# %% [markdown]
# ### Fix levels at low levels (850mb) and upper levels (300mb)

# %%
f = '/project/xprecip/merra2_ncfiles/temp_pressurelevels/850/calculated/temp_850_winter.nc'
DS=xr.open_dataset(f)
temp=DS['T']
temp
# Out:
# <xarray.DataArray 'T' (time: 15760, lat: 361, lon: 576)>
# [3277071360 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2023-02-28T18:00:00
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 -88.0 ... 88.5 89.0 89.5 90.0
#     lev      float64 ...
# Attributes:
#     standard_name:   air_temperature
#     long_name:       Air temperature
#     units:           K
#     fmissing_value:  1000000000000000.0
#     vmax:            1000000000000000.0
#     vmin:            -1000000000000000.0

# %%
f='/project/xprecip/merra2_ncfiles/winds/vwind_850_computed_4-14-23.nc'
DS_winds_850=xr.open_dataset(f)
#DS_winds_850
winter_selected_meridwind_850=DS_winds_850['V']
winter_selected_meridwind_850
# Out:
# <xarray.DataArray 'V' (time: 15400, lat: 55, lon: 113)>
# [95711000 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2022-02-28T18:00:00
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 ...
# Attributes:
#     standard_name:   northward_wind
#     long_name:       Northward wind component
#     units:           m/s
#     fmissing_value:  1000000000000000.0
#     vmax:            1000000000000000.0
#     vmin:            -1000000000000000.0

# %%
vclimo=winter_selected_meridwind_850.mean(dim='time')
vclimo
# Out:
# <xarray.DataArray 'V' (lat: 55, lon: 113)>
# array([[-2.2709541 , -2.36838   , -2.4584134 , ...,  0.50762856,
#          0.46681783,  0.43298322],
#        [-2.3635316 , -2.4691207 , -2.566633  , ...,  0.5938745 ,
#          0.5480109 ,  0.5120406 ],
#        [-2.451161  , -2.5641503 , -2.6700354 , ...,  0.68229043,
#          0.6365874 ,  0.5980475 ],
#        ...,
#        [ 4.990153  ,  4.5417686 ,  4.5846643 , ...,  0.5667625 ,
#         -0.10074187, -0.2288651 ],
#        [ 4.843831  ,  3.6429648 ,  1.4123408 , ...,  0.37715444,
#          0.06506082, -0.41620177],
#        [ 1.3643906 ,  0.01985777,  1.0794904 , ..., -0.44385362,
#         -0.40662727, -0.44259277]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 850.0

# %%
vclimo=vclimo[0,:,:]
vclimo
# Out:
# <xarray.DataArray 'V' (lat: 55, lon: 113)>
# array([[-2.2709541 , -2.36838   , -2.4584134 , ...,  0.50762856,
#          0.46681783,  0.43298322],
#        [-2.3635316 , -2.4691207 , -2.566633  , ...,  0.5938745 ,
#          0.5480109 ,  0.5120406 ],
#        [-2.451161  , -2.5641503 , -2.6700354 , ...,  0.68229043,
#          0.6365874 ,  0.5980475 ],
#        ...,
#        [ 4.990153  ,  4.5417686 ,  4.5846643 , ...,  0.5667625 ,
#         -0.10074187, -0.2288651 ],
#        [ 4.843831  ,  3.6429648 ,  1.4123408 , ...,  0.37715444,
#          0.06506082, -0.41620177],
#        [ 1.3643906 ,  0.01985777,  1.0794904 , ..., -0.44385362,
#         -0.40662727, -0.44259277]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 850.0
#     season   <U3 'DJF'

# %%
# Make the figure larger
fig = plt.figure(figsize=(11,8.5))

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree())
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')

# Add cyclic point to data
data=vclimo[:,:]
#data, lons = add_cyclic_point(data, coord=slp_filt['lon'])
max_val=6.0
increment=1
clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
# Make a filled contour plot
cs=ax.contourf(vclimo['lon'], vclimo['lat'], data,clevs,
            transform = ccrs.PlateCarree(),cmap='coolwarm',extend='both')
ax.contour(vclimo['lon'],vclimo['lat'],data,clevs,transform=ccrs.PlateCarree(),linewidths=1,colors='k')
# Add coastlines
ax.coastlines()
ax.set_extent([-124.5,-66.8,23.486,49])

# Add gridlines
ax.gridlines()

# Add colorbar
cbar = plt.colorbar(cs,shrink=0.7,orientation='horizontal',label='V component total')

# Add title
#plt.title('Total Sensible Heat Transport  at 850mb')
#plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/vtprime_conusclimo_merra.png')

# %%
temp_conus=temp.sel(lat=slice(24.5,51.5),lon=slice(-126.25,-56.25))
temp_conus
# Out:
# <xarray.DataArray 'T' (time: 15760, lat: 55, lon: 113)>
# array([[[287.03214, 287.1228 , ..., 284.9792 , 284.8532 ],
#         [286.76764, 286.7195 , ..., 284.76532, 284.84998],
#         ...,
#         [270.9205 , 271.94412, ..., 268.32068, 268.45425],
#         [272.57166,       nan, ..., 268.89127, 268.7347 ]],
#
#        [[287.44424, 287.57733, ..., 284.23346, 284.24158],
#         [287.10785, 287.1544 , ..., 284.35797, 284.1871 ],
#         ...,
#         [272.945  , 273.56485, ..., 268.78537, 268.611  ],
#         [272.89465,       nan, ..., 268.85257, 268.66327]],
#
#        ...,
#
#        [[281.63644, 281.9635 , ..., 286.09427, 286.02036],
#         [280.98657, 281.36447, ..., 286.05835, 286.05096],
#         ...,
#         [266.2481 , 266.8053 , ..., 250.1538 , 250.58202],
#         [      nan,       nan, ..., 250.33241, 250.50264]],
#
#        [[281.54715, 281.691  , ..., 285.57413, 285.48672],
#         [280.6721 , 280.73615, ..., 285.2839 , 285.2066 ],
#         ...,
# ...

# %%
temp_early=temp_conus.sel(time=slice('1980-12-01','2001-02-28')).mean(dim='time')
temp_late=temp_conus.sel(time=slice('2001-12-01','2022-02-28')).mean(dim='time')
vclimo_early=winter_selected_meridwind_850.sel(time=slice('1980-12-01','2001-02-28')).mean(dim='time')
vclimo_late=winter_selected_meridwind_850.sel(time=slice('2001-12-01','2022-02-28')).mean(dim='time')

# %%
sh_early=temp_early*vclimo_early*1004
sh_late=temp_late*vclimo_late*1004
sh_diff=sh_late-sh_early
sh_diff
# Out:
# <xarray.DataArray (lat: 55, lon: 113)>
# array([[ -91428.625 ,  -82971.375 ,  -72820.56  , ...,  -96125.94  ,
#          -99128.7   , -102572.41  ],
#        [ -97288.81  ,  -86628.375 ,  -75422.75  , ...,  -97579.81  ,
#          -99175.09  ,  -99125.914 ],
#        [-102629.125 ,  -92670.    ,  -81744.44  , ...,  -97300.28  ,
#          -99097.42  ,  -96365.73  ],
#        ...,
#        [-112258.375 , -107985.25  ,  -96010.375 , ...,  -77920.13  ,
#          -75351.84  ,  -70782.086 ],
#        [ -96051.25  ,  -70976.625 ,  -23831.594 , ...,  -92233.97  ,
#          -80235.95  ,  -69535.76  ],
#        [  -1436.9062,  119014.734 , -143376.53  , ..., -124840.53  ,
#         -105518.02  ,  -83896.984 ]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 850.0

# %%
sh_early.to_netcdf('/project/xprecip/merra2_ncfiles/energy_calcs/corrections/sh_total_early850.nc')
sh_late.to_netcdf('/project/xprecip/merra2_ncfiles/energy_calcs/corrections/sh_total_late850.nc')

# %%
temp_overbar=temp_conus.mean(dim='time')
temp_overbar
# Out:
# <xarray.DataArray 'T' (lat: 55, lon: 113)>
# array([[283.73685, 283.8403 , 283.94662, ..., 284.9865 , 284.93735,
#         284.88492],
#        [283.5652 , 283.66513, 283.7649 , ..., 284.83017, 284.78287,
#         284.73633],
#        [283.39044, 283.49036, 283.5935 , ..., 284.65836, 284.61688,
#         284.5745 ],
#        ...,
#        [271.14145, 270.83234, 270.5658 , ..., 261.37076, 261.3389 ,
#         262.00394],
#        [270.60156, 270.52713, 269.66144, ..., 261.0849 , 261.2806 ,
#         261.57898],
#        [269.554  , 268.24017, 269.54797, ..., 260.86707, 261.1132 ,
#         261.27182]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 850.0

# %%
sh850=temp_overbar*vclimo*1004
sh850
# Out:
# <xarray.DataArray (lat: 55, lon: 113)>
# array([[-646930.8  , -674930.7  , -700850.4  , ...,  145245.97 ,
#          133545.89 ,  123843.79 ],
#        [-672896.1  , -703205.06 , -731233.6  , ...,  169830.   ,
#          156688.38 ,  146379.75 ],
#        [-697414.1  , -729819.5  , -760233.5  , ...,  194996.56 ,
#          181908.25 ,  170869.81 ],
#        ...,
#        [1358449.4  , 1234978.   , 1245415.1  , ...,  148727.69 ,
#          -26433.082,  -60203.414],
#        [1315991.2  ,  989462.9  ,  382377.28 , ...,   98863.21 ,
#           17067.129, -109305.12 ],
#        [ 369248.03 ,    5347.958,  292138.34 , ..., -116249.94 ,
#         -106600.445, -116099.56 ]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 850.0

# %%
print(sh_dropnans.nbytes/1e9,"GB")
# Out:
# 2.32390656 GB

# %% [markdown]
# ### I. Sensible Heat Transport (cpVT)

# %%
# Make the figure larger
fig = plt.figure(figsize=(11,8.5))

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree())
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')

# Add cyclic point to data
data=sh_diff[:,:]
#data, lons = add_cyclic_point(data, coord=slp_filt['lon'])
max_val=2e5
increment=0.5e5
clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
#clevs2=np.arange(-6,7,1)
# Make a filled contour plot
cs=ax.contourf(sh_diff['lon'], sh_diff['lat'], data,clevs,
            transform = ccrs.PlateCarree(),cmap='BrBG',extend='both')
#ax.contour(vclimo['lon'],vclimo['lat'],vclimo,clevs2,transform=ccrs.PlateCarree(),linewidths=1,colors='k')
#ax.quiver(vclimo['lon'], vclimo['lat'], vclimo[0,:].values,,minlength=0.1, scale_units='xy',scale=0.0001, transform=ccrs.PlateCarree(), color='k',width=0.002)
# Add coastlines
ax.coastlines()
ax.set_extent([-124.5,-66.8,23.486,49])

# Add gridlines
ax.gridlines()

# Add colorbar
cbar = plt.colorbar(cs,shrink=0.7,orientation='horizontal',label='cpVT_overbar difference')

# Add title
plt.title('Difference in 850mb sensible heat transport (late-early period)')
#plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/vttotal_conusclimo_merra_difference.png')
# Out:
# Text(0.5, 1.0, 'Difference in 850mb sensible heat transport (late-early period)')
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:388: MatplotlibDeprecationWarning:
# The 'inframe' parameter of draw() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use Axes.redraw_in_frame() instead. If any parameter follows 'inframe', they should be passed as keyword, not positionally.
#   inframe=inframe)

# %%
sh_diff.to_netcdf('/project/xprecip/merra2_ncfiles/energy_calcs/corrections/sh_diff_total850.nc')

# %%
shtotal_climo=sh_total.mean(dim='time')
shtotal_climo
# Out:
# <xarray.DataArray (lat: 55, lon: 113)>
# array([[-644161.2   , -672322.75  , -698401.    , ...,  148575.08  ,
#          136801.78  ,  127034.61  ],
#        [-670036.5   , -700519.    , -728724.06  , ...,  173541.4   ,
#          160320.    ,  149927.83  ],
#        [-694442.3   , -727038.    , -757629.2   , ...,  199117.86  ,
#          185936.61  ,  174819.81  ],
#        ...,
#        [1367595.    , 1242338.8   , 1252119.2   , ...,  171388.84  ,
#           -3572.7405,  -37316.438 ],
#        [1322879.4   ,  995666.44  ,  388150.22  , ...,  117491.75  ,
#           37713.77  ,  -87573.31  ],
#        [ 375433.9   ,    8213.18  ,  295107.06  , ..., -101956.52  ,
#          -92001.67  ,  -99265.04  ]], dtype=float32)
# Coordinates:
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#     lev      float64 850.0

# %%
# Make the figure larger
fig = plt.figure(figsize=(11,8.5))

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree())
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')

# Add cyclic point to data
data=sh850[:,:]
#data, lons = add_cyclic_point(data, coord=slp_filt['lon'])
max_val=1600000
increment=200000
clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
clevs2=np.arange(-6,7,1)
# Make a filled contour plot
cs=ax.contourf(sh850['lon'], sh850['lat'], data,clevs,
            transform = ccrs.PlateCarree(),cmap='coolwarm',extend='both')
ax.contour(vclimo['lon'],vclimo['lat'],vclimo,clevs2,transform=ccrs.PlateCarree(),linewidths=1,colors='k')
#ax.quiver(vclimo['lon'], vclimo['lat'], vclimo[0,:].values,,minlength=0.1, scale_units='xy',scale=0.0001, transform=ccrs.PlateCarree(), color='k',width=0.002)
# Add coastlines
ax.coastlines()
ax.set_extent([-124.5,-66.8,23.486,49])

# Add gridlines
ax.gridlines()

# Add colorbar
cbar = plt.colorbar(cs,shrink=0.7,orientation='horizontal',label='cpVT_overbar')

# Add title
plt.title('Total Sensible Heat Transport  at 850mb')
#plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/vttotal_conusclimo_merra.png')
# Out:
# Text(0.5, 1.0, 'Total Sensible Heat Transport  at 850mb')

# %%
sh850.to_netcdf('/project/xprecip/merra2_ncfiles/energy_calcs/corrections/shtotal_climo850.nc')

# %%
#Caption: DJF 1980-2022 climatology of total sensible heat transport at 850mb .Contours represent v wind component climatology also for DJF 1980-2022,
#solid lines represent net northward transport, dashed represent net southward transport

# %% [markdown]
# ### II. Latent heat Transport (LvQ)

# %%
f = '/project/xprecip/merra2_ncfiles/spec_hum/spec_hum_preslev/spechum_wintercomputed.nc'
DS=xr.open_dataset(f)
DS
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 361, lev: 2, lon: 576, time: 15760)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2023-02-28T18:00:00
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 -88.0 ... 88.5 89.0 89.5 90.0
#   * lev      (lev) float64 850.0 300.0
# Data variables:
#     QV       (time, lev, lat, lon) float32 ...

# %%
qv=DS['QV']
qv
# Out:
# <xarray.DataArray 'QV' (time: 15760, lev: 2, lat: 361, lon: 576)>
# [6554142720 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2023-02-28T18:00:00
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 -88.0 ... 88.5 89.0 89.5 90.0
#   * lev      (lev) float64 850.0 300.0
# Attributes:
#     standard_name:   specific_humidity
#     long_name:       Specific humidity
#     units:           kg/kg
#     fmissing_value:  1000000000000000.0
#     vmax:            1000000000000000.0
#     vmin:            -1000000000000000.0

# %%
qv_850=qv.sel(lev=850)
qv_300=qv.sel(lev=300)
qv_850
# Out:
# <xarray.DataArray 'QV' (time: 15760, lat: 361, lon: 576)>
# [3277071360 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2023-02-28T18:00:00
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 -88.0 ... 88.5 89.0 89.5 90.0
#     lev      float64 850.0
# Attributes:
#     standard_name:   specific_humidity
#     long_name:       Specific humidity
#     units:           kg/kg
#     fmissing_value:  1000000000000000.0
#     vmax:            1000000000000000.0
#     vmin:            -1000000000000000.0

# %%
winter_climo=qv_850.mean(dim='time').compute()
winter_climo
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# <xarray.DataArray 'QV' (lat: 361, lon: 576)>
# array([[       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        ...,
#        [0.00053106, 0.00053096, 0.00053087, ..., 0.00053136, 0.00053126,
#         0.00053116],
#        [0.00053665, 0.00053659, 0.00053654, ..., 0.00053683, 0.00053677,
#         0.00053671],
#        [0.00054248, 0.00054248, 0.00054248, ..., 0.00054248, 0.00054248,
#         0.00054248]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
# ...

# %%
# Make the figure larger
fig = plt.figure(figsize=(11,8.5))

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.Robinson())

# Add cyclic point to data
#data=qv_850[0,:,:]
data=winter_climo
#data, lons = add_cyclic_point(data, coord=slp_filt['lon'])
#max_val=24
#increment=4
#clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
# Make a filled contour plot
cs=ax.contourf(qv_850['lon'], qv_850['lat'], data,
            transform = ccrs.PlateCarree(),cmap='YlOrRd',extend='both')
ax.contour(qv_850['lon'],qv_850['lat'],data,transform=ccrs.PlateCarree(),linewidths=0.5,colors='k')
# Add coastlines
ax.coastlines()

# Add gridlines
ax.gridlines()

# Add colorbar
cbar = plt.colorbar(cs,shrink=0.7,orientation='horizontal',label='qv850mb')

# Add title
plt.title('850mb specific humidity winter climo')
#plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/vtprime_globalclimo_ERA.png')
# Out:
# Text(0.5, 1.0, '850mb specific humidity winter climo')

# %%
qv_sametime=qv_850.sel(time=slice('1980-01-01','2022-02-28'))
qv_sametime
# Out:
# <xarray.DataArray 'QV' (time: 15400, lat: 361, lon: 576)>
# [3202214400 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2022-02-28T18:00:00
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 -88.0 ... 88.5 89.0 89.5 90.0
#     lev      float64 850.0
# Attributes:
#     standard_name:   specific_humidity
#     long_name:       Specific humidity
#     units:           kg/kg
#     fmissing_value:  1000000000000000.0
#     vmax:            1000000000000000.0
#     vmin:            -1000000000000000.0

# %%
qv_same=qv_sametime.sel(lat=slice(24.5,51.5),lon=slice(-126.25,-56.25))
qv_same
# Out:
# <xarray.DataArray 'QV' (time: 15400, lat: 55, lon: 113)>
# [95711000 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2022-02-28T18:00:00
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 850.0
# Attributes:
#     standard_name:   specific_humidity
#     long_name:       Specific humidity
#     units:           kg/kg
#     fmissing_value:  1000000000000000.0
#     vmax:            1000000000000000.0
#     vmin:            -1000000000000000.0

# %%
qv_same_early=qv_same.sel(time=slice('1980-12-01','2001-02-28')).mean(dim='time')
qv_same_late=qv_same.sel(time=slice('2001-12-01','2022-02-28')).mean(dim='time')
vclimo_early=winter_selected_meridwind_850.sel(time=slice('1980-12-01','2001-02-28')).mean(dim='time')
vclimo_late=winter_selected_meridwind_850.sel(time=slice('2001-12-01','2022-02-28')).mean(dim='time')

# %%
qv_overbar_early=qv_same_early*vclimo_early*2260000
qv_overbar_late=qv_same_late*vclimo_late*2260000
latent_diff=qv_overbar_late-qv_overbar_early

# %%
qv_overbar_early.to_netcdf('/project/xprecip/merra2_ncfiles/energy_calcs/corrections/lh_totalearly850.nc')
qv_overbar_late.to_netcdf('/project/xprecip/merra2_ncfiles/energy_calcs/corrections/lh_totallate850.nc')

# %%
qmean=qv_same.mean(dim='time')
qmean
# Out:
# <xarray.DataArray 'QV' (lat: 55, lon: 113)>
# array([[0.00358128, 0.00348793, 0.00339643, ..., 0.00721208, 0.00718646,
#         0.00716216],
#        [0.00350795, 0.00342139, 0.00333847, ..., 0.00713687, 0.00711463,
#         0.00709313],
#        [0.00344979, 0.00336132, 0.00328143, ..., 0.00706121, 0.00704416,
#         0.00702388],
#        ...,
#        [0.00292794, 0.00290519, 0.00287645, ..., 0.00146651, 0.00148206,
#         0.0014974 ],
#        [0.00287766, 0.002771  , 0.00262631, ..., 0.00140636, 0.00143328,
#         0.00144582],
#        [0.00258199, 0.00225077, 0.00176092, ..., 0.00133684, 0.00136522,
#         0.00139486]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 850.0

# %%
total_latent_850=vclimo*qmean*2260000 #2260 J/g or 2260000 J/kg
total_latent_850
# Out:
# <xarray.DataArray (lat: 55, lon: 113)>
# array([[-18380.3942427 , -18669.27022114, -18870.62065303, ...,
#           8273.98614492,   7581.77997079,   7008.47069733],
#        [-18737.99579218, -19092.06340089, -19365.10715634, ...,
#           9578.79484631,   8811.50558591,   8208.25726725],
#        [-19110.51187664, -19478.76155376, -19801.04474351, ...,
#          10888.22513819,  10134.34864581,   9493.38356033],
#        ...,
#        [ 33020.55524662,  29819.98570263,  29803.89669538, ...,
#           1878.42829968,   -337.43129054,   -774.50848941],
#        [ 31501.89945474,  22813.93235549,   8382.89476931, ...,
#           1198.73614865,    210.74619362,  -1359.96127734],
#        [  7961.63229737,    101.01145599,   4296.01777578, ...,
#          -1341.00028547,  -1254.60619456,  -1395.22109763]])
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
# ...

# %%
total_latent_850.to_netcdf('/project/xprecip/merra2_ncfiles/energy_calcs/corrections/lh_climo_total850.nc')

# %%
latent_diff.to_netcdf('/project/xprecip/merra2_ncfiles/energy_calcs/corrections/lh_diff_total850.nc')

# %%
# Make the figure larger
fig = plt.figure(figsize=(11,8.5))

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree())
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')

# Add cyclic point to data
data=latent_diff[:,:]
#data, lons = add_cyclic_point(data, coord=slp_filt['lon'])
max_val=15000
increment=2500
clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
#clevs2=np.arange(-6,7,1)
# Make a filled contour plot
cs=ax.contourf(latent_diff['lon'], latent_diff['lat'], data,clevs,
            transform = ccrs.PlateCarree(),cmap='BrBG',extend='both')
#ax.contour(vclimo['lon'],vclimo['lat'],vclimo,clevs2,transform=ccrs.PlateCarree(),linewidths=1,colors='k')
#ax.quiver(vclimo['lon'], vclimo['lat'], vclimo[0,:].values,,minlength=0.1, scale_units='xy',scale=0.0001, transform=ccrs.PlateCarree(), color='k',width=0.002)
# Add coastlines
ax.coastlines()
ax.set_extent([-124.5,-66.8,23.486,49])

# Add gridlines
ax.gridlines()

# Add colorbar
cbar = plt.colorbar(cs,shrink=0.7,orientation='horizontal',label='LqV_overbar difference')

# Add title
plt.title('Difference in 850mb latent heat transport (late-early period)')
#plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/vqtotal_conusclimo_merra_difference.png')
# Out:
# Text(0.5, 1.0, 'Difference in 850mb latent heat transport (late-early period)')
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:388: MatplotlibDeprecationWarning:
# The 'inframe' parameter of draw() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use Axes.redraw_in_frame() instead. If any parameter follows 'inframe', they should be passed as keyword, not positionally.
#   inframe=inframe)

# %%
#latent_chunks=latentclimo_850.chunk(chunks={'lat':5,'lon':10})
#latent_chunks

# %%
# Make the figure larger
fig = plt.figure(figsize=(11,8.5))

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree())
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')
ax.set_extent([-124.5,-66.8,23.486,49])
# Add cyclic point to data
data=total_latent_850[:,:]
#data, lons = add_cyclic_point(data, coord=slp_filt['lon'])
max_val=100000
increment=25000
clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
clevs2=np.arange(-6,7,1)
# Make a filled contour plot
cs=ax.contourf(total_latent_850['lon'], total_latent_850['lat'], data,clevs,
            transform = ccrs.PlateCarree(),cmap='coolwarm',extend='both')
ax.contour(vclimo['lon'],vclimo['lat'],vclimo,clevs2,transform=ccrs.PlateCarree(),linewidths=1,colors='k')
# Add coastlines
ax.coastlines()

# Add gridlines
ax.gridlines()

# Add colorbar
cbar = plt.colorbar(cs,shrink=0.7,orientation='horizontal',label='LvqV_overbar')

# Add title
plt.title('Total Latent Heat Transport winter climatology at 850mb')
#plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/Lvq_conusclimo_merra.png')
# Out:
# Text(0.5, 1.0, 'Total Latent Heat Transport winter climatology at 850mb')
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:388: MatplotlibDeprecationWarning:
# The 'inframe' parameter of draw() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use Axes.redraw_in_frame() instead. If any parameter follows 'inframe', they should be passed as keyword, not positionally.
#   inframe=inframe)

# %% [markdown]
# ### III. Geopotential Flux (g*v*Z)

# %%
f = '/project/xprecip/merra2_ncfiles/geo_height/*.nc'
DS=xr.open_mfdataset(f,combine='nested',concat_dim='time')
DS
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 361, lev: 2, lon: 576, time: 63168)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2021-09-30T18:00:00
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 -88.0 ... 88.5 89.0 89.5 90.0
#   * lev      (lev) float64 850.0 300.0
# Data variables:
#     H        (time, lev, lat, lon) float32 dask.array<chunksize=(4, 2, 361, 576), meta=np.ndarray>
# Attributes: (12/32)
#     CDI:                               Climate Data Interface version 1.9.8 (...
#     Conventions:                       CF-1
#     History:                           Original file generated: Thu Jun 19 11...
#     Comment:                           GMAO filename: d5124_m2_jan79.inst6_3d...
#     Filename:                          MERRA2_100.inst6_3d_ana_Np.19800101.nc4
#     Institution:                       NASA Global Modeling and Assimilation ...
# ...

# %%
winter_only_height=DS['H'].isel(time=DS.time.dt.season.isin(['DJF']))
winter_only_height
# Out:
# <xarray.DataArray 'H' (time: 15760, lev: 2, lat: 361, lon: 576)>
# dask.array<getitem, shape=(15760, 2, 361, 576), dtype=float32, chunksize=(4, 2, 361, 576), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2023-02-28T18:00:00
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 -88.0 ... 88.5 89.0 89.5 90.0
#   * lev      (lev) float64 850.0 300.0
# Attributes:
#     standard_name:   geopotential_height
#     long_name:       Geopotential height
#     units:           m
#     fmissing_value:  1000000000000000.0
#     vmax:            1000000000000000.0
#     vmin:            -1000000000000000.0

# %%
z_850=winter_only_height.sel(lev=850)
z_300=winter_only_height.sel(lev=300)
z_850
# Out:
# <xarray.DataArray 'H' (time: 15760, lat: 361, lon: 576)>
# dask.array<getitem, shape=(15760, 361, 576), dtype=float32, chunksize=(4, 361, 576), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2023-02-28T18:00:00
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 -88.0 ... 88.5 89.0 89.5 90.0
#     lev      float64 850.0
# Attributes:
#     standard_name:   geopotential_height
#     long_name:       Geopotential height
#     units:           m
#     fmissing_value:  1000000000000000.0
#     vmax:            1000000000000000.0
#     vmin:            -1000000000000000.0

# %%
z_conus=z_850.sel(time=slice('1980-01-01','2022-02-28'),lat=slice(24.5,51.5),lon=slice(-126.25,-56.25))
z_conus
# Out:
# <xarray.DataArray 'H' (time: 15400, lat: 55, lon: 113)>
# dask.array<getitem, shape=(15400, 55, 113), dtype=float32, chunksize=(4, 55, 113), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2022-02-28T18:00:00
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 850.0
# Attributes:
#     standard_name:   geopotential_height
#     long_name:       Geopotential height
#     units:           m
#     fmissing_value:  1000000000000000.0
#     vmax:            1000000000000000.0
#     vmin:            -1000000000000000.0

# %%
geo_flux_850=winter_selected_meridwind_850*z_conus
geo_flux_850
# Out:
# <xarray.DataArray (time: 15400, lat: 55, lon: 113)>
# dask.array<multiply, shape=(15400, 55, 113), dtype=float32, chunksize=(4, 55, 113), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2022-02-28T18:00:00
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 850.0

# %%
geo_early=geo_flux_850.sel(time=slice('1980-12-01','2001-02-28'))
geo_late=geo_flux_850.sel(time=slice('2001-12-01','2022-02-28'))
geo_early_climo=geo_early.mean(dim='time')
geo_late_climo=geo_late.mean(dim='time')
geo_diff=geo_late_climo-geo_early_climo

# %%
geo_diff.to_netcdf('/project/xprecip/merra2_ncfiles/energy_calcs/geo_diff_total.nc')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
# Make the figure larger
fig = plt.figure(figsize=(11,8.5))

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree())
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')

# Add cyclic point to data
data=geo_diff[:,:]
#data, lons = add_cyclic_point(data, coord=slp_filt['lon'])
max_val=2500
increment=500
clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
#clevs2=np.arange(-6,7,1)
# Make a filled contour plot
cs=ax.contourf(latent_diff['lon'], latent_diff['lat'], data,clevs,
            transform = ccrs.PlateCarree(),cmap='BrBG',extend='both')
#ax.contour(vclimo['lon'],vclimo['lat'],vclimo,clevs2,transform=ccrs.PlateCarree(),linewidths=1,colors='k')
#ax.quiver(vclimo['lon'], vclimo['lat'], vclimo[0,:].values,,minlength=0.1, scale_units='xy',scale=0.0001, transform=ccrs.PlateCarree(), color='k',width=0.002)
# Add coastlines
ax.coastlines()
ax.set_extent([-124.5,-66.8,23.486,49])

# Add gridlines
ax.gridlines()

# Add colorbar
cbar = plt.colorbar(cs,shrink=0.7,orientation='horizontal',label='LqV_overbar difference')

# Add title
plt.title('Difference in 850mb geopotential flux transport (late-early period)')
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/geototal_conusclimo_merra_difference.png')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:388: MatplotlibDeprecationWarning:
# The 'inframe' parameter of draw() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use Axes.redraw_in_frame() instead. If any parameter follows 'inframe', they should be passed as keyword, not positionally.
#   inframe=inframe)

# %%
geoflux_mean_850=geo_flux_850.mean(dim='time')
geoflux_mean_850
# Out:
# <xarray.DataArray (lat: 55, lon: 113)>
# dask.array<mean_agg-aggregate, shape=(55, 113), dtype=float32, chunksize=(55, 113), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#     lev      float64 850.0

# %%
geoflux_mean_850.to_netcdf('/project/xprecip/merra2_ncfiles/energy_calcs/geofluxtotal_mean_850.nc')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
# Make the figure larger
fig = plt.figure(figsize=(11,8.5))

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree())
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')
ax.set_extent([-124.5,-66.8,23.486,49])
# Add cyclic point to data
data=geoflux_mean_850[:,:]
#data, lons = add_cyclic_point(data, coord=slp_filt['lon'])
max_val=10000
increment=2500
clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
clevs2=np.arange(-6,7,1)
# Make a filled contour plot
cs=ax.contourf(geoflux_mean_850['lon'], geoflux_mean_850['lat'], data,clevs,
            transform = ccrs.PlateCarree(),cmap='coolwarm',extend='both')
ax.contour(vclimo['lon'],vclimo['lat'],vclimo,clevs2,transform=ccrs.PlateCarree(),linewidths=1,colors='k')
# Add coastlines
ax.coastlines()

# Add gridlines
ax.gridlines()

# Add colorbar
cbar = plt.colorbar(cs,shrink=0.7,orientation='horizontal',label='Vgz_overbar')

# Add title
plt.title('Total Geopotential flux Transport winter climatology at 850mb')
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/Vgz_conusclimo_merra.png')

# %%
#Dry static energy=sensible heat+geopotential flux
#Moist static energy=dry static energy +latent energy

# %%
dse=sh_total+geo_flux_850
dse
# Out:
# <xarray.DataArray (time: 15400, lat: 55, lon: 113)>
# array([[[  133031.08 ,  -229024.48 ,  -511019.84 , ...,   763867.8  ,
#            747065.   ,   807571.75 ],
#         [  181433.   ,  -221515.39 ,  -549351.   , ...,   937979.6  ,
#            874834.9  ,   888424.6  ],
#         [  277419.94 ,  -136383.72 ,  -526199.75 , ...,   936989.9  ,
#            972605.6  ,   943425.2  ],
#         ...,
#         [ 3894851.   ,  4220512.   ,  4090607.5  , ..., -4072039.5  ,
#          -4386250.5  , -4346719.   ],
#         [ 3368169.   ,  2098414.2  ,   645523.25 , ..., -4479453.5  ,
#          -4450157.   , -4484050.5  ],
#         [  294842.75 ,          nan,          nan, ..., -5360571.5  ,
#          -4945686.   , -4582513.   ]],
#
#        [[ -385251.5  ,  -692915.94 ,  -868168.3  , ...,   598673.7  ,
#            685858.7  ,   806789.44 ],
#         [ -300142.66 ,  -622332.06 ,  -867141.4  , ...,   754923.44 ,
#            768083.3  ,   851694.9  ],
# ...

# %%
dse_850_climo=dse.mean(dim='time')
dse_850_climo
# Out:
# <xarray.DataArray (lat: 55, lon: 113)>
# array([[-647671.44  , -675981.25  , -702192.9   , ...,  149366.12  ,
#          137529.89  ,  127709.05  ],
#        [-673693.06  , -704334.6   , -732693.2   , ...,  174467.61  ,
#          161174.72  ,  150727.11  ],
#        [-698239.8   , -731004.2   , -761754.2   , ...,  200182.97  ,
#          186930.05  ,  175753.2   ],
#        ...,
#        [1374471.1   , 1248621.    , 1258517.4   , ...,  172127.36  ,
#           -3674.5605,  -37561.87  ],
#        [1329644.5   , 1000775.5   ,  390199.34  , ...,  118006.34  ,
#           37828.117 ,  -88073.47  ],
#        [ 377404.34  ,    8245.899 ,  296864.75  , ..., -102451.13  ,
#          -92449.766 ,  -99770.414 ]], dtype=float32)
# Coordinates:
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#     lev      float64 850.0

# %%
# Make the figure larger
fig = plt.figure(figsize=(11,8.5))

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree())
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')
ax.set_extent([-124.5,-66.8,23.486,49])
# Add cyclic point to data
data=dse_850_climo[:,:]
#data, lons = add_cyclic_point(data, coord=slp_filt['lon'])
max_val=1600000
increment=400000
clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
clevs2=np.arange(-6,7,1)
# Make a filled contour plot
cs=ax.contourf(dse_850_climo['lon'], dse_850_climo['lat'], data,clevs,
            transform = ccrs.PlateCarree(),cmap='coolwarm',extend='both')
ax.contour(vclimo['lon'],vclimo['lat'],vclimo,clevs2,transform=ccrs.PlateCarree(),linewidths=1,colors='k')
# Add coastlines
ax.coastlines()

# Add gridlines
ax.gridlines()

# Add colorbar
cbar = plt.colorbar(cs,shrink=0.7,orientation='horizontal',label='DSE_overbar')

# Add title
plt.title('Total Dry Static Energy transport winter climatology at 850mb')
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/dse_conusclimo_merra.png')

# %%
mse=dse+totallatentchunks
mse
# Out:
# <xarray.DataArray (time: 15400, lat: 55, lon: 113)>
# dask.array<add, shape=(15400, 55, 113), dtype=float64, chunksize=(15400, 5, 10), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2022-02-28T18:00:00
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#     lev      float64 850.0

# %%
mse_850_climo=mse.mean(dim='time')
mse_850_climo
# Out:
# <xarray.DataArray (lat: 55, lon: 113)>
# dask.array<mean_agg-aggregate, shape=(55, 113), dtype=float64, chunksize=(5, 10), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#     lev      float64 850.0

# %%
# Make the figure larger
fig = plt.figure(figsize=(11,8.5))

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree())
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')
ax.set_extent([-124.5,-66.8,23.486,49])
# Add cyclic point to data
data=mse_850_climo[:,:]
#data, lons = add_cyclic_point(data, coord=slp_filt['lon'])
max_val=1600000
increment=400000
clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
clevs2=np.arange(-6,7,1)
# Make a filled contour plot
cs=ax.contourf(mse_850_climo['lon'], mse_850_climo['lat'], data,clevs,
            transform = ccrs.PlateCarree(),cmap='coolwarm',extend='both')
ax.contour(vclimo['lon'],vclimo['lat'],vclimo,clevs2,transform=ccrs.PlateCarree(),linewidths=1,colors='k')
# Add coastlines
ax.coastlines()

# Add gridlines
ax.gridlines()

# Add colorbar
cbar = plt.colorbar(cs,shrink=0.7,orientation='horizontal',label='MSE_overbar')

# Add title
plt.title('Total Moist Static Energy transport winter climatology at 850mb')
plt.savefig('/homes/areed29/CLIM997/summer22_research/Qualifier_Results/mse_conusclimo_merra.png')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:388: MatplotlibDeprecationWarning:
# The 'inframe' parameter of draw() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use Axes.redraw_in_frame() instead. If any parameter follows 'inframe', they should be passed as keyword, not positionally.
#   inframe=inframe)

# %% [markdown]
# ### Panel Plot

# %% [markdown]
# ### Repeat analysis for 300mb (upper levels)

# %%
f='/project/xprecip/merra2_ncfiles/winds/vwinds_preslevs_4-23/*.nc'
DS_winds=xr.open_mfdataset(f,combine='nested',concat_dim='time')
DS_winds
#DS_winds_850
#winter_selected_meridwind_850=DS_winds_850['V']
#winter_selected_meridwind_850
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 361, lev: 2, lon: 576, time: 59428)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2021-09-30T18:00:00
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 -88.0 ... 88.5 89.0 89.5 90.0
#   * lev      (lev) float64 850.0 300.0
# Data variables:
#     V        (time, lev, lat, lon) float32 dask.array<chunksize=(4, 2, 361, 576), meta=np.ndarray>
# Attributes: (12/32)
#     CDI:                               Climate Data Interface version 1.9.8 (...
#     Conventions:                       CF-1
#     History:                           Original file generated: Thu Jun 19 11...
#     Comment:                           GMAO filename: d5124_m2_jan79.inst6_3d...
#     Filename:                          MERRA2_100.inst6_3d_ana_Np.19800101.nc4
#     Institution:                       NASA Global Modeling and Assimilation ...
# ...

# %%
winds_winter=DS_winds['V'].isel(time=DS_winds.time.dt.season.isin(['DJF']))
winds_winter
# Out:
# <xarray.DataArray 'V' (time: 14936, lev: 2, lat: 361, lon: 576)>
# dask.array<getitem, shape=(14936, 2, 361, 576), dtype=float32, chunksize=(4, 2, 361, 576), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2023-02-28T18:00:00
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 -88.0 ... 88.5 89.0 89.5 90.0
#   * lev      (lev) float64 850.0 300.0
# Attributes:
#     standard_name:   northward_wind
#     long_name:       Northward wind component
#     units:           m/s
#     fmissing_value:  1000000000000000.0
#     vmax:            1000000000000000.0
#     vmin:            -1000000000000000.0

# %%
winds_300=winds_winter.sel(lev=300)
winds_300
# Out:
# <xarray.DataArray 'V' (time: 14936, lat: 361, lon: 576)>
# dask.array<getitem, shape=(14936, 361, 576), dtype=float32, chunksize=(4, 361, 576), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2023-02-28T18:00:00
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 -88.0 ... 88.5 89.0 89.5 90.0
#     lev      float64 300.0
# Attributes:
#     standard_name:   northward_wind
#     long_name:       Northward wind component
#     units:           m/s
#     fmissing_value:  1000000000000000.0
#     vmax:            1000000000000000.0
#     vmin:            -1000000000000000.0

# %%
winds_850=winds_winter.sel(lev=850)
winds_850
# Out:
# <xarray.DataArray 'V' (time: 14936, lat: 361, lon: 576)>
# dask.array<getitem, shape=(14936, 361, 576), dtype=float32, chunksize=(4, 361, 576), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2023-02-28T18:00:00
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 -88.0 ... 88.5 89.0 89.5 90.0
#     lev      float64 850.0
# Attributes:
#     standard_name:   northward_wind
#     long_name:       Northward wind component
#     units:           m/s
#     fmissing_value:  1000000000000000.0
#     vmax:            1000000000000000.0
#     vmin:            -1000000000000000.0

# %%
winds_300_loaded=winds_300.load()
winds_300_loaded.to_netcdf('/project/xprecip/merra2_ncfiles/winds/vwinds_preslevs_4-23/300/vwinds_300_winter.nc')

# %%
winds_850_loaded=winds_850.load()
winds_850_loaded.to_netcdf('/project/xprecip/merra2_ncfiles/winds/vwinds_preslevs_4-23/850/vwinds_850_winter.nc')

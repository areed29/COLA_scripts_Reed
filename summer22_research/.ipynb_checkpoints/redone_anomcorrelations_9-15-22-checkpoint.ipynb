# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
#from intake import open_catalog
import cartopy.io.shapereader as shpreader
#import mygrads as mg
#import Ngl
#import Nio
#import fiona
import matplotlib as mpl
import pymannkendall as mk
from cartopy.util import add_cyclic_point
import cartopy.mpl.ticker as cticker

# %% [markdown]
# ### Precip

# %% [markdown]
# ### 00z

# %%
DS_0_precip=xr.open_dataset('/project/xprecip/merra2_ncfiles/precip/anomalies/norm_anoms_precip_00z_corrected.nc')
DS_0_precip
# Out:
# <xarray.Dataset>
# Dimensions:      (hour: 1, lat: 55, lon: 107, time: 3760)
# Coordinates:
#   * time         (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2021-02-28
#   * lon          (lon) float64 -126.9 -126.2 -125.6 ... -61.88 -61.25 -60.62
#   * lat          (lat) float64 23.0 23.5 24.0 24.5 25.0 ... 48.5 49.0 49.5 50.0
#   * hour         (hour) int64 0
# Data variables:
#     PRECTOTCORR  (time, lat, lon, hour) float64 ...

# %%
precip_00z=DS_0_precip['PRECTOTCORR']
precip_00z
# Out:
# <xarray.DataArray 'PRECTOTCORR' (time: 3760, lat: 55, lon: 107, hour: 1)>
# [22127600 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2021-02-28
#   * lon      (lon) float64 -126.9 -126.2 -125.6 -125.0 ... -61.88 -61.25 -60.62
#   * lat      (lat) float64 23.0 23.5 24.0 24.5 25.0 ... 48.0 48.5 49.0 49.5 50.0
#   * hour     (hour) int64 0

# %% [markdown]
# ### 06z

# %%
DS_6_precip=xr.open_dataset('/project/xprecip/merra2_ncfiles/precip/anomalies/norm_anoms_precip_06z_corrected.nc')
DS_6_precip
# Out:
# <xarray.Dataset>
# Dimensions:      (hour: 1, lat: 55, lon: 107, time: 3760)
# Coordinates:
#   * time         (time) datetime64[ns] 1980-01-01T06:00:00 ... 2021-02-28T06:...
#   * lon          (lon) float64 -126.9 -126.2 -125.6 ... -61.88 -61.25 -60.62
#   * lat          (lat) float64 23.0 23.5 24.0 24.5 25.0 ... 48.5 49.0 49.5 50.0
#   * hour         (hour) int64 6
# Data variables:
#     PRECTOTCORR  (time, lat, lon, hour) float64 ...

# %%
precip_06z=DS_6_precip['PRECTOTCORR']
precip_06z
# Out:
# <xarray.DataArray 'PRECTOTCORR' (time: 3760, lat: 55, lon: 107, hour: 1)>
# [22127600 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01T06:00:00 ... 2021-02-28T06:00:00
#   * lon      (lon) float64 -126.9 -126.2 -125.6 -125.0 ... -61.88 -61.25 -60.62
#   * lat      (lat) float64 23.0 23.5 24.0 24.5 25.0 ... 48.0 48.5 49.0 49.5 50.0
#   * hour     (hour) int64 6

# %% [markdown]
# ### 12z

# %%
DS_12_precip=xr.open_dataset('/project/xprecip/merra2_ncfiles/precip/anomalies/norm_anoms_precip_12z_corrected.nc')
DS_12_precip
# Out:
# <xarray.Dataset>
# Dimensions:      (hour: 1, lat: 55, lon: 107, time: 3760)
# Coordinates:
#   * time         (time) datetime64[ns] 1980-01-01T12:00:00 ... 2021-02-28T12:...
#   * lon          (lon) float64 -126.9 -126.2 -125.6 ... -61.88 -61.25 -60.62
#   * lat          (lat) float64 23.0 23.5 24.0 24.5 25.0 ... 48.5 49.0 49.5 50.0
#   * hour         (hour) int64 12
# Data variables:
#     PRECTOTCORR  (time, lat, lon, hour) float64 ...

# %%
precip_12z=DS_12_precip['PRECTOTCORR']
precip_12z
# Out:
# <xarray.DataArray 'PRECTOTCORR' (time: 3760, lat: 55, lon: 107, hour: 1)>
# [22127600 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01T12:00:00 ... 2021-02-28T12:00:00
#   * lon      (lon) float64 -126.9 -126.2 -125.6 -125.0 ... -61.88 -61.25 -60.62
#   * lat      (lat) float64 23.0 23.5 24.0 24.5 25.0 ... 48.0 48.5 49.0 49.5 50.0
#   * hour     (hour) int64 12

# %% [markdown]
# ### 18z

# %%
DS_18_precip=xr.open_dataset('/project/xprecip/merra2_ncfiles/precip/anomalies/norm_anoms_precip_18z_corrected.nc')
DS_18_precip
# Out:
# <xarray.Dataset>
# Dimensions:      (hour: 1, lat: 55, lon: 107, time: 3760)
# Coordinates:
#   * time         (time) datetime64[ns] 1980-01-01T18:00:00 ... 2021-02-28T18:...
#   * lon          (lon) float64 -126.9 -126.2 -125.6 ... -61.88 -61.25 -60.62
#   * lat          (lat) float64 23.0 23.5 24.0 24.5 25.0 ... 48.5 49.0 49.5 50.0
#   * hour         (hour) int64 18
# Data variables:
#     PRECTOTCORR  (time, lat, lon, hour) float64 ...

# %%
precip_18z=DS_18_precip['PRECTOTCORR']
precip_18z
# Out:
# <xarray.DataArray 'PRECTOTCORR' (time: 3760, lat: 55, lon: 107, hour: 1)>
# [22127600 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01T18:00:00 ... 2021-02-28T18:00:00
#   * lon      (lon) float64 -126.9 -126.2 -125.6 -125.0 ... -61.88 -61.25 -60.62
#   * lat      (lat) float64 23.0 23.5 24.0 24.5 25.0 ... 48.0 48.5 49.0 49.5 50.0
#   * hour     (hour) int64 18

# %%
precip_anoms_concat=xr.concat([precip_00z,precip_06z,precip_12z,precip_18z],dim='time')
precip_anoms_concat
# Out:
# <xarray.DataArray 'PRECTOTCORR' (time: 15040, lat: 55, lon: 107, hour: 4)>
# array([[[[-1.51525376e-01,             nan,             nan,
#                       nan],
#          [-1.47969273e-01,             nan,             nan,
#                       nan],
#          [-1.42077847e-01,             nan,             nan,
#                       nan],
#          ...,
#          [-3.67801271e-02,             nan,             nan,
#                       nan],
#          [-1.03129443e-01,             nan,             nan,
#                       nan],
#          [-1.11633763e-01,             nan,             nan,
#                       nan]],
#
#         [[-1.35483797e-01,             nan,             nan,
#                       nan],
#          [-1.30566238e-01,             nan,             nan,
#                       nan],
#          [-1.26608861e-01,             nan,             nan,
#                       nan],
# ...
# ...

# %%
precip_concat_sorted=precip_anoms_concat.sortby('time')
precip_concat_sorted
# Out:
# <xarray.DataArray 'PRECTOTCORR' (time: 15040, lat: 55, lon: 107, hour: 4)>
# array([[[[-0.15152538,         nan,         nan,         nan],
#          [-0.14796927,         nan,         nan,         nan],
#          [-0.14207785,         nan,         nan,         nan],
#          ...,
#          [-0.03678013,         nan,         nan,         nan],
#          [-0.10312944,         nan,         nan,         nan],
#          [-0.11163376,         nan,         nan,         nan]],
#
#         [[-0.1354838 ,         nan,         nan,         nan],
#          [-0.13056624,         nan,         nan,         nan],
#          [-0.12660886,         nan,         nan,         nan],
#          ...,
#          [ 0.01829074,         nan,         nan,         nan],
#          [-0.09382336,         nan,         nan,         nan],
#          [-0.08010421,         nan,         nan,         nan]],
#
#         [[-0.1297424 ,         nan,         nan,         nan],
# ...

# %% [markdown]
# ### Vorticity

# %%
DS_0=xr.open_dataset('/project/xprecip/merra2_ncfiles/winds/vort_analysis/norm_anoms_vort_00z_corrected.nc')
DS_0
# Out:
# <xarray.Dataset>
# Dimensions:                        (hour: 1, lat: 55, lon: 113, time: 3760)
# Coordinates:
#   * time                           (time) datetime64[ns] 1980-01-01 ... 2021-...
#   * lon                            (lon) float64 -126.2 -125.6 ... -56.88 -56.25
#   * lat                            (lat) float64 24.5 25.0 25.5 ... 51.0 51.5
#   * hour                           (hour) int64 0
# Data variables:
#     __xarray_dataarray_variable__  (time, lat, lon, hour) float64 ...

# %%
vort_00z=DS_0['__xarray_dataarray_variable__']
vort_00z
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (time: 3760, lat: 55, lon: 113, hour: 1)>
# [23368400 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 1980-01-02 ... 2021-02-28
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#   * hour     (hour) int64 0

# %%
DS_6=xr.open_dataset('/project/xprecip/merra2_ncfiles/winds/vort_analysis/norm_anoms_vort_06z_corrected.nc')
DS_6
# Out:
# <xarray.Dataset>
# Dimensions:                        (hour: 1, lat: 55, lon: 113, time: 3760)
# Coordinates:
#   * time                           (time) datetime64[ns] 1980-01-01T06:00:00 ...
#   * lon                            (lon) float64 -126.2 -125.6 ... -56.88 -56.25
#   * lat                            (lat) float64 24.5 25.0 25.5 ... 51.0 51.5
#   * hour                           (hour) int64 6
# Data variables:
#     __xarray_dataarray_variable__  (time, lat, lon, hour) float64 ...

# %%
vort_06z=DS_6['__xarray_dataarray_variable__']
vort_06z
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (time: 3760, lat: 55, lon: 113, hour: 1)>
# [23368400 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01T06:00:00 ... 2021-02-28T06:00:00
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#   * hour     (hour) int64 6

# %%
DS_12=xr.open_dataset('/project/xprecip/merra2_ncfiles/winds/vort_analysis/norm_anoms_vort_12z_corrected.nc')
DS_12
# Out:
# <xarray.Dataset>
# Dimensions:                        (hour: 1, lat: 55, lon: 113, time: 3760)
# Coordinates:
#   * time                           (time) datetime64[ns] 1980-01-01T12:00:00 ...
#   * lon                            (lon) float64 -126.2 -125.6 ... -56.88 -56.25
#   * lat                            (lat) float64 24.5 25.0 25.5 ... 51.0 51.5
#   * hour                           (hour) int64 12
# Data variables:
#     __xarray_dataarray_variable__  (time, lat, lon, hour) float64 ...

# %%
vort_12z=DS_12['__xarray_dataarray_variable__']
vort_12z
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (time: 3760, lat: 55, lon: 113, hour: 1)>
# [23368400 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01T12:00:00 ... 2021-02-28T12:00:00
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#   * hour     (hour) int64 12

# %%
DS_18=xr.open_dataset('/project/xprecip/merra2_ncfiles/winds/vort_analysis/norm_anoms_vort_18z_corrected.nc')
DS_18
# Out:
# <xarray.Dataset>
# Dimensions:                        (hour: 1, lat: 55, lon: 113, time: 3760)
# Coordinates:
#   * time                           (time) datetime64[ns] 1980-01-01T18:00:00 ...
#   * lon                            (lon) float64 -126.2 -125.6 ... -56.88 -56.25
#   * lat                            (lat) float64 24.5 25.0 25.5 ... 51.0 51.5
#   * hour                           (hour) int64 18
# Data variables:
#     __xarray_dataarray_variable__  (time, lat, lon, hour) float64 ...

# %%
vort_18z=DS_18['__xarray_dataarray_variable__']
vort_18z
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (time: 3760, lat: 55, lon: 113, hour: 1)>
# [23368400 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01T18:00:00 ... 2021-02-28T18:00:00
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -57.5 -56.88 -56.25
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 49.5 50.0 50.5 51.0 51.5
#   * hour     (hour) int64 18

# %%
vort_concat=xr.concat([vort_00z,vort_06z,vort_12z,vort_18z],dim='time')
vort_concat
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (time: 15040, lat: 55, lon: 113, hour: 4)>
# array([[[[            nan,             nan,             nan,
#                       nan],
#          [            nan,             nan,             nan,
#                       nan],
#          [            nan,             nan,             nan,
#                       nan],
#          ...,
#          [            nan,             nan,             nan,
#                       nan],
#          [            nan,             nan,             nan,
#                       nan],
#          [            nan,             nan,             nan,
#                       nan]],
#
#         [[            nan,             nan,             nan,
#                       nan],
#          [-4.60938499e-01,             nan,             nan,
#                       nan],
#          [-2.29195724e-01,             nan,             nan,
#                       nan],
# ...
# ...

# %%
vort_concat_sorted=vort_concat.sortby('time')
vort_concat_sorted
# Out:
# <xarray.DataArray '__xarray_dataarray_variable__' (time: 15040, lat: 55, lon: 113, hour: 4)>
# array([[[[            nan,             nan,             nan,
#                       nan],
#          [            nan,             nan,             nan,
#                       nan],
#          [            nan,             nan,             nan,
#                       nan],
#          ...,
#          [            nan,             nan,             nan,
#                       nan],
#          [            nan,             nan,             nan,
#                       nan],
#          [            nan,             nan,             nan,
#                       nan]],
#
#         [[            nan,             nan,             nan,
#                       nan],
#          [-4.60938499e-01,             nan,             nan,
#                       nan],
#          [-2.29195724e-01,             nan,             nan,
#                       nan],
# ...
# ...

# %%
corr_map=xr.corr(precip_concat_sorted,vort_concat_sorted,dim='time')
print(corr_map)
# Out:
# <xarray.DataArray (lat: 52, lon: 106, hour: 4)>
# array([[[        nan,         nan,         nan,         nan],
#         [        nan,         nan,         nan,         nan],
#         [        nan,         nan,         nan,         nan],
#         ...,
#         [        nan,         nan,         nan,         nan],
#         [        nan,         nan,         nan,         nan],
#         [        nan,         nan,         nan,         nan]],
#
#        [[        nan,         nan,         nan,         nan],
#         [ 0.00843127,  0.01692308,  0.05387177,  0.02845996],
#         [ 0.00153784,  0.02594903,  0.01487679,  0.04147056],
#         ...,
#         [ 0.07784485,  0.08251032,  0.09607349,  0.07802973],
#         [ 0.05348184,  0.08478759,  0.11663839,  0.09051345],
#         [ 0.07336593,  0.07144306,  0.09604594,  0.07364163]],
#
#        [[        nan,         nan,         nan,         nan],
#         [-0.00064831,  0.02970068,  0.06267595,  0.05159969],
# ...

# %%
corr_map_mean=corr_map.mean(dim='hour')
corr_map_mean
# Out:
# <xarray.DataArray (lat: 52, lon: 106)>
# array([[       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan, 0.02692152, 0.02095855, ..., 0.0836146 , 0.08635532,
#         0.07862414],
#        [       nan, 0.035832  , 0.04440117, ..., 0.08513763, 0.12882492,
#         0.094901  ],
#        ...,
#        [       nan, 0.28797013, 0.21251932, ..., 0.0594864 , 0.0475221 ,
#         0.06125143],
#        [       nan, 0.20810084, 0.20252133, ..., 0.04656842, 0.04241318,
#         0.04939522],
#        [       nan, 0.12358231, 0.09486661, ..., 0.03896374, 0.04823312,
#         0.06045027]])
# Coordinates:
#   * lat      (lat) float64 24.5 25.0 25.5 26.0 26.5 ... 48.0 48.5 49.0 49.5 50.0
#   * lon      (lon) float64 -126.2 -125.6 -125.0 -124.4 ... -61.88 -61.25 -60.62

# %%
clevs=np.arange(-1,1.1,0.1)

fig = plt.figure(figsize=(11,8.5))

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree(central_longitude=180))

# Add cyclic point
data=corr_map_mean
#data,lon=add_cyclic_point(r_map,coord=data_lon)

# Make a filled contour plot
cs=ax.contourf(corr_map['lon'],corr_map['lat'],
            data,clevs,
            transform=ccrs.PlateCarree(),
            cmap='bwr',extend='both')

# Add coastlines
ax.coastlines()

# Add gridlines
ax.gridlines()
ax.set_extent([-124.5,-66.8,23.486,49])
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')

# Call colorbar
cbar=plt.colorbar(cs,orientation='horizontal',shrink=0.7,
                 label='Correlation Coefficient')

# Add title
plt.title('Correlation between Normalized Vorticity and Precipitation Anomalies')
plt.savefig('/homes/areed29/CLIM997/summer22_research/corrmap_vort_precip_anoms')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:388: MatplotlibDeprecationWarning:
# The 'inframe' parameter of draw() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use Axes.redraw_in_frame() instead. If any parameter follows 'inframe', they should be passed as keyword, not positionally.
#   inframe=inframe)

# %%
# Define the figure and each axis for the 2 rows and 2 columns
fig, axs = plt.subplots(nrows=2,ncols=2,
                        subplot_kw={'projection': ccrs.PlateCarree()},
                        figsize=(11,8.5))
clevs=np.arange(-1,1.1,0.1)

# axs is a 2 dimensional array of `GeoAxes`.  
# We will flatten it into a 1-D array
axs=axs.flatten()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())

#Loop over all of the seasons and plot
for i,hour in enumerate(corr_map['hour']):

        # Select the season
        data=corr_map.sel(hour=hour)

        # Add the cyclic point
        data,lons=add_cyclic_point(data,coord=corr_map['lon'])

        # Contour plot
        cs=axs[i].contourf(lons,corr_map['lat'],data,clevs,
                          transform = ccrs.PlateCarree(),
                          cmap='bwr',extend='both')

       # Longitude labels
        axs[i].set_xticks(np.arange(-180,181,60), crs=ccrs.PlateCarree())
        lon_formatter = cticker.LongitudeFormatter()
        axs[i].xaxis.set_major_formatter(lon_formatter)

        # Latitude labels
        axs[i].set_yticks(np.arange(-90,91,30), crs=ccrs.PlateCarree())
        lat_formatter = cticker.LatitudeFormatter()
        axs[i].yaxis.set_major_formatter(lat_formatter)

        # Title each subplot with the name of the season
        axs[i].set_title(hour.values)

        # Draw the coastines for each subplot
        axs[i].coastlines()
        axs[i].gridlines()
        axs[i].set_extent([-124.5,-66.8,23.486,49])
        axs[i].add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')
# Adjust the location of the subplots 
# on the page to make room for the colorbar
fig.subplots_adjust(bottom=0.25, top=0.9, left=0.05, right=0.95,
                    wspace=0.2, hspace=0.2)

# Add a colorbar axis at the bottom of the graph
cbar_ax = fig.add_axes([0.2, 0.175, 0.6, 0.02])

# Draw the colorbar
cbar=fig.colorbar(cs, cax=cbar_ax,orientation='horizontal',label='Correlation Coefficient')
plt.suptitle('Diurnal cycle of Precipitation & Vorticity Anomaly Correlations across CONUS')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:782: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   return super(GeoAxes, self).set_xticks(xticks, minor)
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:829: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   return super(GeoAxes, self).set_yticks(yticks, minor)
# Text(0.5, 0.98, 'Diurnal cycle of Precipitation & Vorticity Anomaly Correlations across CONUS')

# %%
dc_precip=precip_06z.sel(lat=39,lon=-77,method='nearest')
dc_vort_lag=vort_00z.sel(lat=39,lon=-77,method='nearest')
dc_vort_6z=vort_06z.sel(lat=39,lon=-77,method='nearest')
dc_precip_smaller=dc_precip.loc['2019-01-01':'2019-02-28']
dc_vort_lag_smaller=dc_vort_lag.loc['2019-01-01':'2019-02-28']
dc_vort_smaller=dc_vort_6z.loc['2019-01-01':'2019-02-28']

# %%
#DC time series lagged
plt.plot(dc_precip_smaller['time'],dc_precip_smaller,'b')
plt.plot(dc_vort_lag_smaller['time'],dc_vort_lag_smaller,'r')
plt.legend(['Precip','Vorticity (Washington, DC)'])
plt.axhline(y=0.0, color='g', linestyle='-')
plt.xlabel('Time (in years)')
plt.ylabel('Normalized Anomalies')
plt.title('Time evolution of Normalized Vorticity coupled with Normalized Precipitation anomalies in DC (lagged)')
plt.savefig('/homes/areed29/CLIM997/summer22_research/washington_vortanoms_corr',bbox_inches='tight')

# %%
#DC time series lagged
plt.plot(dc_precip_smaller['time'],dc_precip_smaller,'b')
plt.plot(dc_vort_smaller['time'],dc_vort_smaller,'r')
plt.legend(['Precip','Vorticity (Washington, DC)'])
plt.axhline(y=0.0, color='g', linestyle='-')
plt.xlabel('Time (in years)')
plt.ylabel('Normalized Anomalies')
plt.title('Time evolution of Normalized Vorticity coupled with Normalized Precipitation anomalies in DC (no lag)')
plt.savefig('/homes/areed29/CLIM997/summer22_research/washington_vortanoms_corr',bbox_inches='tight')

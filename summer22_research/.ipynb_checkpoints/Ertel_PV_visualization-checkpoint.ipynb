# %% [markdown]
# ### Ertel Potential Vorticity visualization

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
#from intake import open_catalog
import cartopy.io.shapereader as shpreader
import mygrads as mg
#import Ngl
#import Nio
#import fiona
import matplotlib as mpl
import cartopy.mpl.ticker as cticker
from cartopy.util import add_cyclic_point
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from cartopy.feature import NaturalEarthFeature
from cartopy.feature import COASTLINE
from clim680_function import xyticks
import pymannkendall as mk

# %%
# total field
f='/project/xprecip/merra2_ncfiles/ertel_pv/*.nc'
DS_pv=xr.open_mfdataset(f,combine='nested',concat_dim='time')
DS_pv
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 68, lev: 2, lon: 136, time: 126128)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2021-09-30T21:00:00
#   * lon      (lon) float64 -131.2 -130.6 -130.0 -129.4 ... -48.12 -47.5 -46.88
#   * lat      (lat) float64 22.0 22.5 23.0 23.5 24.0 ... 53.5 54.0 54.5 55.0 55.5
#   * lev      (lev) float64 775.0 300.0
# Data variables:
#     EPV      (time, lev, lat, lon) float32 dask.array<chunksize=(8, 2, 68, 136), meta=np.ndarray>
# Attributes: (12/32)
#     CDI:                               Climate Data Interface version 1.9.8 (...
#     Conventions:                       CF-1
#     History:                           Original file generated: Sat May 31 18...
#     Comment:                           GMAO filename: d5124_m2_jan79.inst3_3d...
#     Filename:                          MERRA2_100.inst3_3d_asm_Np.19800101.nc4
#     Institution:                       NASA Global Modeling and Assimilation ...
# ...

# %%
lat_pv=['lat']
lon_pv=['lon']
ertel_pv=DS_pv['EPV']
ertel_pv
# Out:
# <xarray.DataArray 'EPV' (time: 126128, lev: 2, lat: 68, lon: 136)>
# dask.array<concatenate, shape=(126128, 2, 68, 136), dtype=float32, chunksize=(8, 2, 68, 136), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2021-09-30T21:00:00
#   * lon      (lon) float64 -131.2 -130.6 -130.0 -129.4 ... -48.12 -47.5 -46.88
#   * lat      (lat) float64 22.0 22.5 23.0 23.5 24.0 ... 53.5 54.0 54.5 55.0 55.5
#   * lev      (lev) float64 775.0 300.0
# Attributes:
#     standard_name:   ertels_potential_vorticity
#     long_name:       ertels_potential_vorticity
#     units:           K m+2 kg-1 s-1
#     fmissing_value:  1000000000000000.0
#     vmax:            1000000000000000.0
#     vmin:            -1000000000000000.0

# %%
winter_selected_epv=ertel_pv.isel(time=ertel_pv.time.dt.season.isin(['DJF']))
winter_selected_epv
# Out:
# <xarray.DataArray 'EPV' (time: 31520, lev: 2, lat: 68, lon: 136)>
# dask.array<getitem, shape=(31520, 2, 68, 136), dtype=float32, chunksize=(8, 2, 68, 136), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2023-02-28T21:00:00
#   * lon      (lon) float64 -131.2 -130.6 -130.0 -129.4 ... -48.12 -47.5 -46.88
#   * lat      (lat) float64 22.0 22.5 23.0 23.5 24.0 ... 53.5 54.0 54.5 55.0 55.5
#   * lev      (lev) float64 775.0 300.0
# Attributes:
#     standard_name:   ertels_potential_vorticity
#     long_name:       ertels_potential_vorticity
#     units:           K m+2 kg-1 s-1
#     fmissing_value:  1000000000000000.0
#     vmax:            1000000000000000.0
#     vmin:            -1000000000000000.0

# %%
epv_6hr_mean=winter_selected_epv.resample(time='6H').mean(dim='time')
epv_6hr_mean
# Out:
# <xarray.DataArray 'EPV' (time: 63060, lev: 2, lat: 68, lon: 136)>
# dask.array<where, shape=(63060, 2, 68, 136), dtype=float32, chunksize=(1101, 2, 68, 136), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2023-02-28T18:00:00
#   * lon      (lon) float64 -131.2 -130.6 -130.0 -129.4 ... -48.12 -47.5 -46.88
#   * lat      (lat) float64 22.0 22.5 23.0 23.5 24.0 ... 53.5 54.0 54.5 55.0 55.5
#   * lev      (lev) float64 775.0 300.0

# %%
epv_6hr_mean.to_netcdf('/project/xprecip/merra2_ncfiles/ertel_pv/ertel_pv_6hrmean.nc')
# Out:
# /homes/areed29/.conda/envs/clim680/lib/python3.6/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %% [markdown]
# ### Loading in the 6 hourly PV data

# %%
# total field
f='/project/xprecip/merra2_ncfiles/ertel_pv/ertel_pv_6hrmean.nc'
DS_pv=xr.open_dataset(f)
DS_pv
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 68, lev: 2, lon: 136, time: 63060)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2023-02-28T18:00:00
#   * lon      (lon) float64 -131.2 -130.6 -130.0 -129.4 ... -48.12 -47.5 -46.88
#   * lat      (lat) float64 22.0 22.5 23.0 23.5 24.0 ... 53.5 54.0 54.5 55.0 55.5
#   * lev      (lev) float64 775.0 300.0
# Data variables:
#     EPV      (time, lev, lat, lon) float32 ...

# %%
winter_selected_epv=DS_pv.isel(time=DS_pv.time.dt.season.isin(['DJF']))
winter_selected_epv
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 68, lev: 2, lon: 136, time: 15760)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-01-01 ... 2023-02-28T18:00:00
#   * lon      (lon) float64 -131.2 -130.6 -130.0 -129.4 ... -48.12 -47.5 -46.88
#   * lat      (lat) float64 22.0 22.5 23.0 23.5 24.0 ... 53.5 54.0 54.5 55.0 55.5
#   * lev      (lev) float64 775.0 300.0
# Data variables:
#     EPV      (time, lev, lat, lon) float32 ...

# %%
epv_upper=winter_selected_epv.sel(lev=300.0)
epv_lower=winter_selected_epv.sel(lev=775.0)

# %%
epv_upper_climo=epv_upper.groupby('time.month').mean(dim='time')
epv_lower_climo=epv_lower.groupby('time.month').mean(dim='time')

# %%
epv_upper_climo
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 68, lon: 136, month: 3)
# Coordinates:
#   * lon      (lon) float64 -131.2 -130.6 -130.0 -129.4 ... -48.12 -47.5 -46.88
#   * lat      (lat) float64 22.0 22.5 23.0 23.5 24.0 ... 53.5 54.0 54.5 55.0 55.5
#     lev      float64 300.0
#   * month    (month) int64 1 2 12
# Data variables:
#     EPV      (month, lat, lon) float32 5.526e-07 5.505e-07 ... 3.079e-06

# %%
epv_lower_climo
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 68, lon: 136, month: 3)
# Coordinates:
#   * lon      (lon) float64 -131.2 -130.6 -130.0 -129.4 ... -48.12 -47.5 -46.88
#   * lat      (lat) float64 22.0 22.5 23.0 23.5 24.0 ... 53.5 54.0 54.5 55.0 55.5
#     lev      float64 775.0
#   * month    (month) int64 1 2 12
# Data variables:
#     EPV      (month, lat, lon) float32 3.322e-07 3.312e-07 ... 7.692e-07

# %%
dec_upper=epv_upper_climo['EPV'].sel(month=12)
jan_upper=epv_upper_climo['EPV'].sel(month=1)
feb_upper=epv_upper_climo['EPV'].sel(month=2)
dec_lower=epv_lower_climo['EPV'].sel(month=12)
jan_lower=epv_lower_climo['EPV'].sel(month=1)
feb_lower=epv_lower_climo['EPV'].sel(month=2)

# %%
dec_lower
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 68, lon: 136)
# Coordinates:
#   * lon      (lon) float64 -131.2 -130.6 -130.0 -129.4 ... -48.12 -47.5 -46.88
#   * lat      (lat) float64 22.0 22.5 23.0 23.5 24.0 ... 53.5 54.0 54.5 55.0 55.5
#     lev      float64 775.0
#     month    int64 12
# Data variables:
#     EPV      (lat, lon) float32 3.81e-07 3.764e-07 ... 7.718e-07 7.692e-07

# %%
max_val=3.2e-6
increment=0.2e-6
clevs=np.arange(0,max_val,increment)

fig = plt.figure(figsize=(11,8.5))

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree(central_longitude=180))

# Add cyclic point
data=dec_upper
data,lon=add_cyclic_point(data,coord=dec_upper['lon'])
#mask_data,lons=add_cyclic_point(mask_sig,coord=jan_ts['lon'])

# Make a filled contour plot
cs=ax.contourf(lon,dec_upper['lat'],
            data,clevs,
            transform=ccrs.PlateCarree(),
            cmap='jet',extend='both')

ax.set_xticks(np.arange(-180,181,60),crs=ccrs.PlateCarree())
lon_formatter=cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)

# Define ytick for latitude
ax.set_yticks(np.arange(-90,91,30),crs=ccrs.PlateCarree())
lat_formatter=cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)

ax.set_extent([-124.5,-66.8,23.486,49])
ax.coastlines()
ax.gridlines()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')

# Call colorbar
cbar=plt.colorbar(cs,orientation='horizontal',shrink=0.7,
                 label='Ertel PV (Km^2kg^-1s^-1)')

# Add title
plt.title('December Upper EPV 6 hourly Climatology over CONUS from 1980-2022')
plt.savefig('/homes/areed29/CLIM997/summer22_research/epv_dec_climo_upper.png')

# %%
#clevs=np.arange(-1.0,1.0,10)
max_val=3.2e-6
increment=0.2e-6
clevs=np.arange(0,max_val,increment)
#clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)

fig = plt.figure(figsize=(11,8.5))

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree(central_longitude=180))

# Add cyclic point
data=dec_lower
data,lon=add_cyclic_point(data,coord=dec_lower['lon'])
#mask_data,lons=add_cyclic_point(mask_sig,coord=jan_ts['lon'])

# Make a filled contour plot
cs=ax.contourf(lon,dec_lower['lat'],
            data,clevs,
            transform=ccrs.PlateCarree(),
            cmap='jet',extend='both')

ax.set_xticks(np.arange(-180,181,60),crs=ccrs.PlateCarree())
lon_formatter=cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)

# Define ytick for latitude
ax.set_yticks(np.arange(-90,91,30),crs=ccrs.PlateCarree())
lat_formatter=cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)

ax.set_extent([-124.5,-66.8,23.486,49])
ax.coastlines()
ax.gridlines()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')

# Call colorbar
cbar=plt.colorbar(cs,orientation='horizontal',shrink=0.7,
                 label='Ertel PV (Km^2kg^-1s^-1)')

# Add title
plt.title('December Lower PV 6 hourly Climatology over CONUS from 1980-2022')
plt.savefig('/homes/areed29/CLIM997/summer22_research/epv_dec_climo_lower.png')

# %%
max_val=3.2e-6
increment=0.2e-6
clevs=np.arange(0,max_val,increment)

fig = plt.figure(figsize=(11,8.5))

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree(central_longitude=180))

# Add cyclic point
data=jan_upper
data,lon=add_cyclic_point(data,coord=jan_upper['lon'])
#mask_data,lons=add_cyclic_point(mask_sig,coord=jan_ts['lon'])

# Make a filled contour plot
cs=ax.contourf(lon,jan_upper['lat'],
            data,clevs,
            transform=ccrs.PlateCarree(),
            cmap='jet',extend='both')

ax.set_xticks(np.arange(-180,181,60),crs=ccrs.PlateCarree())
lon_formatter=cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)

# Define ytick for latitude
ax.set_yticks(np.arange(-90,91,30),crs=ccrs.PlateCarree())
lat_formatter=cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)

ax.set_extent([-124.5,-66.8,23.486,49])
ax.coastlines()
ax.gridlines()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')

# Call colorbar
cbar=plt.colorbar(cs,orientation='horizontal',shrink=0.7,
                 label='Ertel PV (Km^2kg^-1s^-1)')

# Add title
plt.title('January Upper PV 6 hourly Climatology over CONUS from 1980-2022')
plt.savefig('/homes/areed29/CLIM997/summer22_research/epv_jan_climo_upper.png')

# %%
#clevs=np.arange(-1.0,1.0,10)
max_val=3.2e-6
increment=0.2e-6
clevs=np.arange(0,max_val,increment)
#clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)

fig = plt.figure(figsize=(11,8.5))

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree(central_longitude=180))

# Add cyclic point
data=jan_lower
data,lon=add_cyclic_point(data,coord=jan_lower['lon'])
#mask_data,lons=add_cyclic_point(mask_sig,coord=jan_ts['lon'])

# Make a filled contour plot
cs=ax.contourf(lon,jan_lower['lat'],
            data,clevs,
            transform=ccrs.PlateCarree(),
            cmap='jet',extend='both')

ax.set_xticks(np.arange(-180,181,60),crs=ccrs.PlateCarree())
lon_formatter=cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)

# Define ytick for latitude
ax.set_yticks(np.arange(-90,91,30),crs=ccrs.PlateCarree())
lat_formatter=cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)

ax.set_extent([-124.5,-66.8,23.486,49])
ax.coastlines()
ax.gridlines()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')

# Call colorbar
cbar=plt.colorbar(cs,orientation='horizontal',shrink=0.7,
                 label='Ertel PV (Km^2kg^-1s^-1)')

# Add title
plt.title('January Lower PV 6 hourly Climatology over CONUS from 1980-2022')
plt.savefig('/homes/areed29/CLIM997/summer22_research/epv_jan_climo_lower.png')

# %%
max_val=3.2e-6
increment=0.2e-6
clevs=np.arange(0,max_val,increment)

fig = plt.figure(figsize=(11,8.5))

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree(central_longitude=180))

# Add cyclic point
data=feb_upper
data,lon=add_cyclic_point(data,coord=feb_upper['lon'])
#mask_data,lons=add_cyclic_point(mask_sig,coord=jan_ts['lon'])

# Make a filled contour plot
cs=ax.contourf(lon,feb_upper['lat'],
            data,clevs,
            transform=ccrs.PlateCarree(),
            cmap='jet',extend='both')

ax.set_xticks(np.arange(-180,181,60),crs=ccrs.PlateCarree())
lon_formatter=cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)

# Define ytick for latitude
ax.set_yticks(np.arange(-90,91,30),crs=ccrs.PlateCarree())
lat_formatter=cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)

ax.set_extent([-124.5,-66.8,23.486,49])
ax.coastlines()
ax.gridlines()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')

# Call colorbar
cbar=plt.colorbar(cs,orientation='horizontal',shrink=0.7,
                 label='Ertel PV (Km^2kg^-1s^-1)')

# Add title
plt.title('February Upper PV 6 hourly Climatology over CONUS from 1980-2022')
plt.savefig('/homes/areed29/CLIM997/summer22_research/epv_feb_climo_upper.png')

# %%
#clevs=np.arange(-1.0,1.0,10)
max_val=3.2e-6
increment=0.2e-6
clevs=np.arange(0,max_val,increment)
#clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)

fig = plt.figure(figsize=(11,8.5))

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree(central_longitude=180))

# Add cyclic point
data=feb_lower
data,lon=add_cyclic_point(data,coord=feb_lower['lon'])
#mask_data,lons=add_cyclic_point(mask_sig,coord=jan_ts['lon'])

# Make a filled contour plot
cs=ax.contourf(lon,feb_lower['lat'],
            data,clevs,
            transform=ccrs.PlateCarree(),
            cmap='jet',extend='both')

ax.set_xticks(np.arange(-180,181,60),crs=ccrs.PlateCarree())
lon_formatter=cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)

# Define ytick for latitude
ax.set_yticks(np.arange(-90,91,30),crs=ccrs.PlateCarree())
lat_formatter=cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)

ax.set_extent([-124.5,-66.8,23.486,49])
ax.coastlines()
ax.gridlines()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')

# Call colorbar
cbar=plt.colorbar(cs,orientation='horizontal',shrink=0.7,
                 label='Ertel PV (Km^2kg^-1s^-1)')

# Add title
plt.title('February Lower PV 6 hourly Climatology over CONUS from 1980-2022')
plt.savefig('/homes/areed29/CLIM997/summer22_research/epv_feb_climo_lower.png')

# %% [markdown]
# ### Anomalies

# %%
epv_upper_anoms=epv_upper.groupby('time.month')-epv_upper_climo
epv_lower_anoms=epv_lower.groupby('time.month')-epv_lower_climo

# %%
epv_upper_dec=epv_upper.isel(time=epv_upper.time.dt.month.isin([12]))
epv_lower_dec=epv_lower.isel(time=epv_lower.time.dt.month.isin([12]))
epv_upper_jan=epv_upper.isel(time=epv_upper.time.dt.month.isin([1]))
epv_lower_jan=epv_lower.isel(time=epv_lower.time.dt.month.isin([1]))
epv_upper_feb=epv_upper.isel(time=epv_upper.time.dt.month.isin([2]))
epv_lower_feb=epv_lower.isel(time=epv_lower.time.dt.month.isin([2]))

# %%
anoms_dec_upper=epv_upper_dec-dec_upper
anoms_dec_lower=epv_lower_dec-dec_lower
anoms_jan_upper=epv_upper_jan-jan_upper
anoms_jan_lower=epv_lower_jan-jan_lower
anoms_feb_upper=epv_upper_feb-feb_upper
anoms_feb_lower=epv_lower_feb-feb_lower

# %%
anoms_dec_upper
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 68, lon: 136, time: 5332)
# Coordinates:
#   * time     (time) datetime64[ns] 1980-12-01 ... 2022-12-31T18:00:00
#   * lon      (lon) float64 -131.2 -130.6 -130.0 -129.4 ... -48.12 -47.5 -46.88
#   * lat      (lat) float64 22.0 22.5 23.0 23.5 24.0 ... 53.5 54.0 54.5 55.0 55.5
#     lev      float64 300.0
#     month    int64 12
# Data variables:
#     EPV      (time, lat, lon) float32 -3.904e-07 -4.69e-07 ... -1.238e-06

# %%
max_val=7.5e-6
increment=0.25e-6
#clevs=np.arange(0,max_val,increment)
clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)

fig = plt.figure(figsize=(11,8.5))

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree(central_longitude=180))

# Add cyclic point
data=anoms_dec_upper['EPV'][-1,:,:]
data,lon=add_cyclic_point(data,coord=anoms_dec_upper['lon'])
#mask_data,lons=add_cyclic_point(mask_sig,coord=jan_ts['lon'])

# Make a filled contour plot
cs=ax.contourf(lon,anoms_dec_upper['lat'],
            data,clevs,
            transform=ccrs.PlateCarree(),
            cmap='bwr',extend='both')

ax.set_xticks(np.arange(-180,181,60),crs=ccrs.PlateCarree())
lon_formatter=cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)

# Define ytick for latitude
ax.set_yticks(np.arange(-90,91,30),crs=ccrs.PlateCarree())
lat_formatter=cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)

ax.set_extent([-124.5,-66.8,23.486,49])
ax.coastlines()
ax.gridlines()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')

# Call colorbar
cbar=plt.colorbar(cs,orientation='horizontal',shrink=0.7,
                 label='Ertel PV Anomaly (Km^2kg^-1s^-1)')

# Add title
plt.title('December Upper EPV 6 hourly Anomaly over CONUS from 1980-2022')
plt.savefig('/homes/areed29/CLIM997/summer22_research/epv_dec_climo_upper.png')

# %%
#max_val=3.2e-6
#increment=0.2e-6
#clevs=np.arange(0,max_val,increment)
max_val=7.5e-6
increment=0.25e-6
#clevs=np.arange(0,max_val,increment)
clevs = np.arange(start=-max_val, stop=max_val+increment, step=increment)
 
fig = plt.figure(figsize=(11,8.5))

# Set the axes using the specified map projection
ax=plt.axes(projection=ccrs.PlateCarree(central_longitude=180))

# Add cyclic point
data=anoms_dec_lower['EPV'][-1,:,:]
data,lon=add_cyclic_point(data,coord=anoms_dec_upper['lon'])
#mask_data,lons=add_cyclic_point(mask_sig,coord=jan_ts['lon'])

# Make a filled contour plot
cs=ax.contourf(lon,anoms_dec_lower['lat'],
            data,clevs,
            transform=ccrs.PlateCarree(),
            cmap='bwr',extend='both')

ax.set_xticks(np.arange(-180,181,60),crs=ccrs.PlateCarree())
lon_formatter=cticker.LongitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)

# Define ytick for latitude
ax.set_yticks(np.arange(-90,91,30),crs=ccrs.PlateCarree())
lat_formatter=cticker.LatitudeFormatter()
ax.yaxis.set_major_formatter(lat_formatter)

ax.set_extent([-124.5,-66.8,23.486,49])
ax.coastlines()
ax.gridlines()
us_shapes = list(shpreader.Reader("/scratch/areed29/gadm36_USA_shp/gadm36_USA_1.shp").geometries())
ax.add_geometries(us_shapes, ccrs.PlateCarree(), edgecolor='gray',
                  facecolor='none')

# Call colorbar
cbar=plt.colorbar(cs,orientation='horizontal',shrink=0.7,
                 label='Ertel PV Anomaly (Km^2kg^-1s^-1)')

# Add title
plt.title('December Lower EPV 6 hourly Anomaly over CONUS from 1980-2022')
#plt.savefig('/homes/areed29/CLIM997/summer22_research/epv_dec_climo_upper.png')
# Out:
# Text(0.5, 1.0, 'December Lower EPV 6 hourly Anomaly over CONUS from 1980-2022')
